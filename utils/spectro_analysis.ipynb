# %%
import os
import json
from birdlib import utils
import torch

# %%
import torch
import matplotlib.pyplot as plt

# Percorso base
path = '/home/giacomoschiavo/segments/dataset/test_specs'

# Caricamento dei due spettrogrammi
spec1 = torch.load(f"{path}/Erithacus rubecula_European Robin/20190601_030000_10_5.pt")
spec2 = torch.load(f"{path}/Erithacus rubecula_European Robin/20190601_030000_13_5.pt")
spec3 = torch.load(f"{path}/Erithacus rubecula_European Robin/20190601_030000_111_0.pt")

fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].imshow(spec1.numpy(), origin="lower", aspect="auto", cmap="gray_r")
axs[0].set_title("Erithacus rubecula - 0.963")

img2 = axs[1].imshow(spec2.numpy(), origin="lower", aspect="auto", cmap="gray_r")
axs[1].set_title("Erithacus rubecula - 0.830")

img3 = axs[2].imshow(spec3.numpy(), origin="lower", aspect="auto", cmap="gray_r")
axs[2].set_title("Erithacus rubecula - 0.684")

# Aggiungi colorbar solo una volta per non far casino

plt.tight_layout()
plt.show()

# %% [markdown]
# <audio controls src="../segments/dataset/test/Sylvia atricapilla_Eurasian Blackcap/20190601_190000_181_5.wav" title="Title"></audio>

# %%
import torch
import matplotlib.pyplot as plt

# Percorso base
path = '/home/giacomoschiavo/segments/dataset/test_specs'

# Caricamento dello spettrogramma
spec1 = torch.load(f"{path}/Erithacus rubecula_European Robin/20190601_030000_12_0.pt")

# Crea figura con 2 colonne: una per lo spettrogramma, una per la tabella
fig, axs = plt.subplots(1, 2, figsize=(10, 4), gridspec_kw={'width_ratios': [2, 2]})

# Spettrogramma
axs[0].imshow(spec1.numpy(), origin="lower", aspect="auto", cmap="gray_r")
axs[0].set_title("Erithacus rubecula - 0.944")
axs[0].set_xlabel("Time")
axs[0].set_ylabel("Frequency")

# Dati descrittivi per la tabella
axs[1].axis("off")

# Inserisci una frase o descrizione lunga
descrizione = (
    "True species: \n  [Erithacus rubecula, Regulus ignicapilla]\n"
    "Predicted species: \n  Erithacus rubecula (0.944)"
)

axs[1].text(0, 0.5, descrizione, fontsize=11, va='center', wrap=True)

# Disattiva gli assi del secondo subplot
axs[1].axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import torch
import matplotlib.pyplot as plt

# Percorso base
path = '/home/giacomoschiavo/segments/dataset/test_specs'

# Caricamento dello spettrogramma
spec1 = torch.load(f"{path}/Regulus ignicapilla_Common Firecrest/20190601_030000_16_5.pt")

# Crea figura con 2 colonne: una per lo spettrogramma, una per la tabella
fig, axs = plt.subplots(1, 2, figsize=(10, 4), gridspec_kw={'width_ratios': [2, 2]})

# Spettrogramma
axs[0].imshow(spec1.numpy(), origin="lower", aspect="auto", cmap="gray_r")
axs[0].set_title("")
axs[0].set_xlabel("Time")
axs[0].set_ylabel("Frequency")

# Dati descrittivi per la tabella
axs[1].axis("off")

# Inserisci una frase o descrizione lunga
descrizione = (
    "True species: \n  [Fringilla coelebs, Regulus ignicapilla]\n"
    "Predicted species: \n Fringilla coelebs (0.279) Regulus ignicapilla (0.190)"
)

axs[1].text(0, 0.5, descrizione, fontsize=11, va='center', wrap=True)

# Disattiva gli assi del secondo subplot
axs[1].axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import torch
import matplotlib.pyplot as plt

# Percorso base
path = '/home/giacomoschiavo/segments/dataset/test_specs'

# Caricamento dello spettrogramma
spec1 = torch.load(f"{path}/Regulus ignicapilla_Common Firecrest/20190601_030000_99_0.pt")

# Crea figura con 2 colonne: una per lo spettrogramma, una per la tabella
fig, axs = plt.subplots(1, 2, figsize=(10, 4), gridspec_kw={'width_ratios': [2, 2]})

# Spettrogramma
axs[0].imshow(spec1.numpy(), origin="lower", aspect="auto", cmap="gray_r")
axs[0].set_title("")
axs[0].set_xlabel("Time")
axs[0].set_ylabel("Frequency")

# Dati descrittivi per la tabella
axs[1].axis("off")

# Inserisci una frase o descrizione lunga
descrizione = (
    "True species: \n  [Regulus ignicapilla]\n"
    "Predicted species: \n Fringilla coelebs (0.611) Erithacus rubecula (0.086)"
)

axs[1].text(0, 0.5, descrizione, fontsize=11, va='center', wrap=True)

# Disattiva gli assi del secondo subplot
axs[1].axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import torch
import matplotlib.pyplot as plt

# Carica lo spettrogramma
path = '/home/giacomoschiavo/segments/dataset/test_specs'
spectrogram = torch.load(f"{path}/Anthus trivialis_Tree Pipit/20190601_080000_537_0.pt")
# Eurasian Blackbird	eurbla	0.1484	/home/giacomoschiavo/segments/dataset/test/Sylvia atricapilla_Eurasian Blackcap/20190601_190000_181_5.wav	0

print(f"Shape dello spettrogramma: {spectrogram.shape}")
plt.figure(figsize=(5, 4))
plt.imshow(spectrogram.numpy(), origin="lower", aspect="auto", cmap="gray_r")
plt.title("Spectrogram")
plt.colorbar(label="Log Amplitude")
plt.show()
# Out:
# Shape dello spettrogramma: torch.Size([256, 256])

# %% [markdown]
# # Esempio Wind con Sylvia atricapilla_Eurasian Blackcap

# %% [markdown]
# <audio controls src="../segments/dataset/test/Wind/20190601_100000_3_0.wav" title="Title"></audio>

# %%
import torch
import matplotlib.pyplot as plt

# Carica lo spettrogramma
spectrogram = torch.load("/home/giacomoschiavo/segments/dataset/test_specs/Sylvia atricapilla_Eurasian Blackcap/20190601_100000_3_0.pt")

print(f"Shape dello spettrogramma: {spectrogram.shape}")
plt.figure(figsize=(10, 6))
plt.imshow(spectrogram.numpy(), origin="lower", aspect="auto", cmap="magma_r")
plt.title("Spectrogram")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(label="Log Amplitude")
plt.show()
# Out:
# Shape dello spettrogramma: torch.Size([256, 256])

# %%
# Eurasian Blackcap	blackc1	0.8474	/home/giacomoschiavo/segments/dataset/test/Sylvia atricapilla_Eurasian Blackcap/20190601_100000_3_0.wav	0
# Common Chiffchaff	comchi1	0.0636	/home/giacomoschiavo/segments/dataset/test/Sylvia atricapilla_Eurasian Blackcap/20190601_100000_3_0.wav	0
# Eurasian Blackcap	blackc1	0.8474	/home/giacomoschiavo/segments/dataset/test/Wind/20190601_100000_3_0.wav	0
# Common Chiffchaff	comchi1	0.0636	/home/giacomoschiavo/segments/dataset/test/Wind/20190601_100000_3_0.wav	0
# "3_0": {
#     "Aeroplane": 0.16630589962005615,
#     "Wind": 0.9989504814147949,
#     "Sylvia atricapilla_Eurasian Blackcap": 1.0
# },

# %% [markdown]
# ## esempio Erithacus rubecula

# %% [markdown]
# <audio controls src="../segments/dataset/test/Fringilla coelebs_Common Chaffinch/20190601_030000_10_5.wav" title="Title"></audio>

# %%
import torch
import matplotlib.pyplot as plt

# Carica lo spettrogramma
spectrogram = torch.load("/home/giacomoschiavo/segments/dataset/test_specs/Fringilla coelebs_Common Chaffinch/20190601_030000_7_5.pt")

print(f"Shape dello spettrogramma: {spectrogram.shape}")
plt.figure(figsize=(10, 6))
plt.imshow(spectrogram.numpy(), origin="lower", aspect="auto", cmap="magma_r")
plt.title("Spectrogram")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(label="Log Amplitude")
plt.show()
# Out:
# Shape dello spettrogramma: torch.Size([256, 256])

# %% [markdown]
# Identificano molto bene l'erithacus ma entramni saltano la fringilla completamente
# European Robin	eurrob1	0.9638	/home/giacomoschiavo/segments/dataset/test/Fringilla coelebs_Common Chaffinch/20190601_030000_10_5.wav
# "10_5": {
# "Erithacus rubecula_European Robin": 0.999411940574646
# },

# %%
# I
# European Robin	eurrob1	0.9638	/home/giacomoschiavo/segments/dataset/test/Fringilla coelebs_Common Chaffinch/20190601_030000_10_5.wav

# %%
# Out:
# ['1',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '10001',
#  '10002',
#  '10003',
#  '10004',
#  '10005',
#  '10006',
#  '10007',
#  '10008',
#  '10009',
#  '1001',
#  '10010',
#  '10011',
#  '10012',
#  '10013',
#  '10014',
#  '10015',
#  '10016',
#  '10017',
#  '10018',
#  '10019',
#  '1002',
#  '10020',
#  '10021',
#  '10022',
#  '10023',
#  '10024',
#  '10025',
#  '10026',
#  '10027',
#  '10028',
#  '10029',
#  '1003',
#  '10030',
#  '10031',
#  '10032',
#  '10033',
#  '10034',
#  '10035',
#  '10036',
#  '10037',
#  '10038',
#  '10039',
#  '1004',
#  '10040',
#  '10041',
#  '10042',
#  '10043',
#  '10044',
#  '10045',
#  '10046',
#  '10047',
#  '10048',
#  '10049',
#  '1005',
#  '10050',
#  '10051',
#  '10052',
#  '10053',
#  '10054',
#  '10055',
#  '10056',
#  '10057',
#  '10058',
#  '10059',
#  '1006',
#  '10060',
#  '10061',
#  '10062',
#  '10063',
#  '10064',
#  '10065',
#  '10066',
#  '10067',
#  '10068',
#  '10069',
#  '1007',
#  '10070',
#  '10071',
#  '10072',
# ...

# %% [markdown]
# # Remove augmented spectrograms

# %%
import os
train_specs = '/home/giacomoschiavo/segments/dataset/train_specs'
target_path = '/home/giacomoschiavo/segments/dataset/train_specs_removed'
os.makedirs(target_path, exist_ok=True)
for species in os.listdir(train_specs):
    for audio in os.listdir(os.path.join(train_specs, species)):
        if 'specaug' in audio:
            os.makedirs(os.path.join(target_path, species), exist_ok=True)
            os.rename(
                os.path.join(train_specs, species, audio),
                os.path.join(target_path, species, audio),
            )
