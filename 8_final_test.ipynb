# %% [markdown]
# # Final Test Showdown
# Testing on segments files in Bird_tags_Test.mat

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import numpy as np
import json
import torch.nn as nn
import os
import utils

# %%
# sudo modprobe nvidia_uvm
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
DATASET_NAME = "DATASET_CNN"
MODEL_NAME = 'DeeperCNN'

# %%
DATASET_PATH = f'../segments/{DATASET_NAME}'
FINAL_TEST_PATH = f"{DATASET_PATH}/final_test"
TEST_PATH = f"{DATASET_PATH}/test"
TRAIN_PATH = f"{DATASET_PATH}/train"
MODEL_PATH = f'./models/{MODEL_NAME}'

# %% [markdown]
# # Load the model

# %%
with open(f"utils/{DATASET_NAME}/dataset_config.json") as f:
    dataset_config = json.load(f)

# %%
def create_dataset_config(dataset_name):
    # per ora dataset_config_1 contiene anche final_test
    # tengo momentaneamente cosi poi sarebbe da cambiare
    saving_path = f"utils/{dataset_name}/dataset_config.json"
    if os.path.exists(saving_path):
        print("Dataset config already created!")
        with open(saving_path) as f:
            return json.load(f)

    mappings = utils.get_mappings(TEST_PATH)
    samples = utils.collect_samples(TRAIN_PATH, TEST_PATH, FINAL_TEST_PATH, mappings)

    dataset_config = {
        "mappings": mappings,
        "samples": samples
    }
    with open(saving_path, "w") as f:
        json.dump(dataset_config, f)
    print("Saved new dataset config")
    return dataset_config

# %%
dataset_config = create_dataset_config(DATASET_NAME)
# Out:
# Dataset config already created!

# %%
mappings = dataset_config["mappings"]

# %%
model_class = utils.load_model_class(MODEL_NAME)
model = model_class(len(mappings))
model.to(device)
saving_path = f'models/{MODEL_NAME}/checkpoint.pth'
checkpoint = torch.load(saving_path)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Specs generation

# %%
SPECS_FINAL_TEST_PATH = f"{DATASET_PATH}/final_test_specs"
os.makedirs(SPECS_FINAL_TEST_PATH, exist_ok=True)
utils.specs_generation(FINAL_TEST_PATH, SPECS_FINAL_TEST_PATH, dataset_config['mappings'])
# Out:
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch

# %% [markdown]
# # Custom Thresholds Creation

# %%
from collections import defaultdict
from sklearn.metrics import f1_score

def calculate_conf_scores(valid_loader, model, mappings):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    model.to(device)
    
    conf_scores = defaultdict(list)

    with torch.no_grad():
        for mel_spec, _, file_path in valid_loader:
            mel_spec = mel_spec.to(device)

            # Estraggo la specie corretta dal path
            correct_species = file_path[0].split("/")[-2]
            outputs = model(mel_spec)
            probs = torch.sigmoid(outputs)[0].cpu().numpy()

            for i, prob in enumerate(probs):
                species_name = list(mappings.keys())[i]
                is_correct = species_name == correct_species
                conf_scores[species_name].append((prob, is_correct))

    return conf_scores

# %%
def compute_best_thresholds(conf_scores, num_thresholds=100, min_thresh=0.05, max_thresh=0.95):
    thresholds = {}

    for species, values in conf_scores.items():
        probs, truths = zip(*values)
        probs = np.array(probs)
        truths = np.array(truths).astype(int)

        best_thresh = 0.5
        best_f1 = 0.0

        for thresh in np.linspace(min_thresh, max_thresh, num_thresholds):
            preds = (probs >= thresh).astype(int)
            f1 = f1_score(truths, preds, zero_division=0)
            if f1 > best_f1:
                best_f1 = f1
                best_thresh = thresh

        thresholds[species] = best_thresh
        print(f"📊 {species} -> {best_thresh:.3f}, F1-score: {best_f1:.3f}")

    return thresholds

# %%
def compute_distribution_based_thresholds(conf_scores, min_thresh=0.05, max_thresh=0.95):
    thresholds = {}

    for species, values in conf_scores.items():
        probs, truths = zip(*values)
        probs = np.array(probs)
        truths = np.array(truths).astype(int)

        correct_probs = np.array([p for p, t in zip(probs, truths) if t == 1])

        if len(correct_probs) == 0:
            thresholds[species] = 0.5  # fallback
            print(f"⚠️ Specie: {species}, nessuna predizione corretta trovata. Soglia fallback: 0.5")
            continue

        mean_conf = np.mean(probs)
        std_conf = np.std(probs)
        threshold = np.clip(mean_conf - 2 * std_conf, min_thresh, max_thresh)

        thresholds[species] = threshold
        print(f"📊 {species} -> {threshold:.3f}, (mean={mean_conf:.3f}, std={std_conf}), samples: {len(correct_probs)}")

    return thresholds

# %%
valid_loader = utils.get_dataloader(dataset_config, split="valid", batch_size=1)
conf_scores = calculate_conf_scores(valid_loader, model, dataset_config["mappings"])
best_thresholds = compute_best_thresholds(conf_scores)
# best_thresholds = compute_distribution_based_thresholds(conf_scores)
# Out:
# 📊 Regulus ignicapilla_Common Firecrest -> 0.395, F1-score: 0.629
# 📊 Sylvia atricapilla_Eurasian Blackcap -> 0.768, F1-score: 0.780
# 📊 Fringilla coelebs_Common Chaffinch -> 0.623, F1-score: 0.588
# 📊 Troglodytes troglodytes_Eurasian Wren -> 0.232, F1-score: 0.664
# 📊 Muscicapa striata_Spotted Flycatcher -> 0.350, F1-score: 0.840
# 📊 Glaucidium passerinum_Eurasian Pygmy-Owl -> 0.377, F1-score: 0.800
# 📊 Pyrrhula pyrrhula_Eurasian Bullfinch -> 0.659, F1-score: 0.400
# 📊 Periparus ater_Coal Tit -> 0.386, F1-score: 0.702
# 📊 Lophophanes cristatus_Crested Tit -> 0.105, F1-score: 0.608
# 📊 Regulus regulus_Goldcrest -> 0.895, F1-score: 0.854
# 📊 Turdus merula_Eurasian Blackbird -> 0.732, F1-score: 0.746
# 📊 Certhia familiaris_Eurasian Treecreeper -> 0.614, F1-score: 0.638
# 📊 Erithacus rubecula_European Robin -> 0.595, F1-score: 0.690
# 📊 Turdus philomelos_Song Thrush -> 0.877, F1-score: 0.512
# 📊 Loxia curvirostra_Common Crossbill -> 0.050, F1-score: 0.963
# 📊 Dendrocopos major_Great Spotted Woodpecker -> 0.186, F1-score: 0.752
# 📊 Dryocopus martius_Black Woodpecker -> 0.605, F1-score: 0.786

# %% [markdown]
# # Test Model

# %%
from sklearn.metrics import average_precision_score, precision_recall_fscore_support

def compute_samplewise_mAP(y_true, y_probs):
    """
    Calcola la sample-wise mAP (media delle AP per ogni sample).
    """
    ap_per_sample = []
    for i in range(y_true.shape[0]):
        if np.sum(y_true[i]) == 0:
            continue  # Evita sample senza label positive
        ap = average_precision_score(y_true[i], y_probs[i])
        ap_per_sample.append(ap)
    return np.mean(ap_per_sample)

def compute_classwise_mAP(y_true, y_probs):
    """
    Calcola la class-wise mAP (media delle AP per ogni classe).
    """
    ap_per_class = []
    for i in range(y_true.shape[1]):
        if np.sum(y_true[:, i]) == 0:
            continue  # Evita classi mai presenti
        ap = average_precision_score(y_true[:, i], y_probs[:, i])
        ap_per_class.append(ap)
    return np.mean(ap_per_class)

def compute_f05(y_true, y_pred):
    _, _, f05, _ = precision_recall_fscore_support(
        y_true, y_pred, beta=0.5, average='macro', zero_division=0
    )
    return f05

# %%
inverse_mappings = {value: key for key, value in mappings.items()}

# %%
import numpy as np
from sklearn.metrics import classification_report
import csv
import os

def test_model(model, dataset_config, batch_size=100, thresholds=0.5):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"\n🧬 Advanced testing on: {device}")
    test_pred_segments = {}

    test_loader = utils.get_dataloader(dataset_config, split="final_test", batch_size=batch_size, shuffle=False)
    model.eval()
    criterion = nn.BCEWithLogitsLoss()
    class_names = list(dataset_config['mappings'].keys())
    total_loss = 0.0
    all_preds = []
    all_probs = []
    all_labels = []

    use_custom_threshold = isinstance(thresholds, dict)

    with torch.no_grad():
        for mel_spec, labels, file_path in test_loader:

            # basename = os.path.splitext(file_path[0].split("/")[-1])[0]
            # date, time, segm1, segm2 = basename.split("_")
            # audio_name = "_".join([date, time]) + ".WAV"
            # segm = "_".join([segm1, segm2])
            # test_pred_segments.setdefault(audio_name, {})
            # test_pred_segments[audio_name].setdefault(segm, {})

            mel_spec = mel_spec.to(device)
            labels = labels.to(device)

            outputs = model(mel_spec)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            probs = torch.sigmoid(outputs)

            if use_custom_threshold:
                batch_preds = torch.zeros_like(probs)
                for i, class_name in enumerate(class_names):
                    thresh = thresholds.get(class_name, 0.5)
                    batch_preds[:, i] = (probs[:, i] > thresh).float()
            else:
                batch_preds = (probs > thresholds).float()

            # correct_probs = probs * batch_preds
            # conf_scores = {
            #     inverse_mappings[i]: correct_probs[0, i].item()
            #     for i in range(correct_probs.size(1))
            #     if correct_probs[0, i].item() != 0
            # }
            # test_pred_segments[audio_name][segm].update(conf_scores)

            all_probs.append(probs.cpu())
            all_preds.append(batch_preds.cpu())
            all_labels.append(labels.cpu())

    avg_loss = total_loss / len(test_loader)
    all_probs = torch.cat(all_probs).numpy()
    all_preds = torch.cat(all_preds).numpy()
    all_labels = torch.cat(all_labels).numpy()

    samplewise_map = compute_samplewise_mAP(all_labels, all_probs)  # chiamata mAP
    classwise_map = compute_classwise_mAP(all_labels, all_probs)    # chiamata cmAP
    f05_score = compute_f05(all_labels, all_preds)

    with open(f"models/{MODEL_NAME}/metrics_output.csv", mode="w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Metric", "Value"])
        writer.writerow(["mAP (sample-wise)", samplewise_map])
        writer.writerow(["cmAP (class-wise)", classwise_map])
        writer.writerow(["F0.5 Score", f05_score])

    # 👇 Report
    clf_report = classification_report(all_labels, all_preds, target_names=class_names, output_dict=True, zero_division=0)
    return avg_loss, clf_report, samplewise_map, classwise_map, f05_score, test_pred_segments

# %%
a = [sample for sample in dataset_config["samples"] if sample["split"] == "final_test"]
a
# Out:
# [{'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_591_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_438_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_393_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_585_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_223_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_594_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_564_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_246_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_567_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_396_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_492_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_376_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_565_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_400_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_391_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_259_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_579_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_232_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_550_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_265_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_283_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_541_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_408_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_364_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_355_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_402_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_207_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_408_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_256_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_418_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_564_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_403_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_328_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_297_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_427_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_381_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_562_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_375_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_231_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_276_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_322_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_226_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_202_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_549_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_255_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_196_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_274_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_295_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_546_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_559_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_439_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_228_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_574_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_373_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_463_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_588_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_429_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_273_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_538_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_532_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_379_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_372_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_547_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_220_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_249_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_454_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_576_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_592_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_324_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_334_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_258_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_414_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_406_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_568_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_187_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_336_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_286_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_340_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_330_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_417_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_555_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_271_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_540_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_348_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_538_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_247_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_357_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_361_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_219_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_441_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_285_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_342_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_535_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_531_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_444_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_462_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_282_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_225_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_475_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_541_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_235_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_381_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_382_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_573_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_403_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_205_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_370_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_337_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_316_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_376_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_234_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_553_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_195_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_391_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_349_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_319_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_529_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_325_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_378_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_544_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_400_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_279_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_327_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_390_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_318_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_534_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_390_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_264_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_558_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_270_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_537_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_562_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_543_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_405_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_189_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_474_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_451_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_540_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_577_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_415_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_190000_333_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_537_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_556_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_315_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_388_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_406_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_208_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_436_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_561_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_402_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_268_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_409_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_229_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_384_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_321_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_447_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_583_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_445_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_261_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_493_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_534_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_477_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_204_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_453_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_394_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_589_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_535_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_570_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_280_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_313_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_363_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_399_0.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Muscicapa striata_Spotted Flycatcher/20190601_090000_277_5.wav',
#   'split': 'final_test',
#   'labels': [4]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_517_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_499_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_472_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_474_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_540_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_505_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_541_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_520_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_523_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_492_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_504_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_522_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_495_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_519_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_475_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_471_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_498_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_496_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_469_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_502_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_538_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_493_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_487_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_465_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_490_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_466_5.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_501_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_477_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Periparus ater_Coal Tit/20190601_050000_486_0.wav',
#   'split': 'final_test',
#   'labels': [7]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_94_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_93_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_102_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_90_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_91_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_126_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_129_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_100_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_127_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_114_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_99_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_117_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_96_0.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_112_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_115_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Regulus regulus_Goldcrest/20190601_060000_97_5.wav',
#   'split': 'final_test',
#   'labels': [9]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_45_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_192_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_519_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_78_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_196_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_123_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_525_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_130_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_43_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_94_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_39_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_189_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_514_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_558_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_9_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_93_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_120_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_190_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_516_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_583_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_109_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_517_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_559_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_546_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_030000_4_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_160000_453_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_42_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_129_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_190_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_118_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_558_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_550_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_153_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_547_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_40_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_10_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_148_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_79_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_429_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_175_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_432_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_556_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_61_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_135_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_526_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_549_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_160000_484_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_40_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_111_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_160000_456_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_160000_483_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_43_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_426_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_171_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_207_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_586_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_174_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_192_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_204_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_030000_3_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_160000_459_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_172_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_37_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_430_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_523_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_205_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_585_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_169_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_582_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_160000_481_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_13_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_522_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_520_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_195_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_040000_553_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_202_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_168_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_193_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_121_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_561_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_99_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_75_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_63_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_080000_427_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_170000_562_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_060000_132_0.wav',
#   'split': 'final_test',
#   'labels': [3]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Troglodytes troglodytes_Eurasian Wren/20190601_150000_64_5.wav',
#   'split': 'final_test',
#   'labels': [3]},
# ...
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_391_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_136_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_580_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_63_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_030000_75_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_561_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_99_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_142_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_28_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_583_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_147_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_214_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_94_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_480_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_408_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_435_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_90_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_402_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_135_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_529_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_567_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_531_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_102_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_492_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_438_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_157_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_138_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_585_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_190_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_418_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_564_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_75_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_550_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_585_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_571_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_388_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_580_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_42_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_15_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_516_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_514_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_582_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_117_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_496_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_67_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_136_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_105_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_69_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_405_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_541_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_225_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_487_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_42_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_267_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_544_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_537_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_102_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_246_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_570_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_445_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_82_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_153_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_70_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_384_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_54_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_520_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_534_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_148_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_124_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_88_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_100_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_568_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_36_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_532_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_576_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_145_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_135_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_393_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_24_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_114_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_393_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_141_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_133_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_108_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_40_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_111_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_544_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_523_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_244_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_522_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_37_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_109_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_22_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_52_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_439_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_519_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_61_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_18_0.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_130_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_535_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_060000_565_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  {'file_path': '../segments/DATASET_CNN/final_test/Turdus merula_Eurasian Blackbird/20190601_190000_31_5.wav',
#   'split': 'final_test',
#   'labels': [10]},
#  ...]

# %%
avg_loss, clf_report, samplewise_map, classwise_map, f05_score, test_pred_segments = test_model(model, dataset_config, thresholds=best_thresholds)
# Out:
# 🧬 Advanced testing on: cuda

# %%
print("mAP Score: ", samplewise_map)
print("mcAP Score: ", classwise_map)
print("F0.5 Score: ", f05_score)
# Out:
# mAP Score:  0.5222335607593631
# mcAP Score:  0.20881649311088749
# F0.5 Score:  0.11856008884873939

# %%
from io import StringIO
import pandas as pd

clf_report_df = pd.read_json(StringIO(json.dumps(clf_report)), orient='index')
clf_report_df
# Out:
#                                             precision    recall  f1-score  \
# Regulus ignicapilla_Common Firecrest         0.441489  0.348739  0.389671
# Sylvia atricapilla_Eurasian Blackcap         0.191702  0.815416  0.310425
# Fringilla coelebs_Common Chaffinch           0.654088  0.452830  0.535163
# Troglodytes troglodytes_Eurasian Wren        0.112245  0.297297  0.162963
# Muscicapa striata_Spotted Flycatcher         0.048193  0.023121  0.031250
# Glaucidium passerinum_Eurasian Pygmy-Owl     0.000000  0.000000  0.000000
# Pyrrhula pyrrhula_Eurasian Bullfinch         0.000000  0.000000  0.000000
# Periparus ater_Coal Tit                      0.000000  0.000000  0.000000
# Lophophanes cristatus_Crested Tit            0.000000  0.000000  0.000000
# Regulus regulus_Goldcrest                    0.333333  0.062500  0.105263
# Turdus merula_Eurasian Blackbird             0.348837  0.095238  0.149626
# Certhia familiaris_Eurasian Treecreeper      0.000000  0.000000  0.000000
# Erithacus rubecula_European Robin            0.566038  0.053957  0.098522
# Turdus philomelos_Song Thrush                0.000000  0.000000  0.000000
# Loxia curvirostra_Common Crossbill           0.000000  0.000000  0.000000
# Dendrocopos major_Great Spotted Woodpecker   0.000000  0.000000  0.000000
# Dryocopus martius_Black Woodpecker           0.000000  0.000000  0.000000
# micro avg                                    0.300847  0.361269  0.328301
# macro avg                                    0.158584  0.126418  0.104875
# weighted avg                                 0.464426  0.361269  0.332333
# samples avg                                  0.256161  0.361269  0.289125
#
#                                             support
# Regulus ignicapilla_Common Firecrest            238
# Sylvia atricapilla_Eurasian Blackcap            493
# Fringilla coelebs_Common Chaffinch             1378
# Troglodytes troglodytes_Eurasian Wren           111
# Muscicapa striata_Spotted Flycatcher            173
# Glaucidium passerinum_Eurasian Pygmy-Owl          0
# Pyrrhula pyrrhula_Eurasian Bullfinch              0
# Periparus ater_Coal Tit                          29
# Lophophanes cristatus_Crested Tit                16
# Regulus regulus_Goldcrest                        16
# Turdus merula_Eurasian Blackbird                315
# Certhia familiaris_Eurasian Treecreeper           3
# Erithacus rubecula_European Robin               556
# Turdus philomelos_Song Thrush                     0
# Loxia curvirostra_Common Crossbill               13
# Dendrocopos major_Great Spotted Woodpecker        0
# Dryocopus martius_Black Woodpecker                0
# micro avg                                      3341
# macro avg                                      3341
# weighted avg                                   3341
# samples avg                                    3341

# %%
with open(f'{MODEL_PATH}/classification_report_test.json', 'w') as f:
    json.dump(clf_report, f)
