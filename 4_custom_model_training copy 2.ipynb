# %% [markdown]
# # Dataset Information Creation
# Create a json file to represent the files inside the dataset

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import numpy as np
import json
import torch.nn as nn
import os
from birdlib import utils

# %%
# sudo modprobe nvidia_uvm
torch.cuda.is_available()
# Out:
# True

# %%
DATASET_NAME = "dataset"
MODEL_NAME = 'VanillaCNN'
DATASET_VAR = 'augm_final_4'

# %%
DATASET_PATH = f'../segments/{DATASET_NAME}'
TRAIN_PATH = f"{DATASET_PATH}/train"
VALID_PATH = f"{DATASET_PATH}/valid"
TEST_PATH = f"{DATASET_PATH}/test"
MODEL_PATH = f'./models/{MODEL_NAME}'

# %% [markdown]
# # Create Dataset Config

# %%
def create_dataset_config(dataset_name, config_file_name='dataset_config.json'):
    saving_path = f"utils/{dataset_name}/{config_file_name}"
    if os.path.exists(saving_path):
        print("Dataset config already created!")
        with open(saving_path) as f:
            return json.load(f)

    mappings = utils.get_mappings(TRAIN_PATH)
    samples = utils.collect_samples(TRAIN_PATH, VALID_PATH, TEST_PATH, mappings)

    dataset_config = {
        "mappings": mappings,
        "samples": samples
    }
    with open(saving_path, "w") as f:
        json.dump(dataset_config, f)
    print("Saved new dataset config")
    return dataset_config

# %%
dataset_config = create_dataset_config(DATASET_NAME, f'dataset_config_{DATASET_VAR}.json')
mappings = dataset_config["mappings"]
# Out:
# Dataset config already created!

# %% [markdown]
# ## Load the model

# %%
model_class = utils.load_model_class(MODEL_NAME)
model = model_class(len(mappings))

# %% [markdown]
# # Spectograms Creation

# %%
SPECS_TRAIN_PATH = f"{DATASET_PATH}/train_specs"
SPECS_VALID_PATH = f"{DATASET_PATH}/valid_specs"
SPECS_TEST_PATH = f"{DATASET_PATH}/test_specs"
os.makedirs(SPECS_TRAIN_PATH, exist_ok=True)
os.makedirs(SPECS_VALID_PATH, exist_ok=True)
os.makedirs(SPECS_TEST_PATH, exist_ok=True)
utils.specs_generation(TRAIN_PATH, SPECS_TRAIN_PATH, dataset_config['mappings'])
utils.specs_generation(VALID_PATH, SPECS_VALID_PATH, dataset_config['mappings'])
utils.specs_generation(TEST_PATH, SPECS_TEST_PATH, dataset_config['mappings'])
# Out:
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# '✅ Spettrogrammi generati e salvati.'

# %% [markdown]
# # Model

# %%
def train_model(dataset_config, model, model_name, dataset_var, epochs=10, batch_size=100, lr=1e-5, patience=3, early_stop_patience=10, early_stop_tollerance=1e-5, print_freq=100, load_weights=False, checkpoint_name='checkpoint.pth'):
    history_loss = []
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training {model_name} on: {device}")

    model.to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=patience, threshold=1e-4
    )
    history_loss = []
    best_loss = float("inf")
    starting_epoch = 0

    saving_path = f'models/{model_name}/{dataset_var}/checkpoint.pth'
    if load_weights:
        if not os.path.exists(saving_path):
            print("No weights found!")
            return None
        checkpoint = torch.load(saving_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        history_loss = checkpoint['history_loss']
        best_loss = checkpoint['avg_loss']
        starting_epoch = len(history_loss)
        epochs += starting_epoch
        print(f"Model Loaded!")
    print(f"Starting from epoch {starting_epoch} for {epochs} epochs")
        
    print("Loading training data...")
    train_loader = utils.get_dataloader(dataset_config, split="train", batch_size=batch_size)
    valid_loader = utils.get_dataloader(dataset_config, split="valid", batch_size=batch_size)
    print("Loaded!")
    
    model.train()
    early_stop_counter = 0
    for epoch in range(epochs):
        epoch += starting_epoch
        model.train()
        running_loss = 0.0
        print(f"\n🎯 Starting epoch {epoch + 1}/{epochs}")

        for batch_index, (mel_spec, labels, _) in enumerate(train_loader):
            mel_spec = mel_spec.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(mel_spec)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch = len(history_loss)

            running_loss += loss.item()
            
            if batch_index % print_freq == 0:
                print('Epoch: [{0}][{1}/{2}], Loss: {loss:.5f}'.format(epoch, batch_index, len(train_loader), loss=loss))

        train_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch + 1} - Loss: {train_loss:.5f}")

        # Validation phase
        print("Validating...")
        model.eval()
        with torch.no_grad():
            valid_loss = 0.0
            for mel_spec, labels, _ in valid_loader:
                mel_spec = mel_spec.to(device)
                labels = labels.to(device)
                outputs = model(mel_spec)
                loss = criterion(outputs, labels)
                valid_loss += loss.item()

            valid_loss /= len(valid_loader)
            print(f"Validation Loss: {valid_loss:.5f}")
        
        # weighted average loss (valid loss * 0.2 + train loss * 0.8)
        avg_loss = 0.8 * (running_loss / len(train_loader)) + 0.2 * valid_loss
        history_loss.append(avg_loss)
        scheduler.step(valid_loss)
        
        np.save(f'models/{model_name}/{dataset_var}/history_loss.npy', history_loss)
        if valid_loss < best_loss - early_stop_tollerance:
            best_loss = valid_loss
            early_stop_counter = 0
            print(f"💾 Saving improved model at epoch {epoch+1} with valid_loss={valid_loss:.5f}")
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'avg_loss': avg_loss,
                'history_loss': history_loss
            }, saving_path)
        else:
            early_stop_counter += 1
            print(f"🛑 No improvement — early stop counter: {early_stop_counter}/{early_stop_patience}")

        print(f"🔁 Epoch {epoch+1} completed - Avg loss: {avg_loss:.7f} - LR: {optimizer.param_groups[0]['lr']:.1e}")

        if early_stop_counter >= early_stop_patience:
            print(f"\n🚨 Early stopping triggered after {early_stop_patience} epochs without improvement.")
            break

    print("✅ Training completed")


    return model

# %%
os.makedirs(f'models/{MODEL_NAME}/{DATASET_VAR}', exist_ok=True)
model = train_model(dataset_config, model, model_name=MODEL_NAME, dataset_var=DATASET_VAR, epochs=200, batch_size=64, lr=1e-5, load_weights=False)
# Out:
# Training VanillaCNN on: cuda
# Starting from epoch 0 for 200 epochs
# Loading training data...
# Loaded!
#
# 🎯 Starting epoch 1/200
# Epoch: [0][0/379], Loss: 0.69100
# Epoch: [0][100/379], Loss: 0.19772
# Epoch: [0][200/379], Loss: 0.17350
# Epoch: [0][300/379], Loss: 0.21042
# Epoch 1 - Loss: 0.23211
# Validating...
# Validation Loss: 0.20536
# 💾 Saving improved model at epoch 1 with valid_loss=0.20536
# 🔁 Epoch 1 completed - Avg loss: 0.2267632 - LR: 1.0e-05
#
# 🎯 Starting epoch 2/200
# Epoch: [1][0/379], Loss: 0.17832
# Epoch: [1][100/379], Loss: 0.18081
# Epoch: [1][200/379], Loss: 0.17640
# Epoch: [1][300/379], Loss: 0.16574
# Epoch 2 - Loss: 0.18044
# Validating...
# Validation Loss: 0.19159
# 💾 Saving improved model at epoch 2 with valid_loss=0.19159
# 🔁 Epoch 2 completed - Avg loss: 0.1826660 - LR: 1.0e-05
#
# 🎯 Starting epoch 3/200
# Epoch: [2][0/379], Loss: 0.17413
# Epoch: [2][100/379], Loss: 0.17291
# Epoch: [2][200/379], Loss: 0.16212
# Epoch: [2][300/379], Loss: 0.17717
# Epoch 3 - Loss: 0.16823
# Validating...
# Validation Loss: 0.18782
# 💾 Saving improved model at epoch 3 with valid_loss=0.18782
# 🔁 Epoch 3 completed - Avg loss: 0.1721519 - LR: 1.0e-05
#
# 🎯 Starting epoch 4/200
# Epoch: [3][0/379], Loss: 0.16251
# Epoch: [3][100/379], Loss: 0.15373
# Epoch: [3][200/379], Loss: 0.14663
# Epoch: [3][300/379], Loss: 0.16878
# Epoch 4 - Loss: 0.16141
# Validating...
# Validation Loss: 0.18553
# 💾 Saving improved model at epoch 4 with valid_loss=0.18553
# 🔁 Epoch 4 completed - Avg loss: 0.1662340 - LR: 1.0e-05
#
# 🎯 Starting epoch 5/200
# Epoch: [4][0/379], Loss: 0.13312
# Epoch: [4][100/379], Loss: 0.15211
# Epoch: [4][200/379], Loss: 0.14963
# Epoch: [4][300/379], Loss: 0.16279
# Epoch 5 - Loss: 0.15592
# Validating...
# Validation Loss: 0.18158
# 💾 Saving improved model at epoch 5 with valid_loss=0.18158
# 🔁 Epoch 5 completed - Avg loss: 0.1610503 - LR: 1.0e-05
#
# 🎯 Starting epoch 6/200
# Epoch: [5][0/379], Loss: 0.14425
# Epoch: [5][100/379], Loss: 0.15042
# Epoch: [5][200/379], Loss: 0.16082
# Epoch: [5][300/379], Loss: 0.15115
# Epoch 6 - Loss: 0.15149
# Validating...
# Validation Loss: 0.17685
# 💾 Saving improved model at epoch 6 with valid_loss=0.17685
# 🔁 Epoch 6 completed - Avg loss: 0.1565616 - LR: 1.0e-05
#
# 🎯 Starting epoch 7/200
# Epoch: [6][0/379], Loss: 0.15260
# Epoch: [6][100/379], Loss: 0.16951
# Epoch: [6][200/379], Loss: 0.14501
# Epoch: [6][300/379], Loss: 0.14895
# Epoch 7 - Loss: 0.14763
# Validating...
# Validation Loss: 0.17661
# 💾 Saving improved model at epoch 7 with valid_loss=0.17661
# 🔁 Epoch 7 completed - Avg loss: 0.1534226 - LR: 1.0e-05
#
# 🎯 Starting epoch 8/200
# Epoch: [7][0/379], Loss: 0.16101
# Epoch: [7][100/379], Loss: 0.14001
# Epoch: [7][200/379], Loss: 0.14229
# Epoch: [7][300/379], Loss: 0.14483
# Epoch 8 - Loss: 0.14444
# Validating...
# Validation Loss: 0.17417
# 💾 Saving improved model at epoch 8 with valid_loss=0.17417
# 🔁 Epoch 8 completed - Avg loss: 0.1503863 - LR: 1.0e-05
#
# 🎯 Starting epoch 9/200
# Epoch: [8][0/379], Loss: 0.14333
# Epoch: [8][100/379], Loss: 0.15759
# Epoch: [8][200/379], Loss: 0.14929
# Epoch: [8][300/379], Loss: 0.15323
# Epoch 9 - Loss: 0.14156
# Validating...
# Validation Loss: 0.16902
# 💾 Saving improved model at epoch 9 with valid_loss=0.16902
# 🔁 Epoch 9 completed - Avg loss: 0.1470480 - LR: 1.0e-05
#
# 🎯 Starting epoch 10/200
# Epoch: [9][0/379], Loss: 0.13126
# Epoch: [9][100/379], Loss: 0.13358
# Epoch: [9][200/379], Loss: 0.14252
# Epoch: [9][300/379], Loss: 0.17073
# Epoch 10 - Loss: 0.13912
# Validating...
# Validation Loss: 0.16806
# 💾 Saving improved model at epoch 10 with valid_loss=0.16806
# 🔁 Epoch 10 completed - Avg loss: 0.1449105 - LR: 1.0e-05
#
# 🎯 Starting epoch 11/200
# Epoch: [10][0/379], Loss: 0.10949
# Epoch: [10][100/379], Loss: 0.14628
# Epoch: [10][200/379], Loss: 0.14324
# Epoch: [10][300/379], Loss: 0.11472
# Epoch 11 - Loss: 0.13681
# Validating...
# Validation Loss: 0.16539
# 💾 Saving improved model at epoch 11 with valid_loss=0.16539
# 🔁 Epoch 11 completed - Avg loss: 0.1425226 - LR: 1.0e-05
#
# 🎯 Starting epoch 12/200
# Epoch: [11][0/379], Loss: 0.13331
# Epoch: [11][100/379], Loss: 0.11838
# Epoch: [11][200/379], Loss: 0.14018
# Epoch: [11][300/379], Loss: 0.11416
# Epoch 12 - Loss: 0.13481
# Validating...
# Validation Loss: 0.16352
# 💾 Saving improved model at epoch 12 with valid_loss=0.16352
# 🔁 Epoch 12 completed - Avg loss: 0.1405494 - LR: 1.0e-05
#
# 🎯 Starting epoch 13/200
# Epoch: [12][0/379], Loss: 0.12675
# Epoch: [12][100/379], Loss: 0.11927
# Epoch: [12][200/379], Loss: 0.13196
# Epoch: [12][300/379], Loss: 0.12344
# Epoch 13 - Loss: 0.13280
# Validating...
# Validation Loss: 0.16355
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 13 completed - Avg loss: 0.1389526 - LR: 1.0e-05
#
# 🎯 Starting epoch 14/200
# Epoch: [13][0/379], Loss: 0.12062
# Epoch: [13][100/379], Loss: 0.14308
# Epoch: [13][200/379], Loss: 0.14015
# Epoch: [13][300/379], Loss: 0.12528
# Epoch 14 - Loss: 0.13097
# Validating...
# Validation Loss: 0.16095
# 💾 Saving improved model at epoch 14 with valid_loss=0.16095
# 🔁 Epoch 14 completed - Avg loss: 0.1369649 - LR: 1.0e-05
#
# 🎯 Starting epoch 15/200
# Epoch: [14][0/379], Loss: 0.13624
# Epoch: [14][100/379], Loss: 0.15165
# Epoch: [14][200/379], Loss: 0.12027
# Epoch: [14][300/379], Loss: 0.12027
# Epoch 15 - Loss: 0.12924
# Validating...
# Validation Loss: 0.15919
# 💾 Saving improved model at epoch 15 with valid_loss=0.15919
# 🔁 Epoch 15 completed - Avg loss: 0.1352324 - LR: 1.0e-05
#
# 🎯 Starting epoch 16/200
# Epoch: [15][0/379], Loss: 0.12414
# Epoch: [15][100/379], Loss: 0.14323
# Epoch: [15][200/379], Loss: 0.12618
# Epoch: [15][300/379], Loss: 0.10709
# Epoch 16 - Loss: 0.12775
# Validating...
# Validation Loss: 0.15901
# 💾 Saving improved model at epoch 16 with valid_loss=0.15901
# 🔁 Epoch 16 completed - Avg loss: 0.1340035 - LR: 1.0e-05
#
# 🎯 Starting epoch 17/200
# Epoch: [16][0/379], Loss: 0.14201
# Epoch: [16][100/379], Loss: 0.12361
# Epoch: [16][200/379], Loss: 0.12923
# Epoch: [16][300/379], Loss: 0.11536
# Epoch 17 - Loss: 0.12615
# Validating...
# Validation Loss: 0.15792
# 💾 Saving improved model at epoch 17 with valid_loss=0.15792
# 🔁 Epoch 17 completed - Avg loss: 0.1325064 - LR: 1.0e-05
#
# 🎯 Starting epoch 18/200
# Epoch: [17][0/379], Loss: 0.11005
# Epoch: [17][100/379], Loss: 0.13228
# Epoch: [17][200/379], Loss: 0.10637
# Epoch: [17][300/379], Loss: 0.12939
# Epoch 18 - Loss: 0.12473
# Validating...
# Validation Loss: 0.15784
# 💾 Saving improved model at epoch 18 with valid_loss=0.15784
# 🔁 Epoch 18 completed - Avg loss: 0.1313536 - LR: 1.0e-05
#
# 🎯 Starting epoch 19/200
# Epoch: [18][0/379], Loss: 0.10501
# Epoch: [18][100/379], Loss: 0.14033
# Epoch: [18][200/379], Loss: 0.11265
# Epoch: [18][300/379], Loss: 0.10813
# Epoch 19 - Loss: 0.12333
# Validating...
# Validation Loss: 0.15469
# 💾 Saving improved model at epoch 19 with valid_loss=0.15469
# 🔁 Epoch 19 completed - Avg loss: 0.1295980 - LR: 1.0e-05
#
# 🎯 Starting epoch 20/200
# Epoch: [19][0/379], Loss: 0.14113
# Epoch: [19][100/379], Loss: 0.11115
# Epoch: [19][200/379], Loss: 0.11638
# Epoch: [19][300/379], Loss: 0.12092
# Epoch 20 - Loss: 0.12193
# Validating...
# Validation Loss: 0.15370
# 💾 Saving improved model at epoch 20 with valid_loss=0.15370
# 🔁 Epoch 20 completed - Avg loss: 0.1282860 - LR: 1.0e-05
#
# 🎯 Starting epoch 21/200
# Epoch: [20][0/379], Loss: 0.11757
# Epoch: [20][100/379], Loss: 0.13618
# Epoch: [20][200/379], Loss: 0.10811
# Epoch: [20][300/379], Loss: 0.12511
# Epoch 21 - Loss: 0.12074
# Validating...
# Validation Loss: 0.15448
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 21 completed - Avg loss: 0.1274869 - LR: 1.0e-05
#
# 🎯 Starting epoch 22/200
# Epoch: [21][0/379], Loss: 0.13308
# Epoch: [21][100/379], Loss: 0.13149
# Epoch: [21][200/379], Loss: 0.10753
# Epoch: [21][300/379], Loss: 0.11203
# Epoch 22 - Loss: 0.11950
# Validating...
# Validation Loss: 0.15192
# 💾 Saving improved model at epoch 22 with valid_loss=0.15192
# 🔁 Epoch 22 completed - Avg loss: 0.1259886 - LR: 1.0e-05
#
# 🎯 Starting epoch 23/200
# Epoch: [22][0/379], Loss: 0.11345
# Epoch: [22][100/379], Loss: 0.12406
# Epoch: [22][200/379], Loss: 0.12578
# Epoch: [22][300/379], Loss: 0.12762
# Epoch 23 - Loss: 0.11832
# Validating...
# Validation Loss: 0.15150
# 💾 Saving improved model at epoch 23 with valid_loss=0.15150
# 🔁 Epoch 23 completed - Avg loss: 0.1249599 - LR: 1.0e-05
#
# 🎯 Starting epoch 24/200
# Epoch: [23][0/379], Loss: 0.12549
# Epoch: [23][100/379], Loss: 0.10794
# Epoch: [23][200/379], Loss: 0.10296
# Epoch: [23][300/379], Loss: 0.11969
# Epoch 24 - Loss: 0.11722
# Validating...
# Validation Loss: 0.15250
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 24 completed - Avg loss: 0.1242766 - LR: 1.0e-05
#
# 🎯 Starting epoch 25/200
# Epoch: [24][0/379], Loss: 0.11784
# Epoch: [24][100/379], Loss: 0.11490
# Epoch: [24][200/379], Loss: 0.10456
# Epoch: [24][300/379], Loss: 0.11393
# Epoch 25 - Loss: 0.11615
# Validating...
# Validation Loss: 0.15036
# 💾 Saving improved model at epoch 25 with valid_loss=0.15036
# 🔁 Epoch 25 completed - Avg loss: 0.1229948 - LR: 1.0e-05
#
# 🎯 Starting epoch 26/200
# Epoch: [25][0/379], Loss: 0.11546
# Epoch: [25][100/379], Loss: 0.12094
# Epoch: [25][200/379], Loss: 0.13249
# Epoch: [25][300/379], Loss: 0.11600
# Epoch 26 - Loss: 0.11504
# Validating...
# Validation Loss: 0.14934
# 💾 Saving improved model at epoch 26 with valid_loss=0.14934
# 🔁 Epoch 26 completed - Avg loss: 0.1218960 - LR: 1.0e-05
#
# 🎯 Starting epoch 27/200
# Epoch: [26][0/379], Loss: 0.13136
# Epoch: [26][100/379], Loss: 0.11616
# Epoch: [26][200/379], Loss: 0.12406
# Epoch: [26][300/379], Loss: 0.12208
# Epoch 27 - Loss: 0.11410
# Validating...
# Validation Loss: 0.14782
# 💾 Saving improved model at epoch 27 with valid_loss=0.14782
# 🔁 Epoch 27 completed - Avg loss: 0.1208453 - LR: 1.0e-05
#
# 🎯 Starting epoch 28/200
# Epoch: [27][0/379], Loss: 0.12106
# Epoch: [27][100/379], Loss: 0.09711
# Epoch: [27][200/379], Loss: 0.12554
# Epoch: [27][300/379], Loss: 0.10121
# Epoch 28 - Loss: 0.11317
# Validating...
# Validation Loss: 0.14802
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 28 completed - Avg loss: 0.1201412 - LR: 1.0e-05
#
# 🎯 Starting epoch 29/200
# Epoch: [28][0/379], Loss: 0.10739
# Epoch: [28][100/379], Loss: 0.11816
# Epoch: [28][200/379], Loss: 0.10380
# Epoch: [28][300/379], Loss: 0.12048
# Epoch 29 - Loss: 0.11233
# Validating...
# Validation Loss: 0.14887
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 29 completed - Avg loss: 0.1196347 - LR: 1.0e-05
#
# 🎯 Starting epoch 30/200
# Epoch: [29][0/379], Loss: 0.08855
# Epoch: [29][100/379], Loss: 0.10797
# Epoch: [29][200/379], Loss: 0.11436
# Epoch: [29][300/379], Loss: 0.09447
# Epoch 30 - Loss: 0.11137
# Validating...
# Validation Loss: 0.14853
# 🛑 No improvement — early stop counter: 3/10
# 🔁 Epoch 30 completed - Avg loss: 0.1188021 - LR: 1.0e-05
#
# 🎯 Starting epoch 31/200
# Epoch: [30][0/379], Loss: 0.10321
# Epoch: [30][100/379], Loss: 0.11024
# Epoch: [30][200/379], Loss: 0.09887
# Epoch: [30][300/379], Loss: 0.10688
# Epoch 31 - Loss: 0.11062
# Validating...
# Validation Loss: 0.14781
# 🛑 No improvement — early stop counter: 4/10
# 🔁 Epoch 31 completed - Avg loss: 0.1180578 - LR: 5.0e-06
#
# 🎯 Starting epoch 32/200
# Epoch: [31][0/379], Loss: 0.09707
# Epoch: [31][100/379], Loss: 0.10433
# Epoch: [31][200/379], Loss: 0.12421
# Epoch: [31][300/379], Loss: 0.10052
# Epoch 32 - Loss: 0.10921
# Validating...
# Validation Loss: 0.14601
# 💾 Saving improved model at epoch 32 with valid_loss=0.14601
# 🔁 Epoch 32 completed - Avg loss: 0.1165693 - LR: 5.0e-06
#
# 🎯 Starting epoch 33/200
# Epoch: [32][0/379], Loss: 0.10964
# Epoch: [32][100/379], Loss: 0.10208
# Epoch: [32][200/379], Loss: 0.10159
# Epoch: [32][300/379], Loss: 0.11034
# Epoch 33 - Loss: 0.10876
# Validating...
# Validation Loss: 0.14558
# 💾 Saving improved model at epoch 33 with valid_loss=0.14558
# 🔁 Epoch 33 completed - Avg loss: 0.1161205 - LR: 5.0e-06
#
# 🎯 Starting epoch 34/200
# Epoch: [33][0/379], Loss: 0.10225
# Epoch: [33][100/379], Loss: 0.10308
# Epoch: [33][200/379], Loss: 0.09851
# Epoch: [33][300/379], Loss: 0.11946
# Epoch 34 - Loss: 0.10831
# Validating...
# Validation Loss: 0.14593
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 34 completed - Avg loss: 0.1158349 - LR: 5.0e-06
#
# 🎯 Starting epoch 35/200
# Epoch: [34][0/379], Loss: 0.09744
# Epoch: [34][100/379], Loss: 0.10809
# Epoch: [34][200/379], Loss: 0.08861
# Epoch: [34][300/379], Loss: 0.09938
# Epoch 35 - Loss: 0.10798
# Validating...
# Validation Loss: 0.14682
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 35 completed - Avg loss: 0.1157497 - LR: 5.0e-06
#
# 🎯 Starting epoch 36/200
# Epoch: [35][0/379], Loss: 0.09709
# Epoch: [35][100/379], Loss: 0.11430
# Epoch: [35][200/379], Loss: 0.09550
# Epoch: [35][300/379], Loss: 0.08706
# Epoch 36 - Loss: 0.10755
# Validating...
# Validation Loss: 0.14589
# 🛑 No improvement — early stop counter: 3/10
# 🔁 Epoch 36 completed - Avg loss: 0.1152175 - LR: 5.0e-06
#
# 🎯 Starting epoch 37/200
# Epoch: [36][0/379], Loss: 0.09996
# Epoch: [36][100/379], Loss: 0.10604
# Epoch: [36][200/379], Loss: 0.11064
# Epoch: [36][300/379], Loss: 0.10171
# Epoch 37 - Loss: 0.10717
# Validating...
# Validation Loss: 0.14635
# 🛑 No improvement — early stop counter: 4/10
# 🔁 Epoch 37 completed - Avg loss: 0.1150038 - LR: 2.5e-06
#
# 🎯 Starting epoch 38/200
# Epoch: [37][0/379], Loss: 0.11704
# Epoch: [37][100/379], Loss: 0.10651
# Epoch: [37][200/379], Loss: 0.10285
# Epoch: [37][300/379], Loss: 0.10393
# Epoch 38 - Loss: 0.10648
# Validating...
# Validation Loss: 0.14535
# 💾 Saving improved model at epoch 38 with valid_loss=0.14535
# 🔁 Epoch 38 completed - Avg loss: 0.1142571 - LR: 2.5e-06
#
# 🎯 Starting epoch 39/200
# Epoch: [38][0/379], Loss: 0.08929
# Epoch: [38][100/379], Loss: 0.10453
# Epoch: [38][200/379], Loss: 0.10668
# Epoch: [38][300/379], Loss: 0.10456
# Epoch 39 - Loss: 0.10629
# Validating...
# Validation Loss: 0.14577
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 39 completed - Avg loss: 0.1141904 - LR: 2.5e-06
#
# 🎯 Starting epoch 40/200
# Epoch: [39][0/379], Loss: 0.08594
# Epoch: [39][100/379], Loss: 0.09936
# Epoch: [39][200/379], Loss: 0.09537
# Epoch: [39][300/379], Loss: 0.09676
# Epoch 40 - Loss: 0.10606
# Validating...
# Validation Loss: 0.14507
# 💾 Saving improved model at epoch 40 with valid_loss=0.14507
# 🔁 Epoch 40 completed - Avg loss: 0.1138620 - LR: 2.5e-06
#
# 🎯 Starting epoch 41/200
# Epoch: [40][0/379], Loss: 0.08986
# Epoch: [40][100/379], Loss: 0.09344
# Epoch: [40][200/379], Loss: 0.12430
# Epoch: [40][300/379], Loss: 0.10347
# Epoch 41 - Loss: 0.10586
# Validating...
# Validation Loss: 0.14543
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 41 completed - Avg loss: 0.1137716 - LR: 2.5e-06
#
# 🎯 Starting epoch 42/200
# Epoch: [41][0/379], Loss: 0.10467
# Epoch: [41][100/379], Loss: 0.10321
# Epoch: [41][200/379], Loss: 0.10594
# Epoch: [41][300/379], Loss: 0.11323
# Epoch 42 - Loss: 0.10571
# Validating...
# Validation Loss: 0.14487
# 💾 Saving improved model at epoch 42 with valid_loss=0.14487
# 🔁 Epoch 42 completed - Avg loss: 0.1135445 - LR: 2.5e-06
#
# 🎯 Starting epoch 43/200
# Epoch: [42][0/379], Loss: 0.10776
# Epoch: [42][100/379], Loss: 0.09335
# Epoch: [42][200/379], Loss: 0.09361
# Epoch: [42][300/379], Loss: 0.10363
# Epoch 43 - Loss: 0.10551
# Validating...
# Validation Loss: 0.14486
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 43 completed - Avg loss: 0.1133786 - LR: 2.5e-06
#
# 🎯 Starting epoch 44/200
# Epoch: [43][0/379], Loss: 0.09434
# Epoch: [43][100/379], Loss: 0.14694
# Epoch: [43][200/379], Loss: 0.10205
# Epoch: [43][300/379], Loss: 0.11043
# Epoch 44 - Loss: 0.10533
# Validating...
# Validation Loss: 0.14463
# 💾 Saving improved model at epoch 44 with valid_loss=0.14463
# 🔁 Epoch 44 completed - Avg loss: 0.1131869 - LR: 2.5e-06
#
# 🎯 Starting epoch 45/200
# Epoch: [44][0/379], Loss: 0.10877
# Epoch: [44][100/379], Loss: 0.11505
# Epoch: [44][200/379], Loss: 0.11349
# Epoch: [44][300/379], Loss: 0.09353
# Epoch 45 - Loss: 0.10515
# Validating...
# Validation Loss: 0.14531
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 45 completed - Avg loss: 0.1131797 - LR: 2.5e-06
#
# 🎯 Starting epoch 46/200
# Epoch: [45][0/379], Loss: 0.10703
# Epoch: [45][100/379], Loss: 0.11527
# Epoch: [45][200/379], Loss: 0.11802
# Epoch: [45][300/379], Loss: 0.09882
# Epoch 46 - Loss: 0.10496
# Validating...
# Validation Loss: 0.14577
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 46 completed - Avg loss: 0.1131211 - LR: 2.5e-06
#
# 🎯 Starting epoch 47/200
# Epoch: [46][0/379], Loss: 0.10458
# Epoch: [46][100/379], Loss: 0.11136
# Epoch: [46][200/379], Loss: 0.08561
# Epoch: [46][300/379], Loss: 0.12515
# Epoch 47 - Loss: 0.10478
# Validating...
# Validation Loss: 0.14482
# 🛑 No improvement — early stop counter: 3/10
# 🔁 Epoch 47 completed - Avg loss: 0.1127898 - LR: 2.5e-06
#
# 🎯 Starting epoch 48/200
# Epoch: [47][0/379], Loss: 0.09293
# Epoch: [47][100/379], Loss: 0.13487
# Epoch: [47][200/379], Loss: 0.09004
# Epoch: [47][300/379], Loss: 0.11218
# Epoch 48 - Loss: 0.10463
# Validating...
# Validation Loss: 0.14587
# 🛑 No improvement — early stop counter: 4/10
# 🔁 Epoch 48 completed - Avg loss: 0.1128810 - LR: 1.3e-06
#
# 🎯 Starting epoch 49/200
# Epoch: [48][0/379], Loss: 0.10262
# Epoch: [48][100/379], Loss: 0.10713
# Epoch: [48][200/379], Loss: 0.09293
# Epoch: [48][300/379], Loss: 0.11894
# Epoch 49 - Loss: 0.10425
# Validating...
# Validation Loss: 0.14524
# 🛑 No improvement — early stop counter: 5/10
# 🔁 Epoch 49 completed - Avg loss: 0.1124487 - LR: 1.3e-06
#
# 🎯 Starting epoch 50/200
# Epoch: [49][0/379], Loss: 0.11170
# Epoch: [49][100/379], Loss: 0.09937
# Epoch: [49][200/379], Loss: 0.09628
# Epoch: [49][300/379], Loss: 0.09423
# Epoch 50 - Loss: 0.10416
# Validating...
# Validation Loss: 0.14485
# 🛑 No improvement — early stop counter: 6/10
# 🔁 Epoch 50 completed - Avg loss: 0.1122974 - LR: 1.3e-06
#
# 🎯 Starting epoch 51/200
# Epoch: [50][0/379], Loss: 0.11439
# Epoch: [50][100/379], Loss: 0.12538
# Epoch: [50][200/379], Loss: 0.09030
# Epoch: [50][300/379], Loss: 0.09254
# Epoch 51 - Loss: 0.10405
# Validating...
# Validation Loss: 0.14434
# 💾 Saving improved model at epoch 51 with valid_loss=0.14434
# 🔁 Epoch 51 completed - Avg loss: 0.1121111 - LR: 1.3e-06
#
# 🎯 Starting epoch 52/200
# Epoch: [51][0/379], Loss: 0.09429
# Epoch: [51][100/379], Loss: 0.10782
# Epoch: [51][200/379], Loss: 0.08747
# Epoch: [51][300/379], Loss: 0.09456
# Epoch 52 - Loss: 0.10395
# Validating...
# Validation Loss: 0.14525
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 52 completed - Avg loss: 0.1122125 - LR: 1.3e-06
#
# 🎯 Starting epoch 53/200
# Epoch: [52][0/379], Loss: 0.13106
# Epoch: [52][100/379], Loss: 0.07864
# Epoch: [52][200/379], Loss: 0.10722
# Epoch: [52][300/379], Loss: 0.10603
# Epoch 53 - Loss: 0.10389
# Validating...
# Validation Loss: 0.14519
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 53 completed - Avg loss: 0.1121510 - LR: 1.3e-06
#
# 🎯 Starting epoch 54/200
# Epoch: [53][0/379], Loss: 0.12232
# Epoch: [53][100/379], Loss: 0.10392

# %%
import numpy as np
history_loss = np.load(f'models/{MODEL_NAME}/history_loss_{DATASET_VAR}.npy')
plt.figure(figsize=(8, 5))
plt.plot(history_loss, linestyle='-', color='tomato', label="Loss")
# plt.title(title)
plt.xlabel("Epoch")
# plt.ylabel(ylabel)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import numpy as np
# ----> 2 history_loss = np.load(f'models/{MODEL_NAME}/history_loss_{DATASET_VAR}.npy')
#       3 plt.figure(figsize=(8, 5))
#       4 plt.plot(history_loss, linestyle='-', color='tomato', label="Loss")
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/VanillaCNN/history_loss_augm_final_4.npy'

# %%
torch.cuda.empty_cache()
os.getpid()
# Out:
# 26260
