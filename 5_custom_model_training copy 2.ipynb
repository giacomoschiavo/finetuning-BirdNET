# %% [markdown]
# # Dataset Information Creation
# Create a json file to represent the files inside the dataset

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import json
import torch.nn as nn
import os
from birdlib import utils

# %%
# sudo modprobe nvidia_uvm
torch.cuda.is_available()
# Out:
# True

# %%
DATASET_NAME = "dataset"
MODEL_NAME = 'VanillaCNN'
DATASET_VAR = 'augm_5'

# %%
DATASET_PATH = f'../segments/{DATASET_NAME}'
TRAIN_PATH = f"{DATASET_PATH}/train"
VALID_PATH = f"{DATASET_PATH}/valid"
TEST_PATH = f"{DATASET_PATH}/test"
MODEL_PATH = f'./models/{MODEL_NAME}'

# %% [markdown]
# # Create Dataset Config

# %%
def create_dataset_config(dataset_name, config_file_name='dataset_config.json'):
    saving_path = f"utils/{dataset_name}/{config_file_name}"
    if os.path.exists(saving_path):
        print("Dataset config already created!")
        with open(saving_path) as f:
            return json.load(f)

    mappings = utils.get_mappings(TRAIN_PATH)
    samples = utils.collect_samples(TRAIN_PATH, VALID_PATH, TEST_PATH, mappings)

    dataset_config = {
        "mappings": mappings,
        "samples": samples
    }
    with open(saving_path, "w") as f:
        json.dump(dataset_config, f)
    print("Saved new dataset config")
    return dataset_config

# %%
dataset_config = create_dataset_config(DATASET_NAME, f'dataset_config_{DATASET_VAR}.json')
mappings = dataset_config["mappings"]
# Out:
# Dataset config already created!

# %% [markdown]
# ## Load the model

# %%
model_class = utils.load_model_class(MODEL_NAME)
model = model_class(len(mappings))

# %% [markdown]
# # Spectograms Creation

# %%
SPECS_TRAIN_PATH = f"{DATASET_PATH}/train_specs"
SPECS_VALID_PATH = f"{DATASET_PATH}/valid_specs"
SPECS_TEST_PATH = f"{DATASET_PATH}/test_specs"
os.makedirs(SPECS_TRAIN_PATH, exist_ok=True)
os.makedirs(SPECS_VALID_PATH, exist_ok=True)
os.makedirs(SPECS_TEST_PATH, exist_ok=True)
utils.specs_generation(TRAIN_PATH, SPECS_TRAIN_PATH, dataset_config['mappings'])
utils.specs_generation(VALID_PATH, SPECS_VALID_PATH, dataset_config['mappings'])
utils.specs_generation(TEST_PATH, SPECS_TEST_PATH, dataset_config['mappings'])
# Out:
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Cuculus canorus_Common Cuckoo
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Cuculus canorus_Common Cuckoo
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Cuculus canorus_Common Cuckoo
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# '✅ Spettrogrammi generati e salvati.'

# %% [markdown]
# # Model

# %%
# Esempio fittizio
label_counts = { species: len(os.listdir(os.path.join(TRAIN_PATH, species))) for species in os.listdir(TRAIN_PATH)}
counts = torch.tensor(list(label_counts.values()), dtype=torch.float32)
inv_freq = 1.0 / (counts + 1e-6)
pos_weight = inv_freq / inv_freq.mean()  # normalize around 1
names = list(label_counts.keys())
importance_map = {
    'Aeroplane': 0.1,
    'Wind': 0.1,
    'Vegetation': 0.1,
    'None': 0.0,
    # fallback = 1.0
}

importance = torch.tensor([importance_map.get(name, 1.0) for name in names])
final_pos_weight = pos_weight * importance + 1e-3

final_pos_weight, pos_weight, names
for i, name in enumerate(names):
    print(name, final_pos_weight[i])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
final_pos_weight = final_pos_weight.to(device)
# Out:
# Aeroplane tensor(0.2860)
# Muscicapa striata_Spotted Flycatcher tensor(0.3238)
# Periparus ater_Coal Tit tensor(0.1635)
# Cuculus canorus_Common Cuckoo tensor(9.7237)
# Regulus regulus_Goldcrest tensor(0.1754)
# Anthus trivialis_Tree Pipit tensor(0.2484)
# Vegetation tensor(0.0751)
# Troglodytes troglodytes_Eurasian Wren tensor(0.1370)
# Erithacus rubecula_European Robin tensor(0.0982)
# None tensor(0.0010)
# Parus major_Great Tit tensor(1.5314)
# Certhia familiaris_Eurasian Treecreeper tensor(0.2774)
# Phylloscopus collybita_Common Chiffchaff tensor(0.0765)
# Coccothraustes coccothraustes_Hawfinch tensor(2.0167)
# Wind tensor(0.0199)
# Turdus merula_Eurasian Blackbird tensor(0.2185)
# Loxia curvirostra_Common Crossbill tensor(0.9848)
# Regulus ignicapilla_Common Firecrest tensor(0.0557)
# Sylvia atricapilla_Eurasian Blackcap tensor(0.0432)
# Lophophanes cristatus_Crested Tit tensor(1.1331)
# Fringilla coelebs_Common Chaffinch tensor(0.0181)

# %%
@torch.no_grad()
def evaluate(model, val_loader, criterion, device):
    model.eval()
    val_loss = 0.0
    for mel_spec, labels, _ in val_loader:
        mel_spec = mel_spec.to(device)
        labels = labels.to(device)
        outputs = model(mel_spec)
        loss = criterion(outputs, labels)
        val_loss += loss.item()
    return val_loss / len(val_loader)

# %%
def combined_loss(train_loss, val_loss, epoch, total_epochs):
    val_weight = min(0.9, epoch / (total_epochs * 0.6))  # Massimo 0.9
    train_weight = 1 - val_weight
    return train_weight * train_loss + val_weight * val_loss

# %%
def load_checkpoint(model, optimizer, scheduler, checkpoint_path):
    """Load model and optimizer state from the checkpoint"""
    if not os.path.exists(checkpoint_path):
        print("No weights found!")
        return None, 0, float("inf"), [], []
    
    print(f"Loading checkpoint from {checkpoint_path}")
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    history_loss = checkpoint['history_loss']
    val_loss_history = checkpoint.get('val_loss_history', [])
    best_loss = checkpoint.get('combined_loss', float("inf"))
    
    return model, best_loss, history_loss, val_loss_history

# %%
def prepare_dataloaders(dataset_config, batch_size):
    """Prepare dataloaders for training and validation."""
    print("Loading training data...")
    train_loader = utils.get_dataloader(dataset_config, split="train", batch_size=batch_size)
    print("Loaded!")
    
    print("Loading validation data...")
    val_loader = utils.get_dataloader(dataset_config, split="valid", batch_size=batch_size)
    print("Loaded!")
    
    return train_loader, val_loader

# %%
def initialize_training_components(model, lr=1e-5, patience=3, pos_weight=None):
    """Initialize loss function, optimizer and scheduler."""
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=patience,
    )
    return criterion, optimizer, scheduler

# %%
def train_model(dataset_config, model, total_epochs=10, batch_size=100, lr=1e-5, patience=3, early_stop_patience=15, print_freq=100, load_weights=False, checkpoint_name='checkpoint.pth'):
    history_loss = []
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training {MODEL_NAME} on: {device}")

    model.to(device)
    criterion, optimizer, scheduler = initialize_training_components(model, lr, patience, final_pos_weight)

    history_loss = []
    val_loss_history = []

    best_loss = float("inf")

    saving_path = f'models/{MODEL_NAME}/{checkpoint_name}'
    if load_weights:
        model, best_loss, history_loss, val_loss_history = load_checkpoint(model, optimizer, scheduler, saving_path)
        if model is None:  # Checkpoint not found
            return None
    
    train_loader, val_loader = prepare_dataloaders(dataset_config, batch_size)
    
    early_stop_counter = 0
    for epoch in range(total_epochs):
        model.train()
        running_loss = 0.0
        print(f"\n🎯 Starting epoch {epoch + 1}/{total_epochs}")

        for batch_index, (mel_spec, labels, _) in enumerate(train_loader):
            mel_spec = mel_spec.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(mel_spec)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            
            if batch_index % print_freq == 0:
                print('Epoch: [{0}][{1}/{2}], Loss: {loss:.5f}'.format(epoch, batch_index, len(train_loader), loss=loss))

        val_loss = evaluate(model, val_loader, criterion, device)
        val_loss_history.append(val_loss)
        train_loss = running_loss / len(train_loader)
        history_loss.append(train_loss)
        loss = combined_loss(train_loss, val_loss, epoch, total_epochs)
        scheduler.step(loss)


        np.save(f'models/{MODEL_NAME}/history_loss_{DATASET_VAR}.npy', history_loss)
        np.save(f'models/{MODEL_NAME}/val_loss_history_{DATASET_VAR}.npy', val_loss_history)
        if loss < best_loss:
            best_loss = loss
            early_stop_counter = 0
            print(f"💾 Saving improved model at epoch {epoch+1} with loss={loss:.5f}")
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'combined_loss': loss,
                'history_loss': history_loss,
                'val_loss_history': val_loss_history
            }, saving_path)
        else:
            early_stop_counter += 1
            print(f"🛑 No improvement - early stop counter: {early_stop_counter}/{early_stop_patience}")

        print(f"🔁 Epoch {epoch + 1} completed - Combined loss: {loss:.7f} - LR: {optimizer.param_groups[0]['lr']:.1e}")

        if early_stop_counter >= early_stop_patience:
            print(f"\n🚨 Early stopping triggered after {early_stop_patience} epochs without improvement.")
            break

    print("✅ Training completed")

    return model

# %%
model = train_model(dataset_config, model, total_epochs=200, batch_size=16, print_freq=500, lr=1e-5, load_weights=False, checkpoint_name=f'checkpoint_{DATASET_VAR}.pth')
# Out:
# Training VanillaCNN on: cuda
# Loading training data...
# Loaded!
# Loading validation data...
# Loaded!
#
# 🎯 Starting epoch 1/200
# Epoch: [0][0/2206], Loss: 0.66115
# Epoch: [0][500/2206], Loss: 0.04148
# Epoch: [0][1000/2206], Loss: 0.02134
# Epoch: [0][1500/2206], Loss: 0.03134
# Epoch: [0][2000/2206], Loss: 0.06754
# 💾 Saving improved model at epoch 1 with loss=0.05048
# 🔁 Epoch 1 completed - Combined loss: 0.0504789 - LR: 1.0e-05
#
# 🎯 Starting epoch 2/200
# Epoch: [1][0/2206], Loss: 0.02101
# Epoch: [1][500/2206], Loss: 0.01879
# Epoch: [1][1000/2206], Loss: 0.02089
# Epoch: [1][1500/2206], Loss: 0.03311
# Epoch: [1][2000/2206], Loss: 0.02174
# 💾 Saving improved model at epoch 2 with loss=0.03626
# 🔁 Epoch 2 completed - Combined loss: 0.0362617 - LR: 1.0e-05
#
# 🎯 Starting epoch 3/200
# Epoch: [2][0/2206], Loss: 0.02839
# Epoch: [2][500/2206], Loss: 0.02683
# Epoch: [2][1000/2206], Loss: 0.04123
# Epoch: [2][1500/2206], Loss: 0.05946
# Epoch: [2][2000/2206], Loss: 0.02560
# 💾 Saving improved model at epoch 3 with loss=0.03273
# 🔁 Epoch 3 completed - Combined loss: 0.0327263 - LR: 1.0e-05
#
# 🎯 Starting epoch 4/200
# Epoch: [3][0/2206], Loss: 0.02183
# Epoch: [3][500/2206], Loss: 0.01247
# Epoch: [3][1000/2206], Loss: 0.03203
# Epoch: [3][1500/2206], Loss: 0.01857
# Epoch: [3][2000/2206], Loss: 0.01553
# 💾 Saving improved model at epoch 4 with loss=0.03020
# 🔁 Epoch 4 completed - Combined loss: 0.0301982 - LR: 1.0e-05
#
# 🎯 Starting epoch 5/200
# Epoch: [4][0/2206], Loss: 0.02032
# Epoch: [4][500/2206], Loss: 0.03109
# Epoch: [4][1000/2206], Loss: 0.03536
# Epoch: [4][1500/2206], Loss: 0.01912
# Epoch: [4][2000/2206], Loss: 0.03929
# 💾 Saving improved model at epoch 5 with loss=0.02864
# 🔁 Epoch 5 completed - Combined loss: 0.0286431 - LR: 1.0e-05
#
# 🎯 Starting epoch 6/200
# Epoch: [5][0/2206], Loss: 0.01942
# Epoch: [5][500/2206], Loss: 0.05282
# Epoch: [5][1000/2206], Loss: 0.01339
# Epoch: [5][1500/2206], Loss: 0.00784
# Epoch: [5][2000/2206], Loss: 0.01609
# 💾 Saving improved model at epoch 6 with loss=0.02741
# 🔁 Epoch 6 completed - Combined loss: 0.0274067 - LR: 1.0e-05
#
# 🎯 Starting epoch 7/200
# Epoch: [6][0/2206], Loss: 0.02053
# Epoch: [6][500/2206], Loss: 0.02620
# Epoch: [6][1000/2206], Loss: 0.05469
# Epoch: [6][1500/2206], Loss: 0.01866
# Epoch: [6][2000/2206], Loss: 0.02475
# 💾 Saving improved model at epoch 7 with loss=0.02678
# 🔁 Epoch 7 completed - Combined loss: 0.0267821 - LR: 1.0e-05
#
# 🎯 Starting epoch 8/200
# Epoch: [7][0/2206], Loss: 0.02254
# Epoch: [7][500/2206], Loss: 0.03339
# Epoch: [7][1000/2206], Loss: 0.03474
# Epoch: [7][1500/2206], Loss: 0.01949
# Epoch: [7][2000/2206], Loss: 0.03332
# 💾 Saving improved model at epoch 8 with loss=0.02581
# 🔁 Epoch 8 completed - Combined loss: 0.0258142 - LR: 1.0e-05
#
# 🎯 Starting epoch 9/200
# Epoch: [8][0/2206], Loss: 0.01146
# Epoch: [8][500/2206], Loss: 0.02616
# Epoch: [8][1000/2206], Loss: 0.01010
# Epoch: [8][1500/2206], Loss: 0.02564
# Epoch: [8][2000/2206], Loss: 0.01666
# 💾 Saving improved model at epoch 9 with loss=0.02515
# 🔁 Epoch 9 completed - Combined loss: 0.0251455 - LR: 1.0e-05
#
# 🎯 Starting epoch 10/200
# Epoch: [9][0/2206], Loss: 0.00709
# Epoch: [9][500/2206], Loss: 0.02120
# Epoch: [9][1000/2206], Loss: 0.05965
# Epoch: [9][1500/2206], Loss: 0.01295
# Epoch: [9][2000/2206], Loss: 0.01605
# 💾 Saving improved model at epoch 10 with loss=0.02441
# 🔁 Epoch 10 completed - Combined loss: 0.0244094 - LR: 1.0e-05
#
# 🎯 Starting epoch 11/200
# Epoch: [10][0/2206], Loss: 0.02803
# Epoch: [10][500/2206], Loss: 0.01212
# Epoch: [10][1000/2206], Loss: 0.02594
# Epoch: [10][1500/2206], Loss: 0.01750
# Epoch: [10][2000/2206], Loss: 0.01873
# 💾 Saving improved model at epoch 11 with loss=0.02417
# 🔁 Epoch 11 completed - Combined loss: 0.0241706 - LR: 1.0e-05
#
# 🎯 Starting epoch 12/200
# Epoch: [11][0/2206], Loss: 0.01540
# Epoch: [11][500/2206], Loss: 0.02321
# Epoch: [11][1000/2206], Loss: 0.01433
# Epoch: [11][1500/2206], Loss: 0.01288
# Epoch: [11][2000/2206], Loss: 0.03225
# 🛑 No improvement - early stop counter: 1/15
# 🔁 Epoch 12 completed - Combined loss: 0.0241731 - LR: 1.0e-05
#
# 🎯 Starting epoch 13/200
# Epoch: [12][0/2206], Loss: 0.01570
# Epoch: [12][500/2206], Loss: 0.02023
# Epoch: [12][1000/2206], Loss: 0.01707
# Epoch: [12][1500/2206], Loss: 0.01445
# Epoch: [12][2000/2206], Loss: 0.01198
# 💾 Saving improved model at epoch 13 with loss=0.02338
# 🔁 Epoch 13 completed - Combined loss: 0.0233794 - LR: 1.0e-05
#
# 🎯 Starting epoch 14/200
# Epoch: [13][0/2206], Loss: 0.01071
# Epoch: [13][500/2206], Loss: 0.02495
# Epoch: [13][1000/2206], Loss: 0.03292
# Epoch: [13][1500/2206], Loss: 0.01427
# Epoch: [13][2000/2206], Loss: 0.01991
# 💾 Saving improved model at epoch 14 with loss=0.02333
# 🔁 Epoch 14 completed - Combined loss: 0.0233256 - LR: 1.0e-05
#
# 🎯 Starting epoch 15/200
# Epoch: [14][0/2206], Loss: 0.01316
# Epoch: [14][500/2206], Loss: 0.01933
# Epoch: [14][1000/2206], Loss: 0.00999
# Epoch: [14][1500/2206], Loss: 0.00991
# Epoch: [14][2000/2206], Loss: 0.01845
# 🛑 No improvement - early stop counter: 1/15
# 🔁 Epoch 15 completed - Combined loss: 0.0233890 - LR: 1.0e-05
#
# 🎯 Starting epoch 16/200
# Epoch: [15][0/2206], Loss: 0.01964
# Epoch: [15][500/2206], Loss: 0.02682
# Epoch: [15][1000/2206], Loss: 0.01055
# Epoch: [15][1500/2206], Loss: 0.01028
# Epoch: [15][2000/2206], Loss: 0.01340
# 💾 Saving improved model at epoch 16 with loss=0.02278
# 🔁 Epoch 16 completed - Combined loss: 0.0227757 - LR: 1.0e-05
#
# 🎯 Starting epoch 17/200
# Epoch: [16][0/2206], Loss: 0.01196
# Epoch: [16][500/2206], Loss: 0.01324
# Epoch: [16][1000/2206], Loss: 0.01317
# Epoch: [16][1500/2206], Loss: 0.01152
# Epoch: [16][2000/2206], Loss: 0.01649
# 💾 Saving improved model at epoch 17 with loss=0.02250
# 🔁 Epoch 17 completed - Combined loss: 0.0224965 - LR: 1.0e-05
#
# 🎯 Starting epoch 18/200
# Epoch: [17][0/2206], Loss: 0.01648
# Epoch: [17][500/2206], Loss: 0.03562
# Epoch: [17][1000/2206], Loss: 0.03056
# Epoch: [17][1500/2206], Loss: 0.01897
# Epoch: [17][2000/2206], Loss: 0.00698
# 🛑 No improvement - early stop counter: 1/15
# 🔁 Epoch 18 completed - Combined loss: 0.0227991 - LR: 1.0e-05
#
# 🎯 Starting epoch 19/200
# Epoch: [18][0/2206], Loss: 0.02435
# Epoch: [18][500/2206], Loss: 0.03635
# Epoch: [18][1000/2206], Loss: 0.01084
# Epoch: [18][1500/2206], Loss: 0.00859
# Epoch: [18][2000/2206], Loss: 0.00698
# 🛑 No improvement - early stop counter: 2/15
# 🔁 Epoch 19 completed - Combined loss: 0.0225051 - LR: 1.0e-05
#
# 🎯 Starting epoch 20/200
# Epoch: [19][0/2206], Loss: 0.01118
# Epoch: [19][500/2206], Loss: 0.00898
# Epoch: [19][1000/2206], Loss: 0.00884
# Epoch: [19][1500/2206], Loss: 0.00579
# Epoch: [19][2000/2206], Loss: 0.02236
# 🛑 No improvement - early stop counter: 3/15
# 🔁 Epoch 20 completed - Combined loss: 0.0226124 - LR: 1.0e-05
#
# 🎯 Starting epoch 21/200
# Epoch: [20][0/2206], Loss: 0.01461
# Epoch: [20][500/2206], Loss: 0.01563
# Epoch: [20][1000/2206], Loss: 0.02721
# Epoch: [20][1500/2206], Loss: 0.00953
# Epoch: [20][2000/2206], Loss: 0.02838
# 🛑 No improvement - early stop counter: 4/15
# 🔁 Epoch 21 completed - Combined loss: 0.0229125 - LR: 5.0e-06
#
# 🎯 Starting epoch 22/200
# Epoch: [21][0/2206], Loss: 0.01975
# Epoch: [21][500/2206], Loss: 0.04297
# Epoch: [21][1000/2206], Loss: 0.01291
# Epoch: [21][1500/2206], Loss: 0.02681
# Epoch: [21][2000/2206], Loss: 0.01726
# 💾 Saving improved model at epoch 22 with loss=0.02197
# 🔁 Epoch 22 completed - Combined loss: 0.0219691 - LR: 5.0e-06
#
# 🎯 Starting epoch 23/200
# Epoch: [22][0/2206], Loss: 0.01084
# Epoch: [22][500/2206], Loss: 0.02963
# Epoch: [22][1000/2206], Loss: 0.01529
# Epoch: [22][1500/2206], Loss: 0.01124
# Epoch: [22][2000/2206], Loss: 0.00797
# 🛑 No improvement - early stop counter: 1/15
# 🔁 Epoch 23 completed - Combined loss: 0.0229780 - LR: 5.0e-06
#
# 🎯 Starting epoch 24/200
# Epoch: [23][0/2206], Loss: 0.00880
# Epoch: [23][500/2206], Loss: 0.02967
# Epoch: [23][1000/2206], Loss: 0.01159
# Epoch: [23][1500/2206], Loss: 0.01356
# Epoch: [23][2000/2206], Loss: 0.01709
# 🛑 No improvement - early stop counter: 2/15
# 🔁 Epoch 24 completed - Combined loss: 0.0226031 - LR: 5.0e-06
#
# 🎯 Starting epoch 25/200
# Epoch: [24][0/2206], Loss: 0.00806
# Epoch: [24][500/2206], Loss: 0.02063
# Epoch: [24][1000/2206], Loss: 0.01322
# Epoch: [24][1500/2206], Loss: 0.01001
# Epoch: [24][2000/2206], Loss: 0.02098
# 🛑 No improvement - early stop counter: 3/15
# 🔁 Epoch 25 completed - Combined loss: 0.0229195 - LR: 5.0e-06
#
# 🎯 Starting epoch 26/200
# Epoch: [25][0/2206], Loss: 0.01527
# Epoch: [25][500/2206], Loss: 0.00886
# Epoch: [25][1000/2206], Loss: 0.02621
# Epoch: [25][1500/2206], Loss: 0.01115
# Epoch: [25][2000/2206], Loss: 0.01153
# 🛑 No improvement - early stop counter: 4/15
# 🔁 Epoch 26 completed - Combined loss: 0.0230994 - LR: 2.5e-06
#
# 🎯 Starting epoch 27/200
# Epoch: [26][0/2206], Loss: 0.01048
# Epoch: [26][500/2206], Loss: 0.01896
# Epoch: [26][1000/2206], Loss: 0.00937
# Epoch: [26][1500/2206], Loss: 0.01640
# Epoch: [26][2000/2206], Loss: 0.01087
# 🛑 No improvement - early stop counter: 5/15
# 🔁 Epoch 27 completed - Combined loss: 0.0229986 - LR: 2.5e-06
#
# 🎯 Starting epoch 28/200
# Epoch: [27][0/2206], Loss: 0.01691
# Epoch: [27][500/2206], Loss: 0.02032
# Epoch: [27][1000/2206], Loss: 0.00647
# Epoch: [27][1500/2206], Loss: 0.00703
# Epoch: [27][2000/2206], Loss: 0.02608
# 🛑 No improvement - early stop counter: 6/15
# 🔁 Epoch 28 completed - Combined loss: 0.0237435 - LR: 2.5e-06
#
# 🎯 Starting epoch 29/200
# Epoch: [28][0/2206], Loss: 0.01107
# Epoch: [28][500/2206], Loss: 0.01176
# Epoch: [28][1000/2206], Loss: 0.01152
# Epoch: [28][1500/2206], Loss: 0.01751
# Epoch: [28][2000/2206], Loss: 0.00967
# 🛑 No improvement - early stop counter: 7/15
# 🔁 Epoch 29 completed - Combined loss: 0.0238233 - LR: 2.5e-06
#
# 🎯 Starting epoch 30/200
# Epoch: [29][0/2206], Loss: 0.00681
# Epoch: [29][500/2206], Loss: 0.01070
# Epoch: [29][1000/2206], Loss: 0.00892
# Epoch: [29][1500/2206], Loss: 0.01838
# Epoch: [29][2000/2206], Loss: 0.01350
# 🛑 No improvement - early stop counter: 8/15
# 🔁 Epoch 30 completed - Combined loss: 0.0240692 - LR: 1.3e-06
#
# 🎯 Starting epoch 31/200
# Epoch: [30][0/2206], Loss: 0.01386
# Epoch: [30][500/2206], Loss: 0.01485
# Epoch: [30][1000/2206], Loss: 0.01210
# Epoch: [30][1500/2206], Loss: 0.00669
# Epoch: [30][2000/2206], Loss: 0.00762
# 🛑 No improvement - early stop counter: 9/15
# 🔁 Epoch 31 completed - Combined loss: 0.0244608 - LR: 1.3e-06
#
# 🎯 Starting epoch 32/200
# Epoch: [31][0/2206], Loss: 0.01773
# Epoch: [31][500/2206], Loss: 0.00923
# Epoch: [31][1000/2206], Loss: 0.01560
# Epoch: [31][1500/2206], Loss: 0.01345
# Epoch: [31][2000/2206], Loss: 0.00732
# 🛑 No improvement - early stop counter: 10/15
# 🔁 Epoch 32 completed - Combined loss: 0.0249234 - LR: 1.3e-06
#
# 🎯 Starting epoch 33/200
# Epoch: [32][0/2206], Loss: 0.02769
# Epoch: [32][500/2206], Loss: 0.01696
# Epoch: [32][1000/2206], Loss: 0.01139
# Epoch: [32][1500/2206], Loss: 0.00948
# Epoch: [32][2000/2206], Loss: 0.01253
# 🛑 No improvement - early stop counter: 11/15
# 🔁 Epoch 33 completed - Combined loss: 0.0253054 - LR: 1.3e-06
#
# 🎯 Starting epoch 34/200
# Epoch: [33][0/2206], Loss: 0.01304
# Epoch: [33][500/2206], Loss: 0.00927
# Epoch: [33][1000/2206], Loss: 0.01727
# Epoch: [33][1500/2206], Loss: 0.00810
# Epoch: [33][2000/2206], Loss: 0.01553
# 🛑 No improvement - early stop counter: 12/15
# 🔁 Epoch 34 completed - Combined loss: 0.0253725 - LR: 6.3e-07
#
# 🎯 Starting epoch 35/200
# Epoch: [34][0/2206], Loss: 0.01061
# Epoch: [34][500/2206], Loss: 0.02639
# Epoch: [34][1000/2206], Loss: 0.00811
# Epoch: [34][1500/2206], Loss: 0.02254
# Epoch: [34][2000/2206], Loss: 0.00804
# 🛑 No improvement - early stop counter: 13/15
# 🔁 Epoch 35 completed - Combined loss: 0.0260454 - LR: 6.3e-07
#
# 🎯 Starting epoch 36/200
# Epoch: [35][0/2206], Loss: 0.00932
# Epoch: [35][500/2206], Loss: 0.00877
# Epoch: [35][1000/2206], Loss: 0.01411
# Epoch: [35][1500/2206], Loss: 0.00885
# Epoch: [35][2000/2206], Loss: 0.01032
# 🛑 No improvement - early stop counter: 14/15
# 🔁 Epoch 36 completed - Combined loss: 0.0263705 - LR: 6.3e-07
#
# 🎯 Starting epoch 37/200
# Epoch: [36][0/2206], Loss: 0.00904
# Epoch: [36][500/2206], Loss: 0.00963
# Epoch: [36][1000/2206], Loss: 0.01392
# Epoch: [36][1500/2206], Loss: 0.02998
# Epoch: [36][2000/2206], Loss: 0.01004
# 🛑 No improvement - early stop counter: 15/15
# 🔁 Epoch 37 completed - Combined loss: 0.0265651 - LR: 6.3e-07
#
# 🚨 Early stopping triggered after 15 epochs without improvement.
# ✅ Training completed

# %%
history_loss = np.load(f'models/{MODEL_NAME}/history_loss_{DATASET_VAR}.npy')
plt.figure(figsize=(8, 5))
plt.plot(history_loss, linestyle='-', color='tomato', label="Loss")
# plt.title(title)
plt.xlabel("Epoch")
# plt.ylabel(ylabel)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
torch.cuda.empty_cache()
os.getpid()
# Out:
# 5519
