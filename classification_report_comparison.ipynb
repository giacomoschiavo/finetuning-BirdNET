# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns
import json
import librosa
import soundfile as sf
import pandas as pd
from tqdm import tqdm
import scipy.stats as stats

# %%
model_1 = 'augm_spec_append'
model_2 = 'test'
class_report_1 = json.load(open(f'classifiers/official/{model_1}/classification_report.json'))
class_report_2 = json.load(open(f'classifiers/official/{model_2}/classification_report.json'))
df_1 = pd.DataFrame(class_report_1)
df_2 = pd.DataFrame(class_report_2)
df_1 = df_1.T
df_2 = df_2.T

# %%
df_1
# Out:
#                                             precision    recall  f1-score  \
# Certhia familiaris_Eurasian Treecreeper      0.000000  0.000000  0.000000
# Dendrocopos major_Great Spotted Woodpecker   1.000000  0.400000  0.571429
# Dryocopus martius_Black Woodpecker           0.750000  0.250000  0.375000
# Erithacus rubecula_European Robin            0.262626  0.292135  0.276596
# Fringilla coelebs_Common Chaffinch           0.850746  0.698997  0.767442
# Lophophanes cristatus_Crested Tit            0.000000  0.000000  0.000000
# Loxia curvirostra_Common Crossbill           0.520000  0.464286  0.490566
# Muscicapa striata_Spotted Flycatcher         0.000000  0.000000  0.000000
# Pecking_                                     0.258065  0.615385  0.363636
# Periparus ater_Coal Tit                      0.500000  0.134615  0.212121
# Rain_                                        0.571429  0.307692  0.400000
# Regulus ignicapilla_Common Firecrest         0.393130  0.502439  0.441113
# ...

# %%
df_2
# Out:
#                                             precision    recall  f1-score  \
# Certhia familiaris_Eurasian Treecreeper      0.000000  0.000000  0.000000
# Dendrocopos major_Great Spotted Woodpecker   1.000000  0.800000  0.888889
# Dryocopus martius_Black Woodpecker           0.222222  0.166667  0.190476
# Erithacus rubecula_European Robin            0.733333  0.123596  0.211538
# Fringilla coelebs_Common Chaffinch           0.981735  0.239688  0.385305
# Glaucidium passerinum_Eurasian Pygmy-Owl     0.000000  0.000000  0.000000
# Lophophanes cristatus_Crested Tit            1.000000  0.100000  0.181818
# Loxia curvirostra_Common Crossbill           0.000000  0.000000  0.000000
# Muscicapa striata_Spotted Flycatcher         0.000000  0.000000  0.000000
# Pecking_                                     0.000000  0.000000  0.000000
# Periparus ater_Coal Tit                      1.000000  0.346154  0.514286
# Pyrrhula pyrrhula_Eurasian Bullfinch         0.000000  0.000000  0.000000
# ...
