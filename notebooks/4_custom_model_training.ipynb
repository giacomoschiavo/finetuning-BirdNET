# %% [markdown]
# # Dataset Information Creation
# Create a json file to represent the files inside the dataset

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import numpy as np
import json
import torch.nn as nn
import os
from birdlib import utils

# %%
# sudo modprobe nvidia_uvm
torch.cuda.is_available()
# Out:
# True

# %%
DATASET_NAME = "dataset"
MODEL_NAME = 'CustomCNN'
DATASET_VAR = 'custom'

# %%
DATASET_PATH = f'../segments/{DATASET_NAME}'
TRAIN_PATH = f"{DATASET_PATH}/train"
VALID_PATH = f"{DATASET_PATH}/valid"
TEST_PATH = f"{DATASET_PATH}/test"
MODEL_PATH = f'./models/{MODEL_NAME}'

# %% [markdown]
# # Create Dataset Config

# %%
def create_dataset_config(dataset_name, config_file_name='dataset_config.json'):
    saving_path = f"utils/{dataset_name}/{config_file_name}"
    if os.path.exists(saving_path):
        print("Dataset config already created!")
        with open(saving_path) as f:
            return json.load(f)

    mappings = utils.get_mappings(TRAIN_PATH)
    samples = utils.collect_samples(TRAIN_PATH, VALID_PATH, TEST_PATH, mappings)

    dataset_config = {
        "mappings": mappings,
        "samples": samples
    }
    with open(saving_path, "w") as f:
        json.dump(dataset_config, f)
    print("Saved new dataset config")
    return dataset_config

# %%
dataset_config = create_dataset_config(DATASET_NAME, f'dataset_config_{DATASET_VAR}.json')
mappings = dataset_config["mappings"]
# Out:
# Saved new dataset config

# %% [markdown]
# ## Load the model

# %%
INPUT_SHAPE = (256, 256)

config_file = f'/home/giacomoschiavo/finetuning-BirdNET/models/CustomCNN/model_ranking_config_6_0.json'
with open(config_file) as f:
    configs = json.load(f)

# %%
configs
# Out:
# [{'model_id': 19,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [4, 5, 6, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 128,
#    'dropout': 0.0,
#    'dense_hidden': 128},
#   'micro_f1': 0.01678627904147914,
#   'weighted_f1': 0.029839708730654717,
#   'samples_f1': 0.006456303620764868,
#   'mean_f1': 0.01769409713096624},
#  {'model_id': 5,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [3, 4, 6, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 64,
#    'dropout': 0.0,
#    'dense_hidden': 64},
#   'micro_f1': 0.016910069177555727,
#   'weighted_f1': 0.028214908264909272,
#   'samples_f1': 0.0072415297368038384,
#   'mean_f1': 0.01745550239308961},
#  {'model_id': 7,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [2, 5, 6, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 64,
#    'dropout': 0.5,
#    'dense_hidden': 64},
#   'micro_f1': 0.015288394718554551,
#   'weighted_f1': 0.02866390430004854,
#   'samples_f1': 0.006228491105617759,
#   'mean_f1': 0.016726930041406952},
#  {'model_id': 2,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [3, 3, 5, 5],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 32,
#    'dropout': 0.5,
#    'dense_hidden': 128},
#   'micro_f1': 0.015126237348459567,
#   'weighted_f1': 0.02872557910234706,
#   'samples_f1': 0.00573408947700063,
#   'mean_f1': 0.016528635309269086},
#  {'model_id': 1,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [2, 3, 5, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 32,
#    'dropout': 0.5,
#    'dense_hidden': 128},
#   'micro_f1': 0.014989529372864544,
#   'weighted_f1': 0.02743581331791322,
#   'samples_f1': 0.006344820900586496,
#   'mean_f1': 0.01625672119712142},
#  {'model_id': 13,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [2, 3, 4, 5],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 128,
#    'dropout': 0.5,
#    'dense_hidden': 32},
#   'micro_f1': 0.015597379640220442,
#   'weighted_f1': 0.02568544044800431,
#   'samples_f1': 0.006405755555093929,
#   'mean_f1': 0.015896191881106227},
#  {'model_id': 12,
#   'config': {'num_conv_layers': 3,
#    'kernel_sizes': [3, 4, 6],
#    'channels': [16, 32, 64],
#    'batch_size': 128,
#    'dropout': 0.0,
#    'dense_hidden': 128},
#   'micro_f1': 0.014627941488234045,
#   'weighted_f1': 0.027433880994213535,
#   'samples_f1': 0.005448112064369154,
#   'mean_f1': 0.015836644848938913},
#  {'model_id': 0,
#   'config': {'num_conv_layers': 3,
#    'kernel_sizes': [2, 3, 4],
#    'channels': [16, 32, 64],
#    'batch_size': 32,
#    'dropout': 0.5,
#    'dense_hidden': 64},
#   'micro_f1': 0.013762537905295079,
#   'weighted_f1': 0.026594132751524488,
#   'samples_f1': 0.005181522950899132,
#   'mean_f1': 0.015179397869239566},
#  {'model_id': 18,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [2, 2, 2, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 128,
#    'dropout': 0.0,
#    'dense_hidden': 32},
#   'micro_f1': 0.01338147833474936,
#   'weighted_f1': 0.025710871725051546,
#   'samples_f1': 0.005077657062534189,
#   'mean_f1': 0.014723335707445032},
#  {'model_id': 14,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [3, 3, 4, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 128,
#    'dropout': 0.0,
#    'dense_hidden': 32},
#   'micro_f1': 0.013093289689034369,
#   'weighted_f1': 0.02567950136947017,
#   'samples_f1': 0.005370558867723327,
#   'mean_f1': 0.014714449975409287},
#  {'model_id': 11,
#   'config': {'num_conv_layers': 3,
#    'kernel_sizes': [2, 4, 5],
#    'channels': [16, 32, 64],
#    'batch_size': 128,
#    'dropout': 0.5,
#    'dense_hidden': 64},
#   'micro_f1': 0.014280697647196533,
#   'weighted_f1': 0.023673524348319454,
#   'samples_f1': 0.005356017643352236,
#   'mean_f1': 0.014436746546289408},
#  {'model_id': 17,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [3, 5, 5, 6],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 128,
#    'dropout': 0.0,
#    'dense_hidden': 64},
#   'micro_f1': 0.013373253493013972,
#   'weighted_f1': 0.023952875548901548,
#   'samples_f1': 0.005840725122388637,
#   'mean_f1': 0.014388951388101387},
#  {'model_id': 15,
#   'config': {'num_conv_layers': 3,
#    'kernel_sizes': [3, 5, 6],
#    'channels': [16, 32, 64],
#    'batch_size': 128,
#    'dropout': 0.5,
#    'dense_hidden': 32},
#   'micro_f1': 0.0132987012987013,
#   'weighted_f1': 0.022634939770180017,
#   'samples_f1': 0.006330279676215403,
#   'mean_f1': 0.014087973581698908},
#  {'model_id': 3,
#   'config': {'num_conv_layers': 1,
#    'kernel_sizes': [4],
#    'channels': [16],
#    'batch_size': 32,
#    'dropout': 0.0,
#    'dense_hidden': 64},
#   'micro_f1': 0.013026052104208418,
#   'weighted_f1': 0.0231789107555975,
#   'samples_f1': 0.005438417914788425,
#   'mean_f1': 0.013881126924864783},
#  {'model_id': 10,
#   'config': {'num_conv_layers': 1,
#    'kernel_sizes': [3],
#    'channels': [16],
#    'batch_size': 128,
#    'dropout': 0.0,
#    'dense_hidden': 128},
#   'micro_f1': 0.012635011208477685,
#   'weighted_f1': 0.02388909945695428,
#   'samples_f1': 0.004822839416412195,
#   'mean_f1': 0.013782316693948055},
#  {'model_id': 4,
#   'config': {'num_conv_layers': 2,
#    'kernel_sizes': [4, 6],
#    'channels': [16, 32],
#    'batch_size': 64,
#    'dropout': 0.0,
#    'dense_hidden': 64},
#   'micro_f1': 0.013081870707511175,
#   'weighted_f1': 0.02184680291903855,
#   'samples_f1': 0.005501429887063157,
#   'mean_f1': 0.013476701171204293},
#  {'model_id': 16,
#   'config': {'num_conv_layers': 3,
#    'kernel_sizes': [4, 5, 6],
#    'channels': [16, 32, 64],
#    'batch_size': 128,
#    'dropout': 0.5,
#    'dense_hidden': 32},
#   'micro_f1': 0.013870929822499116,
#   'weighted_f1': 0.020323664402416244,
#   'samples_f1': 0.005142746352576219,
#   'mean_f1': 0.01311244685916386},
#  {'model_id': 8,
#   'config': {'num_conv_layers': 4,
#    'kernel_sizes': [3, 4, 4, 4],
#    'channels': [16, 32, 64, 128],
#    'batch_size': 64,
#    'dropout': 0.5,
#    'dense_hidden': 32},
#   'micro_f1': 0.012893356643356644,
#   'weighted_f1': 0.0210748507574909,
#   'samples_f1': 0.005307546895448596,
#   'mean_f1': 0.013091918098765379},
#  {'model_id': 6,
#   'config': {'num_conv_layers': 2,
#    'kernel_sizes': [2, 3],
#    'channels': [16, 32],
#    'batch_size': 64,
#    'dropout': 0.5,
#    'dense_hidden': 128},
#   'micro_f1': 0.011781389767644814,
#   'weighted_f1': 0.022076658001643396,
#   'samples_f1': 0.004672580097910909,
#   'mean_f1': 0.012843542622399708},
#  {'model_id': 9,
#   'config': {'num_conv_layers': 2,
#    'kernel_sizes': [3, 4],
#    'channels': [16, 32],
#    'batch_size': 64,
#    'dropout': 0.0,
#    'dense_hidden': 64},
#   'micro_f1': 0.011411972196285923,
#   'weighted_f1': 0.0205224770847449,
#   'samples_f1': 0.00423634336677815,
#   'mean_f1': 0.01205693088260299}]

# %%
model_class = utils.load_model_class(MODEL_NAME)
model = model_class((256, 256), configs[0]['config'], len(mappings))

# %%
batch_size = configs[0]['config']['batch_size']

# %% [markdown]
# # Spectograms Creation

# %%
SPECS_TRAIN_PATH = f"{DATASET_PATH}/train_specs"
SPECS_VALID_PATH = f"{DATASET_PATH}/valid_specs"
SPECS_TEST_PATH = f"{DATASET_PATH}/test_specs"
os.makedirs(SPECS_TRAIN_PATH, exist_ok=True)
os.makedirs(SPECS_VALID_PATH, exist_ok=True)
os.makedirs(SPECS_TEST_PATH, exist_ok=True)
utils.specs_generation(TRAIN_PATH, SPECS_TRAIN_PATH, dataset_config['mappings'])
utils.specs_generation(VALID_PATH, SPECS_VALID_PATH, dataset_config['mappings'])
utils.specs_generation(TEST_PATH, SPECS_TEST_PATH, dataset_config['mappings'])
# Out:
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# Processing: Aeroplane
# Processing: Muscicapa striata_Spotted Flycatcher
# Processing: Periparus ater_Coal Tit
# Processing: Regulus regulus_Goldcrest
# Processing: Anthus trivialis_Tree Pipit
# Processing: Vegetation
# Processing: Troglodytes troglodytes_Eurasian Wren
# Processing: Erithacus rubecula_European Robin
# Processing: None
# Processing: Parus major_Great Tit
# Processing: Certhia familiaris_Eurasian Treecreeper
# Processing: Phylloscopus collybita_Common Chiffchaff
# Processing: Coccothraustes coccothraustes_Hawfinch
# Processing: Wind
# Processing: Turdus merula_Eurasian Blackbird
# Processing: Loxia curvirostra_Common Crossbill
# Processing: Regulus ignicapilla_Common Firecrest
# Processing: Sylvia atricapilla_Eurasian Blackcap
# Processing: Lophophanes cristatus_Crested Tit
# Processing: Fringilla coelebs_Common Chaffinch
# '✅ Spettrogrammi generati e salvati.'

# %% [markdown]
# # Model

# %%
def train_model(dataset_config, model, model_name, dataset_var, epochs=10, batch_size=100, lr=1e-5, patience=3, early_stop_patience=15, print_freq=100, load_weights=False):
    history_loss = []
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training {model_name} on: {device}")

    model.to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=patience
    )
    history_loss = []
    history_valid_loss = []
    best_loss = float("inf")

    saving_path = f'models/{model_name}/{dataset_var}/checkpoint.pth'
    if load_weights:
        if not os.path.exists(saving_path):
            print("No weights found!")
            return None
        checkpoint = torch.load(saving_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        history_loss = checkpoint['history_loss']
        history_valid_loss = checkpoint['history_valid_loss']
        best_loss = checkpoint['best_loss']
        starting_epoch = len(history_loss)
        print(f"Model Loaded!")
        
    print("Loading training data...")
    train_loader, valid_loader = utils.get_dataloader(dataset_config, split="train", batch_size=batch_size, split_ratio=0.15)
    print("Loaded!")
    
    model.train()
    early_stop_counter = 0
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        print(f"\n🎯 Starting epoch {epoch + 1}/{epochs}")

        for batch_index, (mel_spec, labels, _) in enumerate(train_loader):
            mel_spec = mel_spec.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(mel_spec)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            
            if batch_index % print_freq == 0:
                print('Epoch: [{0}][{1}/{2}], Loss: {loss:.5f}'.format(epoch, batch_index, len(train_loader), loss=loss))

        train_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch + 1} - Train Loss: {train_loss:.5f}")

        # Validation phase
        model.eval()
        with torch.no_grad():
            valid_loss = 0.0
            for mel_spec, labels, _ in valid_loader:
                mel_spec = mel_spec.to(device)
                labels = labels.to(device)
                outputs = model(mel_spec)
                loss = criterion(outputs, labels)
                valid_loss += loss.item()

            valid_loss /= len(valid_loader)
        
        history_loss.append(train_loss)
        history_valid_loss.append(valid_loss)
        scheduler.step(valid_loss)
        
        np.save(f'models/{model_name}/{dataset_var}/history_loss.npy', history_loss)
        np.save(f'models/{model_name}/{dataset_var}/history_valid_loss.npy', history_valid_loss)
        if valid_loss < best_loss:
            best_loss = valid_loss
            early_stop_counter = 0
            print(f"💾 Saving improved model at epoch {epoch+1} with Valid loss={valid_loss:.5f}")
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'history_valid_loss': history_valid_loss,
                'history_loss': history_loss,
                'best_loss': best_loss,
            }, saving_path)
        else:
            early_stop_counter += 1
            print(f"🛑 No improvement — early stop counter: {early_stop_counter}/{early_stop_patience}")

        print(f"🔁 Epoch {epoch+1} completed - valid loss: {valid_loss:.7f} - LR: {optimizer.param_groups[0]['lr']:.1e}")

        if early_stop_counter >= early_stop_patience:
            print(f"\n🚨 Early stopping triggered after {early_stop_patience} epochs without improvement.")
            break

    torch.save(model.state_dict(), f"models/{model_name}/{dataset_var}/final_weights.pth")
    print("✅ Training completed")


    return model

# %%
os.makedirs(f'models/{MODEL_NAME}/{DATASET_VAR}', exist_ok=True)
model = train_model(dataset_config, model, model_name=MODEL_NAME, dataset_var=DATASET_VAR, epochs=200, batch_size=batch_size, lr=1e-4, load_weights=False)
# Out:
# Training CustomCNN on: cuda
# Loading training data...
# Loaded!
#
# 🎯 Starting epoch 1/200
# Epoch: [0][0/154], Loss: 0.68493
# Epoch: [0][100/154], Loss: 0.20830
# Epoch 1 - Train Loss: 0.24410
# 💾 Saving improved model at epoch 1 with Valid loss=0.21027
# 🔁 Epoch 1 completed - valid loss: 0.2102746 - LR: 1.0e-04
#
# 🎯 Starting epoch 2/200
# Epoch: [1][0/154], Loss: 0.21371
# Epoch: [1][100/154], Loss: 0.17209
# Epoch 2 - Train Loss: 0.18820
# 💾 Saving improved model at epoch 2 with Valid loss=0.17013
# 🔁 Epoch 2 completed - valid loss: 0.1701318 - LR: 1.0e-04
#
# 🎯 Starting epoch 3/200
# Epoch: [2][0/154], Loss: 0.16301
# Epoch: [2][100/154], Loss: 0.14136
# Epoch 3 - Train Loss: 0.15867
# 💾 Saving improved model at epoch 3 with Valid loss=0.14603
# 🔁 Epoch 3 completed - valid loss: 0.1460273 - LR: 1.0e-04
#
# 🎯 Starting epoch 4/200
# Epoch: [3][0/154], Loss: 0.13901
# Epoch: [3][100/154], Loss: 0.13806
# Epoch 4 - Train Loss: 0.14127
# 💾 Saving improved model at epoch 4 with Valid loss=0.13546
# 🔁 Epoch 4 completed - valid loss: 0.1354574 - LR: 1.0e-04
#
# 🎯 Starting epoch 5/200
# Epoch: [4][0/154], Loss: 0.13196
# Epoch: [4][100/154], Loss: 0.12932
# Epoch 5 - Train Loss: 0.13065
# 💾 Saving improved model at epoch 5 with Valid loss=0.12850
# 🔁 Epoch 5 completed - valid loss: 0.1285020 - LR: 1.0e-04
#
# 🎯 Starting epoch 6/200
# Epoch: [5][0/154], Loss: 0.12825
# Epoch: [5][100/154], Loss: 0.11020
# Epoch 6 - Train Loss: 0.12297
# 💾 Saving improved model at epoch 6 with Valid loss=0.12050
# 🔁 Epoch 6 completed - valid loss: 0.1204993 - LR: 1.0e-04
#
# 🎯 Starting epoch 7/200
# Epoch: [6][0/154], Loss: 0.12456
# Epoch: [6][100/154], Loss: 0.12716
# Epoch 7 - Train Loss: 0.11694
# 💾 Saving improved model at epoch 7 with Valid loss=0.11751
# 🔁 Epoch 7 completed - valid loss: 0.1175096 - LR: 1.0e-04
#
# 🎯 Starting epoch 8/200
# Epoch: [7][0/154], Loss: 0.10880
# Epoch: [7][100/154], Loss: 0.10401
# Epoch 8 - Train Loss: 0.11151
# 💾 Saving improved model at epoch 8 with Valid loss=0.11278
# 🔁 Epoch 8 completed - valid loss: 0.1127833 - LR: 1.0e-04
#
# 🎯 Starting epoch 9/200
# Epoch: [8][0/154], Loss: 0.10460
# Epoch: [8][100/154], Loss: 0.10813
# Epoch 9 - Train Loss: 0.10678
# 💾 Saving improved model at epoch 9 with Valid loss=0.10928
# 🔁 Epoch 9 completed - valid loss: 0.1092780 - LR: 1.0e-04
#
# 🎯 Starting epoch 10/200
# Epoch: [9][0/154], Loss: 0.10096
# Epoch: [9][100/154], Loss: 0.09020
# Epoch 10 - Train Loss: 0.10291
# 💾 Saving improved model at epoch 10 with Valid loss=0.10775
# 🔁 Epoch 10 completed - valid loss: 0.1077485 - LR: 1.0e-04
#
# 🎯 Starting epoch 11/200
# Epoch: [10][0/154], Loss: 0.10039
# Epoch: [10][100/154], Loss: 0.08590
# Epoch 11 - Train Loss: 0.09923
# 💾 Saving improved model at epoch 11 with Valid loss=0.10667
# 🔁 Epoch 11 completed - valid loss: 0.1066703 - LR: 1.0e-04
#
# 🎯 Starting epoch 12/200
# Epoch: [11][0/154], Loss: 0.10041
# Epoch: [11][100/154], Loss: 0.09335
# Epoch 12 - Train Loss: 0.09565
# 💾 Saving improved model at epoch 12 with Valid loss=0.10240
# 🔁 Epoch 12 completed - valid loss: 0.1023959 - LR: 1.0e-04
#
# 🎯 Starting epoch 13/200
# Epoch: [12][0/154], Loss: 0.08772
# Epoch: [12][100/154], Loss: 0.09771
# Epoch 13 - Train Loss: 0.09178
# 💾 Saving improved model at epoch 13 with Valid loss=0.10087
# 🔁 Epoch 13 completed - valid loss: 0.1008710 - LR: 1.0e-04
#
# 🎯 Starting epoch 14/200
# Epoch: [13][0/154], Loss: 0.09664
# Epoch: [13][100/154], Loss: 0.09331
# Epoch 14 - Train Loss: 0.08869
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 14 completed - valid loss: 0.1010334 - LR: 1.0e-04
#
# 🎯 Starting epoch 15/200
# Epoch: [14][0/154], Loss: 0.09212
# Epoch: [14][100/154], Loss: 0.08591
# Epoch 15 - Train Loss: 0.08494
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 15 completed - valid loss: 0.1011801 - LR: 1.0e-04
#
# 🎯 Starting epoch 16/200
# Epoch: [15][0/154], Loss: 0.07481
# Epoch: [15][100/154], Loss: 0.07597
# Epoch 16 - Train Loss: 0.08263
# 💾 Saving improved model at epoch 16 with Valid loss=0.10038
# 🔁 Epoch 16 completed - valid loss: 0.1003810 - LR: 1.0e-04
#
# 🎯 Starting epoch 17/200
# Epoch: [16][0/154], Loss: 0.09706
# Epoch: [16][100/154], Loss: 0.07282
# Epoch 17 - Train Loss: 0.07931
# 💾 Saving improved model at epoch 17 with Valid loss=0.09724
# 🔁 Epoch 17 completed - valid loss: 0.0972435 - LR: 1.0e-04
#
# 🎯 Starting epoch 18/200
# Epoch: [17][0/154], Loss: 0.06688
# Epoch: [17][100/154], Loss: 0.07814
# Epoch 18 - Train Loss: 0.07686
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 18 completed - valid loss: 0.1003109 - LR: 1.0e-04
#
# 🎯 Starting epoch 19/200
# Epoch: [18][0/154], Loss: 0.07140
# Epoch: [18][100/154], Loss: 0.07233
# Epoch 19 - Train Loss: 0.07398
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 19 completed - valid loss: 0.0990119 - LR: 1.0e-04
#
# 🎯 Starting epoch 20/200
# Epoch: [19][0/154], Loss: 0.06489
# Epoch: [19][100/154], Loss: 0.08467
# Epoch 20 - Train Loss: 0.07185
# 🛑 No improvement — early stop counter: 3/10
# 🔁 Epoch 20 completed - valid loss: 0.0994403 - LR: 1.0e-04
#
# 🎯 Starting epoch 21/200
# Epoch: [20][0/154], Loss: 0.07463
# Epoch: [20][100/154], Loss: 0.07601
# Epoch 21 - Train Loss: 0.06877
# 💾 Saving improved model at epoch 21 with Valid loss=0.09671
# 🔁 Epoch 21 completed - valid loss: 0.0967074 - LR: 1.0e-04
#
# 🎯 Starting epoch 22/200
# Epoch: [21][0/154], Loss: 0.06127
# Epoch: [21][100/154], Loss: 0.05367
# Epoch 22 - Train Loss: 0.06614
# 🛑 No improvement — early stop counter: 1/10
# 🔁 Epoch 22 completed - valid loss: 0.0992171 - LR: 1.0e-04
#
# 🎯 Starting epoch 23/200
# Epoch: [22][0/154], Loss: 0.06903
# Epoch: [22][100/154], Loss: 0.06445
# Epoch 23 - Train Loss: 0.06400
# 🛑 No improvement — early stop counter: 2/10
# 🔁 Epoch 23 completed - valid loss: 0.1013992 - LR: 1.0e-04
#
# 🎯 Starting epoch 24/200
# Epoch: [23][0/154], Loss: 0.06361
# Epoch: [23][100/154], Loss: 0.05554
# Epoch 24 - Train Loss: 0.06166
# 🛑 No improvement — early stop counter: 3/10
# 🔁 Epoch 24 completed - valid loss: 0.1048895 - LR: 1.0e-04
#
# 🎯 Starting epoch 25/200
# Epoch: [24][0/154], Loss: 0.05625
# Epoch: [24][100/154], Loss: 0.05179
# Epoch 25 - Train Loss: 0.06011
# 🛑 No improvement — early stop counter: 4/10
# 🔁 Epoch 25 completed - valid loss: 0.1024270 - LR: 5.0e-05
#
# 🎯 Starting epoch 26/200
# Epoch: [25][0/154], Loss: 0.05356
# Epoch: [25][100/154], Loss: 0.04912
# Epoch 26 - Train Loss: 0.05425
# 🛑 No improvement — early stop counter: 5/10
# 🔁 Epoch 26 completed - valid loss: 0.1025730 - LR: 5.0e-05
#
# 🎯 Starting epoch 27/200
# Epoch: [26][0/154], Loss: 0.05664
# Epoch: [26][100/154], Loss: 0.05943
# Epoch 27 - Train Loss: 0.05197
# 🛑 No improvement — early stop counter: 6/10
# 🔁 Epoch 27 completed - valid loss: 0.1067315 - LR: 5.0e-05
#
# 🎯 Starting epoch 28/200
# Epoch: [27][0/154], Loss: 0.04432
# Epoch: [27][100/154], Loss: 0.04623
# Epoch 28 - Train Loss: 0.05123
# 🛑 No improvement — early stop counter: 7/10
# 🔁 Epoch 28 completed - valid loss: 0.1078378 - LR: 5.0e-05
#
# 🎯 Starting epoch 29/200
# Epoch: [28][0/154], Loss: 0.04224
# Epoch: [28][100/154], Loss: 0.06108
# Epoch 29 - Train Loss: 0.04995
# 🛑 No improvement — early stop counter: 8/10
# 🔁 Epoch 29 completed - valid loss: 0.1095137 - LR: 2.5e-05
#
# 🎯 Starting epoch 30/200
# Epoch: [29][0/154], Loss: 0.05510
# Epoch: [29][100/154], Loss: 0.05973
# Epoch 30 - Train Loss: 0.04696
# 🛑 No improvement — early stop counter: 9/10
# 🔁 Epoch 30 completed - valid loss: 0.1106470 - LR: 2.5e-05
#
# 🎯 Starting epoch 31/200
# Epoch: [30][0/154], Loss: 0.04378
# Epoch: [30][100/154], Loss: 0.04169
# Epoch 31 - Train Loss: 0.04591
# 🛑 No improvement — early stop counter: 10/10
# 🔁 Epoch 31 completed - valid loss: 0.1112897 - LR: 2.5e-05
#
# 🚨 Early stopping triggered after 10 epochs without improvement.
# ✅ Training completed

# %%
import numpy as np
history_loss = np.load(f'models/{MODEL_NAME}/{DATASET_VAR}/history_loss.npy')
plt.figure(figsize=(8, 5))
plt.plot(history_loss, linestyle='-', color='tomato', label="Loss")
# plt.title(title)
plt.xlabel("Epoch")
# plt.ylabel(ylabel)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
torch.cuda.empty_cache()
os.getpid()
# Out:
# 10833
