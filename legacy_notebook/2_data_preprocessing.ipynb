# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns
import json
import librosa
import soundfile as sf
import random
import pandas as pd
from pydub import AudioSegment
from tqdm import tqdm

# %%
DATASET_NAME = 'dataset'
AUDIO_SOURCE = '/home/giacomoschiavo/Tovanella'

# %%
DATASET_PATH = f'/home/giacomoschiavo/segments/{DATASET_NAME}'
TRAIN_PATH = f'/home/giacomoschiavo/segments/{DATASET_NAME}/train'
VALID_PATH = f'/home/giacomoschiavo/segments/{DATASET_NAME}/valid'
TEST_PATH = f'/home/giacomoschiavo/segments/{DATASET_NAME}/test'

# %%
species_list = set(os.listdir(TEST_PATH)).intersection(set(os.listdir(TRAIN_PATH)))

# %%
def print_dataset_count_table(dataset_path):
    train_folder = f"{dataset_path}/train"
    valid_folder = f"{dataset_path}/valid"
    test_folder = f"{dataset_path}/test"

    dataset_count = {}
    for species in os.listdir(test_folder):
        dataset_count[species] = {
            "train": len(os.listdir(os.path.join(train_folder, species))) if os.path.exists(os.path.join(train_folder, species)) else 0,
            "valid": len(os.listdir(os.path.join(valid_folder, species))) if os.path.exists(os.path.join(valid_folder, species)) else 0,
            "test": len(os.listdir(os.path.join(test_folder, species))) if os.path.exists(os.path.join(test_folder, species)) else 0
        }

    dataset_species_count_df = pd.DataFrame.from_dict(dataset_count, orient='index')
    dataset_species_count_df.index.name = 'Species'
    return dataset_species_count_df.sort_values(by=["test"], ascending=False)

# %%
print_dataset_count_table(DATASET_PATH)
# Out:
#                                           train  valid  test
# Species
# None                                      15257      0  5116
# Fringilla coelebs_Common Chaffinch         7310      0   981
# Phylloscopus collybita_Common Chiffchaff   2172      0   669
# Erithacus rubecula_European Robin          1616      0   549
# Sylvia atricapilla_Eurasian Blackcap       3782      0   487
# Turdus merula_Eurasian Blackbird            728      0   307
# Regulus ignicapilla_Common Firecrest       3172      0   231
# Wind                                        411      0   146
# Troglodytes troglodytes_Eurasian Wren      1361      0   111
# Vegetation                                  206      0    26
# Aeroplane                                    82      0    22
# Periparus ater_Coal Tit                     993      0    20
# Anthus trivialis_Tree Pipit                 803      0    17
# Muscicapa striata_Spotted Flycatcher        271      0    14
# Regulus regulus_Goldcrest                   785      0    10
# Thunder                                       0      0     9
# Engine_Engine                                15      0     8
# Parus major_Great Tit                        84      0     3
# Certhia familiaris_Eurasian Treecreeper     342      0     3
# Lophophanes cristatus_Crested Tit           141      0     3

# %%
print_dataset_count_table(DATASET_PATH)
# Out:
#                                           train  valid  test
# Species
# None                                      15257      0  5116
# Fringilla coelebs_Common Chaffinch         7310      0   981
# Sylvia atricapilla_Eurasian Blackcap       3782      0   487
# Regulus ignicapilla_Common Firecrest       3172      0   231
# Phylloscopus collybita_Common Chiffchaff   2172      0   669
# Erithacus rubecula_European Robin          1616      0   549
# Troglodytes troglodytes_Eurasian Wren      1361      0   111
# Periparus ater_Coal Tit                     993      0    20
# Anthus trivialis_Tree Pipit                 803      0    17
# Regulus regulus_Goldcrest                   785      0    10
# Turdus merula_Eurasian Blackbird            728      0   307
# Wind                                        411      0   146
# Certhia familiaris_Eurasian Treecreeper     342      0     3
# Muscicapa striata_Spotted Flycatcher        271      0    14
# Vegetation                                  206      0    26
# Lophophanes cristatus_Crested Tit           141      0     3
# Parus major_Great Tit                        84      0     3
# Aeroplane                                    82      0    22
# Engine_Engine                                15      0     8
# Thunder                                       0      0     9

# %% [markdown]
# # Data division
# How the segments are automatically split into training and test set

# %%
# # # LOAD
# with open(f"utils/{DATASET_NAME}/species_date_count.json") as f:
#     species_date_count = json.load(f)

# %% [markdown]
# Get the count by date in each species

# %%
# get date count by species
target = f'{DATASET_PATH}/train'
species_date_count = {}
for species in species_list:
    if target not in species_date_count:
        species_date_count[species] = {}
    audio_names = os.listdir(os.path.join(target, species))
    date_counts = { audio.split("_")[0]: 0 for audio in audio_names }
    for date in date_counts:
        species_date_count[species][date] = { "count": sum(date in audio for audio in audio_names), "is_training": False, "is_test": False}

# %%
# with open(f"utils/{DATASET_NAME}/species_date_count.json", 'w') as f:
#     json.dump(species_date_count, f)

# %%
species_in_test = os.listdir(f'{DATASET_PATH}/test')
species_in_train = os.listdir(f'{DATASET_PATH}/train')

# %%
# species ONLY in train, not in test
species_to_test = set(species_in_train).difference(species_in_test)
species_to_test
# Out:
# set()

# %%
# species in test and not present in train
set(species_in_test).difference(species_in_train)
# Out:
# set()

# %%
import copy
random_valid_species = []
manual_split = []
train_test_division = copy.deepcopy(species_date_count)
for species in train_test_division.keys():
    if species not in species_to_test:
        continue
    dates = list(train_test_division[species].keys())
    date_count = len(dates)
    values = [value["count"] for value in train_test_division[species].values()]
    if date_count <= 1:     # ignore
        print(f'{species} to be removed ❌')
        continue
    elif date_count == 2:
        random_valid_species.append(species)
        greatest_date = dates[np.argmax(values)]
        train_test_division[species][greatest_date]["is_training"] = True     # majority -> training
        lowest_date = dates[np.argmin(values)]
        train_test_division[species][lowest_date]["is_test"] = True     # minority -> test
    else:
        random_valid_species.append(species)
        manual_split.append(species)
        print(f'{species} needs a manual split! 👨‍🔧')

# %% [markdown]
# ## Manual Split

# %%
manual_split
# Out:
# []

# %%
# {'20190608': {'count': 51, 'is_training': False, 'is_test': False},
#  '20200217': {'count': 21, 'is_training': False, 'is_test': False},
#  '20200215': {'count': 3, 'is_training': False, 'is_test': False}}

train_test_division['Dryocopus martius_Black Woodpecker']['20190608']['is_training'] = True
train_test_division['Dryocopus martius_Black Woodpecker']['20200217']['is_test'] = True
train_test_division['Dryocopus martius_Black Woodpecker']['20190608']['is_training'] = True
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 6
#       1 # {'20190608': {'count': 51, 'is_training': False, 'is_test': False},
#       2 #  '20200217': {'count': 21, 'is_training': False, 'is_test': False},
#       3 #  '20200215': {'count': 3, 'is_training': False, 'is_test': False}}
#       5 train_test_division['Dryocopus martius_Black Woodpecker']['20190608']['is_training'] = True
# ----> 6 train_test_division['Dryocopus martius_Black Woodpecker']['20200217']['is_test'] = True
#       7 train_test_division['Dryocopus martius_Black Woodpecker']['20190608']['is_training'] = True
#
# KeyError: '20200217'

# %%
# {'20190608': {'count': 2141, 'is_training': False, 'is_test': False},
#  '20190603': {'count': 2042, 'is_training': False, 'is_test': False},
#  '20190621': {'count': 58, 'is_training': False, 'is_test': False}}
train_test_division['Turdus philomelos_Song Thrush']['20190608']['is_training'] = True
train_test_division['Turdus philomelos_Song Thrush']['20190603']['is_training'] = True
train_test_division['Turdus philomelos_Song Thrush']['20190621']['is_test'] = True

# %% [markdown]
# # How to split data in training and test set?
# + 1 date: ignore
# + Only 2 dates: minority -> test, majority -> training
# + More than 2 dates: take the majority and calculate the sum of all the other dates; if the sum is greater than half majority, move the biggest element in the minority into the majority and check again the sum

# %%
for species in train_test_division.keys():
    if species in species_to_test:
        continue
    dates = list(train_test_division[species].keys())
    date_count = len(dates)
    values = [value["count"] for value in train_test_division[species].values()]
    if date_count <= 1:    
        train_test_division[species][dates[0]]['is_training'] = True
        random_valid_species.append(species)
        continue
    elif date_count == 2:
        greatest_date = dates[np.argmax(values)]
        train_test_division[species][greatest_date]["is_training"] = True
    else:
        greatest_value_index = np.argmax(values)
        greatest_value_date = dates[greatest_value_index]
        greatest_value = train_test_division[species][greatest_value_date]["count"]
        train_test_division[species][greatest_value_date]["is_training"] = True
        other_values = [value["count"] if value["is_training"] == False else 0 for value in train_test_division[species].values()]
        sum_other_values = sum(other_values)
        while sum_other_values > greatest_value / 3:
            greatest_value_index = np.argmax(other_values)
            greatest_value_date = dates[greatest_value_index]
            train_test_division[species][greatest_value_date]["is_training"] = True            
            sum_other_values -= train_test_division[species][greatest_value_date]["count"]

# %%
train_test_division['random_valid_species'] = random_valid_species

# %%
# SAVE
# with open(f"utils/{DATASET_NAME}/train_test_division.json", 'w') as f:
#     json.dump(train_test_division, f)

# %% [markdown]
# # Split Representation

# %%
# Supponiamo che 'species_date_count' contenga i tuoi dati
n_species = len(train_test_division.keys())

cols = 4
rows = (n_species // cols) + (n_species % cols != 0) 

fig, axes = plt.subplots(rows, cols, figsize=(18, 3 * rows))
axes = axes.flatten()

for i, species in enumerate(train_test_division.keys()):
    dates = list(train_test_division[species].keys())
    counts = [value["count"] for value in train_test_division[species].values()]
    if len(dates) > 1:
        is_training = ["Training" if value["is_training"] else "Valid" for value in train_test_division[species].values()]
    else:
        is_training = ["Training"]
    sns.barplot(x=dates, y=counts, ax=axes[i], hue=is_training)

    for j, count in enumerate(counts):
        axes[i].text(j, count + 0.1, str(count), ha='center', va='bottom')
    axes[i].set_title(species)
    axes[i].tick_params(axis='x', rotation=30)  # Ruota le etichette sull'asse x se necessario

for i in range(n_species, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()  # Aggiusta lo spazio tra i grafici
plt.show()

# %% [markdown]
# # Test set creation
# Here we move the segments from the source (all the segments divided by species) to the test set, as the species_date_count describes

# %%
os.makedirs(TEST_PATH, exist_ok=True)
os.makedirs(VALID_PATH, exist_ok=True)

# %% [markdown]
# First, integrate the test set with the labels from the training set

# %%
for species in species_to_test:
    os.makedirs(os.path.join(TEST_PATH, species), exist_ok=True)
    dates = train_test_division[species].keys()
    if len(dates) == 1:
        print(f'{species} is ignored (not enough data)')
        continue
    for date in dates:
        if train_test_division[species][date]['is_test']:
            all_audio = [audio for audio in os.listdir(os.path.join(TRAIN_PATH, species)) if date in audio]
            for audio in all_audio:
                os.rename(
                    os.path.join(TRAIN_PATH, species, audio),
                    os.path.join(TEST_PATH, species, audio)
                )
            print(f'{species} is integrated in the test set!')
# Out:
# Turdus philomelos_Song Thrush is integrated in the test set!
# Poecile palustris_Marsh Tit is ignored (not enough data)
# Dryocopus martius_Black Woodpecker is integrated in the test set!
# Rain is integrated in the test set!
# Dendrocopos major_Great Spotted Woodpecker is integrated in the test set!
# Bat is ignored (not enough data)
# unknown is ignored (not enough data)
# Glaucidium passerinum_Eurasian Pygmy-Owl is ignored (not enough data)
# Loxia curvirostra_Common Crossbill is integrated in the test set!
# Prunella modularis_Dunnock is ignored (not enough data)
# Phylloscopus trochilus_Willow Warbler is ignored (not enough data)
# Pyrrhula pyrrhula_Eurasian Bullfinch is ignored (not enough data)
# Insect is ignored (not enough data)
# Pecking is integrated in the test set!
# Turdus viscivorus_Mistle Thrush is ignored (not enough data)

# %% [markdown]
# # Validation creation

# %% [markdown]
# Prendiamo sempre 1/5 random del training set. (80/20)
#
# ATTENZIONE: siccome e' random, bisogna salvare in un file gli esempi spostati in modo da poter annullare lo spostamento

# %%
random_valid_species
# Out:
# ['Rain',
#  'Dryocopus martius_Black Woodpecker',
#  'Loxia curvirostra_Common Crossbill',
#  'Pecking',
#  'Dendrocopos major_Great Spotted Woodpecker',
#  'Turdus philomelos_Song Thrush',
#  'Aeroplane',
#  'Phylloscopus collybita_Common Chiffchaff']

# %%
def move_random_valid(random_valid_species, train_path, valid_path, valid_ratio=0.2):
    np.random.seed(42)
    for species in random_valid_species:
        species_audio = os.listdir(os.path.join(train_path, species))
        selected_audio = np.random.choice(species_audio, int(len(species_audio) * valid_ratio), replace=False)
        species_dir_path = os.path.join(valid_path, species)
        if os.path.exists(species_dir_path):
            continue
        os.makedirs(species_dir_path, exist_ok=True)
        for audio in selected_audio:
            os.rename(
                os.path.join(train_path, species, audio),
                os.path.join(valid_path, species, audio)
            )

# %%
VALID_RATIO = 0.2
move_random_valid(random_valid_species, TRAIN_PATH, VALID_PATH, valid_ratio=VALID_RATIO)

# %%
def move_to_valid(train_test_division, train_path, valid_path):
    random_valid_species = train_test_division['random_valid_species']
    for species, dates in train_test_division.items():
        if species in random_valid_species:
            continue
        if isinstance(dates, list):     # ignores random_valid_species
            continue
        if len(dates) == 1:
            date_info = train_test_division[species][list(dates.keys())[0]] 
            print(species)
            if date_info['is_training'] is False:
                continue
        for date, info in dates.items():
            if info['is_training'] is False and info['is_test'] is False:   # move to valid
                species_dir_path = os.path.join(valid_path, species)
                if os.path.exists(species_dir_path):
                    continue
                os.makedirs(species_dir_path, exist_ok=True)
                for audio in os.listdir(os.path.join(train_path, species)):
                    if date in audio:
                        os.rename(
                            os.path.join(train_path, species, audio),
                            os.path.join(species_dir_path, audio)
                        )

# %%
move_to_valid(train_test_division, TRAIN_PATH, VALID_PATH)
# Out:
# unknown
# Glaucidium passerinum_Eurasian Pygmy-Owl
# Poecile palustris_Marsh Tit
# Phylloscopus trochilus_Willow Warbler
# Pyrrhula pyrrhula_Eurasian Bullfinch
# Turdus viscivorus_Mistle Thrush
# Bat
# Insect
# Prunella modularis_Dunnock

# %%
len(os.listdir(TRAIN_PATH)), len(os.listdir(TEST_PATH)), len(os.listdir(VALID_PATH))
# Out:
# (22, 22, 22)

# %% [markdown]
# Manteniamo solo le specie in cui sono presenti elementi nei tre set

# %%
valid_species = os.listdir(VALID_PATH)
REMOVED_PATH = f'{DATASET_PATH}/removed'
os.makedirs(REMOVED_PATH, exist_ok=True)
REMOVED_TRAIN_PATH = f'{REMOVED_PATH}/train'
os.makedirs(REMOVED_TRAIN_PATH, exist_ok=True)
for species in os.listdir(TRAIN_PATH):
    if species not in valid_species:
        os.makedirs(os.path.join(REMOVED_TRAIN_PATH, species), exist_ok=True)
        os.rename(
            os.path.join(TRAIN_PATH, species),
            os.path.join(REMOVED_TRAIN_PATH, species)
        )

# %%
valid_species = os.listdir(VALID_PATH)
REMOVED_TEST_PATH = f'{REMOVED_PATH}/test'
os.makedirs(REMOVED_TEST_PATH, exist_ok=True)
for species in os.listdir(TEST_PATH):
    if species not in valid_species:
        os.makedirs(os.path.join(REMOVED_TEST_PATH, species), exist_ok=True)
        os.rename(
            os.path.join(TEST_PATH, species),
            os.path.join(REMOVED_TEST_PATH, species)
        )

# %%
    # for audio in os.listdir(os.path.join(TRAIN_PATH, species)):
    #     test_dates = [date for date in train_test_division[species].keys() 
    #                   if train_test_division[species][date]["is_training"] == False]
    #     audio_date = audio.split("_")[0]
    #     if audio_date in test_dates:
    #         source = os.path.join(TRAIN_PATH, species, audio)
    #         dest = os.path.join(TEST_PATH, species, audio)
    #         os.rename(source, dest)

# %%
# # MOVE EVERYTHING BACK TO TRAINING
# train_folder = f"E:/Giacomo/Tovanella/{DATASET_NAME}/train"
# test_folder = f"E:/Giacomo/Tovanella/{DATASET_NAME}/test"
# valid_folder = f"E:/Giacomo/Tovanella/{DATASET_NAME}/valid"
# removed = f"E:/Giacomo/Tovanella/{DATASET_NAME}/removed"

# for species in os.listdir(test_folder):
    # for audio in os.listdir(os.path.join(test_folder, species)):
    #     os.rename(
    #         os.path.join(test_folder, species, audio),
    #         os.path.join(train_folder, species, audio),
    #     )
# for species in os.listdir(removed):
#     os.rename(
#         os.path.join(removed, species),
#         os.path.join(train_folder, species),
#     )

# %% [markdown]
# # Sample Removal

# %%
train_folder = f"{DATASET_PATH}/train"
train_removed = f"{DATASET_PATH}/train_removed"

# %%
for species in os.listdir(train_removed):
    all_audio = os.listdir(os.path.join(train_removed, species))
    for audio in all_audio:
        os.rename(
            os.path.join(train_removed, species, audio),
            os.path.join(train_folder, species, audio)
        )

# %%
for species in os.listdir(train_folder):
    if species != 'None':
        continue
    all_audio = os.listdir(os.path.join(train_folder, species))
    if len(all_audio) <= 100:
        continue
    random.shuffle(all_audio)
    os.makedirs(os.path.join(train_removed, species), exist_ok=True)
    chosen_audio = all_audio[:1000]
    for audio in all_audio:
        if audio in chosen_audio:
            continue
        print(species, audio)
        os.rename(
            os.path.join(train_folder, species, audio),
            os.path.join(train_removed, species, audio)
        )
# Out:
# None 20190621_010000_75_0.wav
# None XC668297_0_61_5.wav
# None 20190603_160000_450_0.wav
# None 20200215_090000_49_5.wav
# None 20190621_110000_120_0.wav
# None 20190603_190000_499_5.wav
# None XC870807_0_33_0.wav
# None 20190607_110000_382_5.wav
# None 20190621_210000_135_0.wav
# None 20190621_210000_286_5.wav
# None 20200217_000000_541_5.wav
# None 20190603_160000_322_5.wav
# None 20190607_080000_487_5.wav
# None 20200217_070000_240_0.wav
# None 20200217_110000_144_0.wav
# None 20190603_160000_376_5.wav
# None 20190621_020000_469_5.wav
# None 20190603_170000_321_0.wav
# None 20190603_140000_444_0.wav
# None 20190603_050000_219_0.wav
# None 20190603_090000_66_0.wav
# None 20200215_090000_90_0.wav
# None 20200215_110000_409_5.wav
# None 20190603_170000_330_0.wav
# None 20200215_090000_93_0.wav
# None XC980998_0_4_5.wav
# None 20200217_160000_282_0.wav
# None 20200215_100000_541_5.wav
# None 20200217_160000_228_0.wav
# None 20190603_230000_276_0.wav
# None 20190603_130000_177_0.wav
# None 20200217_160000_76_5.wav
# None 20190603_180000_132_0.wav
# None 20190607_080000_255_0.wav
# None 20200215_120000_154_5.wav
# None 20200217_120000_156_0.wav
# None 20190621_140000_0_0.wav
# None 20190612_020000_502_5.wav
# None 20200215_070000_472_5.wav
# None 20200217_070000_520_5.wav
# None 20200217_120000_273_0.wav
# None 20190621_090000_514_5.wav
# None 20200217_070000_85_5.wav
# None 20190612_020000_186_0.wav
# None 20190621_010000_63_0.wav
# None XC978938_0_34_5.wav
# None 20200217_160000_147_0.wav
# None 20190603_110000_336_0.wav
# None XC761451_0_15_0.wav
# None 20190607_090000_459_0.wav
# None 20200217_140000_255_0.wav
# None 20190621_150000_445_5.wav
# None 20200217_120000_84_0.wav
# None 20190621_010000_508_5.wav
# None XC900653_0_7_5.wav
# None 20200215_070000_454_5.wav
# None 20200217_120000_255_0.wav
# None 20190621_160000_367_5.wav
# None 20190607_110000_315_0.wav
# None 20190621_010000_502_5.wav
# None 20190603_180000_499_5.wav
# None 20190603_170000_322_5.wav
# None 20190621_170000_417_0.wav
# None 20200217_000000_181_5.wav
# None 20200215_090000_508_5.wav
# None 20200215_070000_490_5.wav
# None 20190603_170000_178_5.wav
# None 20200215_070000_102_0.wav
# None 20200215_080000_505_5.wav
# None 20200217_120000_211_5.wav
# None 20200217_140000_394_5.wav
# None 20190612_020000_435_0.wav
# None 20200217_060000_300_0.wav
# None 20190607_120000_261_0.wav
# None 20190603_140000_340_5.wav
# None 20190603_170000_499_5.wav
# None 20190603_190000_88_5.wav
# None 20190603_150000_444_0.wav
# None 20200215_080000_105_0.wav
# None 20200215_100000_459_0.wav
# None 20190603_150000_439_5.wav
# None 20200217_160000_252_0.wav
# None 20190621_150000_151_5.wav
# None 20190621_010000_409_5.wav
# None 20190603_150000_250_5.wav
# None 20200215_060000_229_5.wav
# None 20200217_070000_360_0.wav
# None 20200217_160000_457_5.wav
# None 20200215_080000_282_0.wav
# None 20200217_110000_385_5.wav
# None 20200215_100000_3_0.wav
# None 20190603_180000_121_5.wav
# None 20190603_150000_147_0.wav
# None 20200217_090000_433_5.wav
# None 20200217_060000_259_5.wav
# None 20200215_100000_408_0.wav
# None 20200215_080000_259_5.wav
# None 20190603_120000_58_5.wav
# None 20200217_120000_423_0.wav
# None 20200217_070000_121_5.wav
# None 20190621_010000_283_5.wav
# None 20200217_090000_49_5.wav
# None 20200217_110000_117_0.wav
# None 20200217_160000_351_0.wav
# None 20200215_110000_114_0.wav
# None 20190603_110000_570_0.wav
# None 20200217_140000_163_5.wav
# None XC713961_0_42_0.wav
# None XC870807_0_43_5.wav
# None 20190621_020000_27_0.wav
# None 20190621_010000_426_0.wav
# None 20200217_090000_126_0.wav
# None 20200217_160000_555_0.wav
# None 20200217_060000_481_5.wav
# None 20200217_090000_243_0.wav
# None 20190603_130000_160_5.wav
# None 20190621_120000_249_0.wav
# None 20200217_000000_78_0.wav
# None 20190621_120000_267_0.wav
# None 20190603_150000_10_5.wav
# None 20190603_230000_279_0.wav
# None 20200217_110000_141_0.wav
# None 20190603_230000_121_5.wav
# None 20190603_130000_562_5.wav
# None 20200215_120000_376_5.wav
# None 20200215_110000_577_5.wav
# None 20190612_020000_315_0.wav
# None 20190621_120000_198_0.wav
# None 20200215_070000_571_5.wav
# None 20200217_090000_555_0.wav
# None 20200217_110000_418_5.wav
# None 20190621_150000_273_0.wav
# None 20200217_120000_265_5.wav
# None 20200217_090000_129_0.wav
# None 20200217_110000_255_0.wav
# None 20190621_140000_418_5.wav
# None 20200217_160000_583_5.wav
# None XC680900_0_6_0.wav
# None 20200217_110000_585_0.wav
# None 20190621_140000_36_0.wav
# None 20190607_080000_279_0.wav
# None 20200215_090000_486_0.wav
# None 20190603_150000_529_5.wav
# None 20200215_070000_318_0.wav
# None 20200215_090000_499_5.wav
# None 20190603_150000_195_0.wav
# None 20190603_150000_52_5.wav
# None 20200215_070000_159_0.wav
# None 20190607_100000_79_5.wav
# None 20190621_160000_447_0.wav
# None 20200217_070000_451_5.wav
# None 20190621_050000_285_0.wav
# None 20200217_060000_453_0.wav
# None 20190612_030000_292_5.wav
# None 20200215_110000_526_5.wav
# None 20200215_070000_391_5.wav
# None 20200215_070000_421_5.wav
# None 20190603_230000_118_5.wav
# None 20200215_100000_400_5.wav
# None 20200217_090000_241_5.wav
# None 20190621_020000_18_0.wav
# None 20190603_190000_513_0.wav
# None 20190621_210000_501_0.wav
# None 20190621_140000_201_0.wav
# None 20200217_070000_132_0.wav
# None 20190621_020000_423_0.wav
# None 20200215_120000_64_5.wav
# None 20200215_090000_420_0.wav
# None 20200215_070000_316_5.wav
# None 20190603_170000_238_5.wav
# None 20200217_120000_339_0.wav
# None 20190621_110000_60_0.wav
# None 20190621_110000_210_0.wav
# None 20190603_150000_184_5.wav
# None 20190621_090000_510_0.wav
# None 20200217_070000_199_5.wav
# None 20200215_070000_585_0.wav
# None 20190603_170000_438_0.wav
# None 20200217_000000_442_5.wav
# None 20190621_010000_105_0.wav
# None XC912998_0_25_5.wav
# None 20200215_100000_402_0.wav
# None 20200217_110000_49_5.wav
# None 20190603_090000_570_0.wav
# None 20190607_110000_54_0.wav
# None 20190621_150000_469_5.wav
# None XC680900_0_15_0.wav
# None 20200215_080000_219_0.wav
# None 20200217_000000_457_5.wav
# None 20190621_020000_222_0.wav
# None 20200217_120000_73_5.wav
# None 20200217_070000_573_0.wav
# None 20190621_020000_102_0.wav
# None 20200217_090000_169_5.wav
# None 20200217_110000_592_5.wav
# None 20190621_140000_220_5.wav
# None 20200215_060000_426_0.wav
# None 20190607_110000_346_5.wav
# None 20190621_010000_112_5.wav
# None 20190607_100000_27_0.wav
# None 20190621_020000_283_5.wav
# None XC721327_0_9_0.wav
# None 20200215_060000_283_5.wav
# None XC931635_0_12_0.wav
# None 20190607_090000_510_0.wav
# None 20200217_060000_27_0.wav
# None 20200215_110000_270_0.wav
# None 20190621_160000_493_5.wav
# None 20190621_140000_184_5.wav
# None 20200217_160000_538_5.wav
# None 20190607_080000_525_0.wav
# None 20200215_100000_9_0.wav
# None 20190612_020000_534_0.wav
# None 20190603_170000_514_5.wav
# None 20200217_090000_274_5.wav
# None 20190607_120000_78_0.wav
# None 20200217_160000_429_0.wav
# None 20190621_160000_444_0.wav
# None 20190603_140000_411_0.wav
# None 20200215_120000_490_5.wav
# None 20200217_160000_487_5.wav
# None XC912998_0_9_0.wav
# None 20190621_180000_181_5.wav
# None 20190621_150000_15_0.wav
# None 20200217_000000_529_5.wav
# None 20190621_210000_90_0.wav
# None 20200217_000000_382_5.wav
# None 20190621_140000_186_0.wav
# None 20190607_110000_589_5.wav
# None 20200215_080000_22_5.wav
# None 20190603_110000_535_5.wav
# None 20200217_160000_172_5.wav
# None 20190607_120000_594_0.wav
# None 20190603_230000_84_0.wav
# None 20190603_130000_136_5.wav
# None 20190603_230000_411_0.wav
# None 20200215_110000_225_0.wav
# None 20190621_020000_264_0.wav
# None 20190603_160000_298_5.wav
# None 20190603_070000_261_0.wav
# None 20200215_100000_283_5.wav
# None 20200215_060000_166_5.wav
# None 20190621_160000_315_0.wav
# None 20190603_140000_76_5.wav
# None 20190603_230000_393_0.wav
# None 20190612_020000_385_5.wav
# None 20190607_060000_51_0.wav
# None 20200215_110000_592_5.wav
# None 20190621_090000_544_5.wav
# None 20200217_070000_486_0.wav
# None 20200215_110000_145_5.wav
# None 20200217_060000_180_0.wav
# None 20190603_150000_204_0.wav
# None 20200215_100000_102_0.wav
# None 20200217_090000_283_5.wav
# None 20200215_110000_588_0.wav
# None 20200217_120000_483_0.wav
# None 20190607_100000_157_5.wav
# None 20190621_170000_211_5.wav
# None 20200217_060000_457_5.wav
# None 20190603_160000_84_0.wav
# None 20190603_170000_571_5.wav
# None 20190603_170000_213_0.wav
# None 20190621_160000_228_0.wav
# None 20200215_060000_172_5.wav
# None 20200217_000000_178_5.wav
# None 20200215_060000_438_0.wav
# None 20190603_130000_586_5.wav
# None 20190621_020000_255_0.wav
# None 20200217_060000_273_0.wav
# None 20200217_070000_562_5.wav
# None 20190603_160000_253_5.wav
# None 20200217_060000_123_0.wav
# None 20200215_080000_447_0.wav
# None 20200217_140000_210_0.wav
# None 20200217_110000_597_0.wav
# None 20190621_180000_223_5.wav
# None 20190612_020000_399_0.wav
# None 20190603_230000_294_0.wav
# None 20190607_110000_310_5.wav
# None 20200215_060000_475_5.wav
# None 20200217_140000_357_0.wav
# None 20190621_210000_139_5.wav
# None 20190621_010000_382_5.wav
# None 20190621_020000_217_5.wav
# None 20190607_090000_543_0.wav
# None 20200217_120000_250_5.wav
# None 20190603_170000_463_5.wav
# None 20190621_020000_534_0.wav
# None 20190603_110000_526_5.wav
# None 20200217_060000_451_5.wav
# None 20190621_020000_94_5.wav
# None 20190621_210000_442_5.wav
# None 20200217_070000_508_5.wav
# None 20190612_020000_243_0.wav
# None 20200217_070000_546_0.wav
# None 20190603_230000_528_0.wav
# None 20200217_060000_12_0.wav
# None 20200215_060000_178_5.wav
# None 20200217_120000_201_0.wav
# None 20190621_160000_163_5.wav
# None 20190603_160000_222_0.wav
# None 20190603_180000_417_0.wav
# None 20190607_120000_18_0.wav
# None 20190621_160000_354_0.wav
# None 20190603_190000_57_0.wav
# None 20200215_070000_198_0.wav
# None 20190603_160000_307_5.wav
# None 20200215_070000_252_0.wav
# None 20190621_010000_352_5.wav
# None 20200215_090000_457_5.wav
# None 20190603_160000_321_0.wav
# None 20190607_120000_63_0.wav
# None 20190603_230000_300_0.wav
# None 20190603_150000_216_0.wav
# None 20190612_020000_144_0.wav
# None 20200217_110000_348_0.wav
# None 20190621_150000_483_0.wav
# None 20190621_140000_244_5.wav
# None 20200215_070000_591_0.wav
# None 20200217_160000_408_0.wav
# None 20190621_180000_166_5.wav
# None 20200217_060000_307_5.wav
# None 20200217_000000_43_5.wav
# None 20190603_130000_124_5.wav
# None 20200217_090000_271_5.wav
# None 20200217_160000_486_0.wav
# None 20200217_000000_160_5.wav
# None XC902525_0_19_5.wav
# None 20200215_070000_477_0.wav
# None 20200215_080000_559_5.wav
# None 20190621_150000_184_5.wav
# None XC680900_0_18_0.wav
# None 20190612_020000_138_0.wav
# None 20200215_090000_477_0.wav
# None 20200217_160000_475_5.wav
# None 20200217_160000_597_0.wav
# None 20190621_090000_543_0.wav
# None 20190612_030000_315_0.wav
# None 20190603_160000_13_5.wav
# None 20190612_020000_423_0.wav
# None 20200215_120000_310_5.wav
# None 20200215_110000_585_0.wav
# None 20190603_130000_180_0.wav
# None 20200217_140000_472_5.wav
# None 20190603_230000_342_0.wav
# None 20190607_090000_519_0.wav
# None XC870807_0_31_5.wav
# None 20190607_120000_270_0.wav
# None 20200215_060000_258_0.wav
# None 20200217_110000_9_0.wav
# None 20190603_130000_258_0.wav
# None 20190621_020000_288_0.wav
# None 20190621_160000_540_0.wav
# None 20190603_130000_279_0.wav
# None 20200215_120000_283_5.wav
# None 20190603_160000_277_5.wav
# None 20200215_090000_187_5.wav
# None 20200215_070000_442_5.wav
# None 20200217_140000_142_5.wav
# None 20190621_210000_13_5.wav
# None 20190621_160000_322_5.wav
# None 20190603_090000_562_5.wav
# None 20190621_120000_336_0.wav
# None XC696997_0_46_5.wav
# None 20190603_150000_145_5.wav
# None 20190603_190000_187_5.wav
# None 20200217_110000_453_0.wav
# None 20190612_020000_456_0.wav
# None 20190607_100000_240_0.wav
# None 20200215_070000_558_0.wav
# None XC978938_0_33_0.wav
# None 20190603_130000_412_5.wav
# None 20200217_140000_403_5.wav
# None 20200215_120000_567_0.wav
# None 20190603_160000_268_5.wav
# None 20190607_080000_555_0.wav
# None 20200215_080000_99_0.wav
# None 20190612_020000_241_5.wav
# None 20200215_110000_399_0.wav
# None 20200217_160000_216_0.wav
# None 20190607_120000_51_0.wav
# None 20190607_110000_157_5.wav
# None 20200217_140000_64_5.wav
# None 20190603_230000_334_5.wav
# None 20200215_060000_571_5.wav
# None 20190621_160000_294_0.wav
# None 20190603_180000_414_0.wav
# None 20190612_020000_274_5.wav
# None 20190607_080000_429_0.wav
# None 20190607_060000_471_0.wav
# None XC900653_0_40_5.wav
# None 20190607_070000_516_0.wav
# None 20200215_120000_31_5.wav
# None 20190621_110000_195_0.wav
# None 20190607_110000_235_5.wav
# None XC729201_0_37_5.wav
# None 20200215_110000_289_5.wav
# None 20200217_110000_528_0.wav
# None 20200215_110000_373_5.wav
# None 20200217_160000_90_0.wav
# None 20190607_120000_231_0.wav
# None 20200217_060000_355_5.wav
# None 20200217_160000_232_5.wav
# None 20200217_000000_519_0.wav
# None 20200217_140000_520_5.wav
# None 20190603_160000_177_0.wav
# None 20190621_020000_238_5.wav
# None 20200215_070000_115_5.wav
# None 20200217_070000_226_5.wav
# None 20200217_060000_153_0.wav
# None XC669748_0_15_0.wav
# None 20200217_090000_543_0.wav
# None 20190621_150000_582_0.wav
# None 20200217_090000_196_5.wav
# None 20190603_160000_484_5.wav
# None 20200215_080000_354_0.wav
# None 20200217_140000_321_0.wav
# None 20200215_090000_51_0.wav
# None 20200217_090000_592_5.wav
# None 20190621_210000_376_5.wav
# None 20190621_010000_414_0.wav
# None 20200217_000000_504_0.wav
# None 20190603_150000_316_5.wav
# None 20200215_110000_582_0.wav
# None 20190621_020000_433_5.wav
# None 20200215_070000_331_5.wav
# None 20200215_120000_28_5.wav
# None 20200217_070000_421_5.wav
# None 20200217_160000_177_0.wav
# None 20190612_020000_127_5.wav
# None 20200215_070000_120_0.wav
# None 20190621_020000_558_0.wav
# None 20190621_210000_327_0.wav
# None 20200217_120000_436_5.wav
# None 20200215_100000_376_5.wav
# None 20190607_120000_540_0.wav
# None 20200217_070000_564_0.wav
# None 20190603_130000_447_0.wav
# None 20190607_090000_544_5.wav
# None 20200217_160000_10_5.wav
# None 20200217_000000_148_5.wav
# None 20200217_140000_328_5.wav
# None 20190603_190000_358_5.wav
# None 20190607_120000_418_5.wav
# None XC801434_0_13_5.wav
# None 20190621_010000_412_5.wav
# None 20200217_000000_108_0.wav
# None 20190621_160000_318_0.wav
# None 20200217_120000_307_5.wav
# None 20200217_110000_4_5.wav
# None 20190621_160000_141_0.wav
# None 20200217_110000_292_5.wav
# None 20190621_150000_78_0.wav
# None 20190603_150000_61_5.wav
# None 20200217_160000_246_0.wav
# None 20190603_150000_358_5.wav
# None 20190607_090000_483_0.wav
# None XC696997_0_78_0.wav
# None 20190621_010000_456_0.wav
# None 20190603_130000_249_0.wav
# None 20200217_090000_75_0.wav
# None 20190603_160000_64_5.wav
# None 20200217_120000_105_0.wav
# None 20190603_160000_156_0.wav
# None 20190603_140000_370_5.wav
# None 20200215_070000_261_0.wav
# None 20190621_020000_591_0.wav
# None 20200215_090000_385_5.wav
# None 20190603_160000_306_0.wav
# None 20190621_140000_498_0.wav
# None 20200215_080000_316_5.wav
# None 20200217_160000_415_5.wav
# None 20190607_110000_394_5.wav
# None 20190621_120000_63_0.wav
# None 20190621_150000_214_5.wav
# None 20190603_160000_351_0.wav
# None 20200217_140000_199_5.wav
# None 20190603_190000_271_5.wav
# None 20190621_110000_21_0.wav
# None 20190621_020000_483_0.wav
# None 20200217_060000_306_0.wav
# None 20190612_020000_360_0.wav
# None 20200215_110000_61_5.wav
# None 20190621_210000_99_0.wav
# None 20190621_110000_292_5.wav
# None 20200217_120000_120_0.wav
# None 20200215_070000_568_5.wav
# None 20200217_070000_465_0.wav
# None 20200217_000000_579_0.wav
# None 20190621_150000_454_5.wav
# None 20200215_090000_232_5.wav
# None 20190607_100000_535_5.wav
# None 20190621_010000_595_5.wav
# None 20190621_160000_274_5.wav
# None 20190603_110000_517_5.wav
# None 20200217_140000_528_0.wav
# None 20200215_070000_265_5.wav
# None 20200217_120000_234_0.wav
# None 20200215_080000_276_0.wav
# None 20200215_090000_36_0.wav
# None XC882147_0_4_5.wav
# None 20200217_120000_96_0.wav
# None 20200217_000000_357_0.wav
# None 20190603_190000_66_0.wav
# None 20190621_020000_541_5.wav
# None 20190621_010000_150_0.wav
# None 20200217_120000_79_5.wav
# None 20200215_100000_27_0.wav
# None 20190621_020000_429_0.wav
# None 20200217_060000_328_5.wav
# None 20200217_000000_327_0.wav
# None 20190612_020000_52_5.wav
# None 20190607_120000_76_5.wav
# None 20200217_110000_10_5.wav
# None XC733505_0_9_0.wav
# None 20190612_020000_552_0.wav
# None 20190621_020000_409_5.wav
# None 20190607_100000_480_0.wav
# None 20200215_080000_364_5.wav
# None 20190621_010000_432_0.wav
# None 20200215_070000_250_5.wav
# None 20200215_080000_286_5.wav
# None 20190621_210000_267_0.wav
# None 20200215_110000_259_5.wav
# None 20190607_120000_111_0.wav
# None 20200215_070000_435_0.wav
# None 20200215_060000_594_0.wav
# None 20200217_000000_510_0.wav
# None 20190603_230000_34_5.wav
# None 20200215_090000_228_0.wav
# None 20190621_160000_327_0.wav
# None 20190621_150000_108_0.wav
# None 20190621_150000_331_5.wav
# None 20200215_110000_217_5.wav
# None 20190603_170000_298_5.wav
# None 20190603_150000_357_0.wav
# None XC981987_0_1_5.wav
# None 20200217_160000_238_5.wav
# None 20190621_210000_388_5.wav
# None 20200217_070000_579_0.wav
# None 20190603_190000_538_5.wav
# None 20190621_210000_364_5.wav
# None 20190621_190000_456_0.wav
# None 20200217_060000_402_0.wav
# None 20190603_150000_73_5.wav
# None 20190603_230000_577_5.wav
# None 20190603_130000_501_0.wav
# None 20190612_020000_31_5.wav
# None 20200217_000000_46_5.wav
# None 20190621_160000_394_5.wav
# None 20190603_230000_291_0.wav
# None 20200217_070000_318_0.wav
# None 20190603_120000_316_5.wav
# None 20200215_080000_430_5.wav
# None 20190621_150000_388_5.wav
# None XC669748_0_7_5.wav
# None 20200217_090000_312_0.wav
# None 20190621_210000_430_5.wav
# None 20190603_190000_259_5.wav
# None 20200217_160000_196_5.wav
# None 20200215_090000_432_0.wav
# None 20200217_110000_238_5.wav
# None 20200217_140000_424_5.wav
# None 20190621_210000_334_5.wav
# None 20190603_170000_297_0.wav
# None 20200217_000000_157_5.wav
# None 20200215_090000_124_5.wav
# None 20200217_120000_285_0.wav
# None 20190603_150000_121_5.wav
# None 20200217_000000_423_0.wav
# None 20190621_110000_93_0.wav
# None 20200217_140000_537_0.wav
# None 20200215_090000_201_0.wav
# None 20190603_190000_6_0.wav
# None 20190603_130000_51_0.wav
# None 20190612_020000_39_0.wav
# None 20190603_190000_178_5.wav
# None 20200217_110000_535_5.wav
# None 20190621_010000_594_0.wav
# None 20200217_120000_193_5.wav
# None 20200217_070000_492_0.wav
# None 20190612_020000_322_5.wav
# None 20200215_100000_34_5.wav
# None 20190607_100000_97_5.wav
# None 20190621_140000_291_0.wav
# None 20190621_010000_316_5.wav
# None 20190603_170000_538_5.wav
# None 20200215_080000_289_5.wav
# None 20190621_210000_423_0.wav
# None 20200217_000000_561_0.wav
# None 20200215_080000_181_5.wav
# None 20190612_020000_216_0.wav
# None 20200217_160000_289_5.wav
# None 20190603_110000_519_0.wav
# None 20190621_210000_43_5.wav
# None 20190621_020000_555_0.wav
# None XC978938_0_37_5.wav
# None 20200217_000000_168_0.wav
# None 20190621_110000_43_5.wav
# None 20200217_070000_292_5.wav
# None 20190603_230000_438_0.wav
# None 20190612_020000_429_0.wav
# None 20190621_150000_270_0.wav
# None 20190621_110000_325_5.wav
# None 20200217_070000_442_5.wav
# None 20200215_070000_486_0.wav
# None 20190621_160000_432_0.wav
# None 20200217_120000_81_0.wav
# None 20200217_060000_499_5.wav
# None 20200217_110000_142_5.wav
# None 20200217_070000_592_5.wav
# None 20200215_060000_318_0.wav
# None 20200217_160000_562_5.wav
# None 20200217_160000_370_5.wav
# None 20190603_150000_102_0.wav
# None 20190603_130000_70_5.wav
# None XC668297_0_48_0.wav
# None XC738886_0_0_0.wav
# None 20190621_020000_378_0.wav
# None 20200217_110000_57_0.wav
# None 20190621_140000_298_5.wav
# None XC699878_0_12_0.wav
# None 20200217_070000_409_5.wav
# None 20190621_150000_502_5.wav
# None 20190621_010000_201_0.wav
# None 20190621_140000_349_5.wav
# None XC685625_0_6_0.wav
# None 20190603_160000_381_0.wav
# None XC696997_0_45_0.wav
# None 20190621_020000_223_5.wav
# None XC902525_0_13_5.wav
# None 20200217_060000_120_0.wav
# None 20190621_010000_525_0.wav
# None 20190603_190000_562_5.wav
# None 20190621_110000_180_0.wav
# None 20190621_020000_514_5.wav
# None 20200215_090000_55_5.wav
# None 20200217_160000_82_5.wav
# None 20190621_140000_361_5.wav
# None 20200217_110000_7_5.wav
# None 20200217_060000_397_5.wav
# None 20200215_070000_172_5.wav
# None 20190603_170000_588_0.wav
# None 20190603_120000_268_5.wav
# None 20200217_090000_258_0.wav
# None 20200217_160000_268_5.wav
# None 20190603_120000_232_5.wav
# None 20190603_140000_385_5.wav
# None 20190621_020000_462_0.wav
# None 20190612_020000_553_5.wav
# None 20190621_210000_591_0.wav
# None 20200217_000000_136_5.wav
# None 20200217_060000_594_0.wav
# None 20190603_170000_418_5.wav
# None 20190603_230000_564_0.wav
# None 20190603_180000_210_0.wav
# None 20190621_050000_288_0.wav
# None 20190607_100000_537_0.wav
# None 20200217_110000_306_0.wav
# None 20200215_070000_225_0.wav
# None 20190603_130000_429_0.wav
# None 20190603_140000_333_0.wav
# None 20190621_160000_499_5.wav
# None 20190603_160000_558_0.wav
# None 20190621_020000_216_0.wav
# None 20200217_110000_139_5.wav
# None 20190603_120000_372_0.wav
# None 20200217_070000_270_0.wav
# None 20200215_090000_156_0.wav
# None 20190607_080000_534_0.wav
# None 20200217_000000_229_5.wav
# None 20190603_130000_565_5.wav
# None 20190621_020000_421_5.wav
# None 20190603_160000_159_0.wav
# None 20200215_090000_526_5.wav
# None 20200217_120000_433_5.wav
# None 20190621_210000_264_0.wav
# None 20190603_160000_504_0.wav
# None 20190621_020000_516_0.wav
# None 20190603_160000_522_0.wav
# None 20190603_170000_133_5.wav
# None 20200217_000000_40_5.wav
# None 20200215_110000_12_0.wav
# None 20190603_130000_24_0.wav
# None 20200217_120000_16_5.wav
# None 20200215_060000_274_5.wav
# None 20190603_150000_435_0.wav
# None 20190603_150000_409_5.wav
# None 20190603_160000_39_0.wav
# None 20200217_110000_241_5.wav
# None 20200217_090000_564_0.wav
# None 20200217_060000_376_5.wav
# None 20190603_230000_271_5.wav
# None 20190607_100000_261_0.wav
# None 20190603_150000_127_5.wav
# None XC668297_0_0_0.wav
# None 20200215_110000_37_5.wav
# None 20200217_110000_441_0.wav
# None 20190603_160000_505_5.wav
# None 20200215_070000_136_5.wav
# None 20190607_080000_235_5.wav
# None 20200215_090000_514_5.wav
# None 20190603_180000_304_5.wav
# None 20200217_140000_523_5.wav
# None 20190621_210000_348_0.wav
# None 20200217_090000_39_0.wav
# None 20200217_090000_247_5.wav
# None 20200217_000000_397_5.wav
# None XC934870_0_9_0.wav
# None 20190621_160000_379_5.wav
# None 20200215_100000_573_0.wav
# None 20190621_020000_184_5.wav
# None 20190607_120000_349_5.wav
# None XC803211_0_9_0.wav
# None XC761451_0_0_0.wav
# None 20190603_170000_123_0.wav
# None 20190603_160000_471_0.wav
# None 20200215_100000_405_0.wav
# None 20190621_160000_321_0.wav
# None 20200215_060000_486_0.wav
# None 20190621_160000_415_5.wav
# None 20190603_150000_495_0.wav
# None 20200215_070000_349_5.wav
# None 20190603_170000_52_5.wav
# None 20190621_190000_333_0.wav
# None 20190603_190000_3_0.wav
# None 20190621_020000_528_0.wav
# None 20200215_090000_496_5.wav
# None 20200215_070000_223_5.wav
# None 20200217_110000_417_0.wav
# None 20190607_110000_166_5.wav
# None 20200215_110000_30_0.wav
# None 20190612_020000_217_5.wav
# None 20200215_070000_106_5.wav
# None 20190603_230000_357_0.wav
# None 20190621_160000_237_0.wav
# None 20190603_140000_342_0.wav
# None 20200215_060000_399_0.wav
# None 20190603_230000_523_5.wav
# None 20200217_140000_238_5.wav
# None 20200217_060000_427_5.wav
# None 20200217_120000_361_5.wav
# None 20200215_070000_310_5.wav
# None 20190603_170000_450_0.wav
# None 20200217_070000_424_5.wav
# None XC877694_0_21_0.wav
# None 20200215_070000_289_5.wav
# None 20190607_120000_144_0.wav
# None 20190621_150000_529_5.wav
# None 20200217_110000_337_5.wav
# None 20200217_070000_168_0.wav
# None 20190603_170000_67_5.wav
# None 20190603_160000_274_5.wav
# None 20200215_120000_330_0.wav
# None 20200215_060000_564_0.wav
# None 20190621_010000_111_0.wav
# None 20190603_080000_597_0.wav
# None 20190603_190000_276_0.wav
# None 20200217_000000_121_5.wav
# None 20190621_110000_463_5.wav
# None 20200217_090000_216_0.wav
# None 20200215_110000_369_0.wav
# None 20190603_140000_360_0.wav
# None 20190607_100000_463_5.wav
# None 20190607_120000_589_5.wav
# None 20200215_070000_111_0.wav
# None 20200217_090000_376_5.wav
# None 20190621_020000_195_0.wav
# None 20190603_230000_117_0.wav
# None 20190621_120000_331_5.wav
# None 20200215_100000_64_5.wav
# None 20190603_150000_211_5.wav
# None 20190607_080000_541_5.wav
# None 20200215_110000_75_0.wav
# None 20200217_090000_349_5.wav
# None 20190621_020000_151_5.wav
# None 20190603_150000_231_0.wav
# None 20200215_070000_256_5.wav
# None 20200217_160000_324_0.wav
# None 20190603_160000_61_5.wav
# None 20190607_090000_445_5.wav
# None 20190621_020000_97_5.wav
# None 20190621_110000_106_5.wav
# None 20200217_060000_72_0.wav
# None 20190621_150000_31_5.wav
# None 20200217_090000_591_0.wav
# None 20190607_090000_204_0.wav
# None 20200215_070000_418_5.wav
# None 20200217_140000_207_0.wav
# None 20190607_100000_561_0.wav
# None 20190603_190000_280_5.wav
# None 20200217_070000_61_5.wav
# None 20200215_080000_568_5.wav
# None 20190607_110000_546_0.wav
# None 20200215_120000_583_5.wav
# None 20200217_070000_115_5.wav
# None 20200217_110000_217_5.wav
# None 20200217_060000_93_0.wav
# None 20190603_180000_505_5.wav
# None 20200215_080000_201_0.wav
# None 20200217_110000_463_5.wav
# None 20190621_180000_279_0.wav
# None 20200217_140000_330_0.wav
# None 20190621_140000_229_5.wav
# None 20200215_090000_121_5.wav
# None 20190603_130000_283_5.wav
# None 20190621_110000_88_5.wav
# None 20190621_010000_135_0.wav
# None 20200217_060000_456_0.wav
# None 20200215_120000_345_0.wav
# None 20200215_090000_66_0.wav
# None 20200217_160000_229_5.wav
# None 20190603_230000_319_5.wav
# None 20200215_070000_564_0.wav
# None 20190603_110000_477_0.wav
# None 20190607_080000_400_5.wav
# None 20190612_020000_271_5.wav
# None 20190607_110000_298_5.wav
# None 20190607_110000_415_5.wav
# None 20200217_160000_154_5.wav
# None 20190603_230000_91_5.wav
# None 20190603_160000_429_0.wav
# None 20190621_010000_153_0.wav
# None 20190621_010000_406_5.wav
# None 20190603_170000_552_0.wav
# None 20200215_100000_289_5.wav
# None 20200217_090000_463_5.wav
# None 20190603_230000_298_5.wav
# None 20190621_110000_238_5.wav
# None 20190603_120000_228_0.wav
# None 20190607_090000_202_5.wav
# None 20200217_110000_58_5.wav
# None 20190621_170000_343_5.wav
# None 20200217_110000_18_0.wav
# None 20190607_110000_303_0.wav
# None 20200217_000000_568_5.wav
# None 20190612_020000_156_0.wav
# None 20200217_160000_192_0.wav
# None 20200215_060000_573_0.wav
# None 20200217_060000_327_0.wav
# None 20200217_060000_45_0.wav
# None 20200215_080000_279_0.wav
# None 20200215_110000_102_0.wav
# None 20200217_110000_0_0.wav
# None 20200217_140000_483_0.wav
# None 20190603_150000_375_0.wav
# None 20200217_120000_274_5.wav
# None 20190607_120000_127_5.wav
# None 20200215_080000_420_0.wav
# None 20190603_190000_67_5.wav
# None 20200215_110000_282_0.wav
# None 20190603_160000_463_5.wav
# None 20190621_020000_211_5.wav
# None 20190603_230000_18_0.wav
# None 20200215_070000_361_5.wav
# None 20200215_120000_387_0.wav
# None 20200215_080000_151_5.wav
# None 20200217_090000_141_0.wav
# None 20190607_110000_57_0.wav
# None 20190607_120000_132_0.wav
# None 20200217_070000_321_0.wav
# None 20200215_080000_432_0.wav
# None 20190621_140000_207_0.wav
# None 20190607_120000_271_5.wav
# None 20190603_150000_498_0.wav
# None 20190603_160000_255_0.wav
# None 20200217_120000_540_0.wav
# None 20190603_230000_232_5.wav
# None 20190621_210000_211_5.wav
# None 20200217_120000_115_5.wav
# None 20190607_120000_502_5.wav
# None 20190607_120000_525_0.wav
# None 20190621_210000_301_5.wav
# None 20200215_120000_13_5.wav
# None 20190621_210000_303_0.wav
# None 20200215_070000_91_5.wav
# None 20190603_230000_111_0.wav
# None 20200217_120000_175_5.wav
# None 20200217_090000_273_0.wav
# None 20200215_060000_405_0.wav
# None 20200217_140000_150_0.wav
# None 20190612_020000_508_5.wav
# None 20200215_060000_451_5.wav
# None 20190603_180000_424_5.wav
# None 20190603_170000_141_0.wav
# None 20200217_060000_426_0.wav
# None 20200217_110000_570_0.wav
# None 20190603_230000_70_5.wav
# None 20200215_100000_571_5.wav
# None 20190621_010000_436_5.wav
# None 20200217_000000_33_0.wav
# None 20190621_110000_222_0.wav
# None 20200217_070000_523_5.wav
# None 20190603_180000_339_0.wav
# None 20200217_060000_277_5.wav
# None 20190621_110000_102_0.wav
# None 20200215_070000_592_5.wav
# None 20190612_020000_444_0.wav
# None 20200217_090000_309_0.wav
# None 20200217_000000_147_0.wav
# None 20190621_150000_268_5.wav
# None 20200217_120000_526_5.wav
# None 20200215_100000_79_5.wav
# None 20190621_110000_211_5.wav
# None 20200217_060000_472_5.wav
# None 20190607_110000_201_0.wav
# None 20190621_090000_397_5.wav
# None 20190621_020000_513_0.wav
# None 20200217_000000_415_5.wav
# None 20190621_110000_262_5.wav
# None 20200215_080000_550_5.wav
# None 20200217_070000_420_0.wav
# None 20200217_160000_349_5.wav
# None 20200217_070000_243_0.wav
# None 20190621_020000_247_5.wav
# None 20200217_090000_186_0.wav
# None 20200217_160000_493_5.wav
# None 20200217_160000_201_0.wav
# None 20200217_160000_267_0.wav
# None 20190621_160000_387_0.wav
# None 20190603_190000_144_0.wav
# None 20190621_020000_550_5.wav
# None 20200217_090000_43_5.wav
# None 20190603_180000_273_0.wav
# None 20190621_110000_231_0.wav
# None 20190621_160000_381_0.wav
# None 20200217_120000_169_5.wav
# None 20200217_140000_219_0.wav
# None 20200215_070000_283_5.wav
# None 20190603_150000_135_0.wav
# None 20200217_090000_99_0.wav
# None 20190612_020000_126_0.wav
# None 20200217_140000_169_5.wav
# None 20190621_170000_252_0.wav
# None XC696997_0_40_5.wav
# None 20190621_010000_468_0.wav
# None 20200217_140000_276_0.wav
# None 20190603_150000_405_0.wav
# None 20200215_060000_454_5.wav
# None 20200217_090000_7_5.wav
# None 20200215_120000_519_0.wav
# None 20200217_160000_553_5.wav
# None 20200217_070000_469_5.wav
# None 20200217_070000_87_0.wav
# None 20190607_110000_193_5.wav
# None 20190621_110000_204_0.wav
# None 20200215_120000_94_5.wav
# None 20200217_090000_549_0.wav
# None 20190607_120000_559_5.wav
# None 20190603_140000_493_5.wav
# None 20200217_000000_117_0.wav
# None 20190621_110000_327_0.wav
# None 20200217_070000_187_5.wav
# None 20190621_150000_412_5.wav
# None 20190603_150000_115_5.wav
# None 20200217_090000_544_5.wav
# None 20190621_130000_369_0.wav
# None 20200217_000000_273_0.wav
# None 20200217_160000_348_0.wav
# None 20200215_110000_174_0.wav
# None 20190603_150000_217_5.wav
# None 20190621_210000_109_5.wav
# None 20190621_160000_472_5.wav
# None 20190603_150000_489_0.wav
# None XC668297_0_27_0.wav
# None 20190603_160000_202_5.wav
# None 20190621_210000_531_0.wav
# None 20190603_180000_255_0.wav
# None 20190603_110000_457_5.wav
# None 20200215_090000_180_0.wav
# None 20200217_000000_538_5.wav
# None 20190603_170000_397_5.wav
# None 20190621_020000_55_5.wav
# None 20190621_140000_340_5.wav
# None 20190621_020000_345_0.wav
# None 20190603_230000_252_0.wav
# None 20200217_110000_21_0.wav
# None XC946355_0_3_0.wav
# None 20200215_060000_516_0.wav
# None 20190621_010000_181_5.wav
# None 20190603_140000_60_0.wav
# None 20190603_110000_198_0.wav
# None 20190607_110000_45_0.wav
# None XC818170_0_42_0.wav
# None 20200217_060000_361_5.wav
# None 20190603_170000_346_5.wav
# None 20200215_110000_541_5.wav
# None 20190603_190000_265_5.wav
# None 20200217_120000_58_5.wav
# None 20200215_090000_588_0.wav
# None 20200215_110000_372_0.wav
# None 20200217_140000_496_5.wav
# None 20200217_000000_153_0.wav
# None 20200215_100000_82_5.wav
# None 20200217_000000_289_5.wav
# None 20190603_230000_429_0.wav
# None 20200217_110000_438_0.wav
# None 20200217_090000_381_0.wav
# None 20190603_150000_285_0.wav
# None 20190603_160000_45_0.wav
# None 20200215_070000_513_0.wav
# None 20190607_080000_370_5.wav
# None 20200215_080000_582_0.wav
# None 20200217_140000_31_5.wav
# None 20200217_060000_540_0.wav
# None 20190621_110000_124_5.wav
# None 20190621_020000_333_0.wav
# None 20190607_120000_16_5.wav
# None 20200215_120000_327_0.wav
# None 20190612_020000_316_5.wav
# None 20190621_010000_249_0.wav
# None 20200215_080000_183_0.wav
# None XC938020_0_10_5.wav
# None 20200217_140000_181_5.wav
# None 20190603_190000_436_5.wav
# None 20190621_110000_109_5.wav
# None 20190603_160000_315_0.wav
# None 20190603_140000_61_5.wav
# None 20190607_110000_10_5.wav
# None XC696997_0_66_0.wav
# None 20200217_160000_331_5.wav
# None 20190621_020000_310_5.wav
# None 20190621_210000_174_0.wav
# None 20200217_110000_180_0.wav
# None 20190603_150000_177_0.wav
# None 20190603_190000_130_5.wav
# None 20200217_090000_310_5.wav
# None 20190621_010000_103_5.wav
# None 20190621_150000_522_0.wav
# None 20200217_060000_432_0.wav
# None 20200217_090000_316_5.wav
# None 20190621_010000_259_5.wav
# None 20190603_150000_321_0.wav
# None 20190621_140000_334_5.wav
# None 20200217_160000_319_5.wav
# None 20200215_120000_549_0.wav
# None 20200215_090000_394_5.wav
# None 20190621_160000_465_0.wav
# None 20200217_090000_238_5.wav
# None 20190621_010000_453_0.wav
# None 20190621_210000_106_5.wav
# None 20190603_150000_69_0.wav
# None 20200215_070000_37_5.wav
# None 20190621_140000_76_5.wav
# None 20200217_120000_283_5.wav
# None 20200215_080000_19_5.wav
# None 20190621_010000_477_0.wav
# None 20200217_160000_142_5.wav
# None 20200215_100000_388_5.wav
# None 20190607_080000_505_5.wav
# None 20190607_120000_325_5.wav
# None 20200217_120000_532_5.wav
# None 20200217_070000_208_5.wav
# None 20200215_100000_187_5.wav
# None 20200217_120000_298_5.wav
# None 20190603_140000_214_5.wav
# None 20200215_080000_186_0.wav
# None 20190603_110000_270_0.wav
# None 20200215_080000_583_5.wav
# None 20190603_130000_262_5.wav
# None 20190612_020000_82_5.wav
# None 20200217_160000_139_5.wav
# None 20200215_070000_157_5.wav
# None 20190621_180000_246_0.wav
# None 20190607_110000_124_5.wav
# None 20200217_140000_369_0.wav
# None 20190603_160000_69_0.wav
# None 20190621_020000_67_5.wav
# None 20190621_010000_339_0.wav
# None 20190603_160000_342_0.wav
# None 20200215_110000_181_5.wav
# None 20190607_080000_439_5.wav
# None 20190603_130000_36_0.wav
# None 20190603_180000_202_5.wav
# None 20190603_230000_432_0.wav
# None 20190603_180000_93_0.wav
# None 20200217_120000_550_5.wav
# None 20190621_210000_154_5.wav
# None 20200215_090000_157_5.wav
# None 20200215_110000_220_5.wav
# None 20200217_090000_219_0.wav
# None 20200215_070000_465_0.wav
# None 20200215_060000_534_0.wav
# None 20200217_140000_162_0.wav
# None 20200215_110000_451_5.wav
# None 20190612_020000_207_0.wav
# None XC818169_0_7_5.wav
# None 20190621_120000_318_0.wav
# None 20200215_100000_21_0.wav
# None 20200217_090000_414_0.wav
# None 20200217_070000_427_5.wav
# None 20200215_080000_69_0.wav
# None 20200215_080000_417_0.wav
# None 20200217_000000_67_5.wav
# None 20200215_090000_403_5.wav
# None 20200217_110000_274_5.wav
# None 20190621_210000_30_0.wav
# None 20200217_140000_384_0.wav
# None 20190607_100000_430_5.wav
# None 20200215_070000_534_0.wav
# None 20190612_020000_43_5.wav
# None 20190607_110000_30_0.wav
# None 20200215_100000_529_5.wav
# None 20190621_010000_234_0.wav
# None 20200217_160000_384_0.wav
# None 20190621_150000_420_0.wav
# None 20190603_120000_400_5.wav
# None 20190603_160000_295_5.wav
# None 20190621_160000_373_5.wav
# None 20200217_120000_466_5.wav
# None 20200215_080000_565_5.wav
# None 20190621_210000_168_0.wav
# None 20200217_070000_171_0.wav
# None 20200215_070000_132_0.wav
# None 20190621_210000_175_5.wav
# None 20190621_110000_19_5.wav
# None 20200215_090000_454_5.wav
# None 20200217_090000_393_0.wav
# None 20200215_070000_304_5.wav
# None 20190621_020000_246_0.wav
# None 20190603_160000_487_5.wav
# None 20200215_080000_562_5.wav
# None 20190603_230000_550_5.wav
# None 20190603_110000_292_5.wav
# None 20190621_210000_453_0.wav
# None 20190621_170000_472_5.wav
# None 20200215_070000_540_0.wav
# None 20200215_070000_519_0.wav
# None 20200215_090000_364_5.wav
# None 20190603_230000_228_0.wav
# None 20200217_140000_75_0.wav
# None 20200217_110000_432_0.wav
# None 20190603_110000_514_5.wav
# None 20190612_030000_286_5.wav
# None 20200217_160000_63_0.wav
# None 20190603_230000_558_0.wav
# None 20190603_230000_136_5.wav
# None 20190621_020000_123_0.wav
# None 20200215_120000_561_0.wav
# None 20190607_080000_453_0.wav
# None 20200215_070000_69_0.wav
# None 20200215_120000_336_0.wav
# None 20200217_110000_333_0.wav
# None 20190603_150000_36_0.wav
# None 20190621_210000_111_0.wav
# None XC900653_0_63_0.wav
# None 20190621_160000_198_0.wav
# None 20190621_180000_117_0.wav
# None 20190621_010000_583_5.wav
# None 20190621_210000_432_0.wav
# None 20200217_000000_88_5.wav
# None 20200217_110000_120_0.wav
# None 20200217_120000_573_0.wav
# None XC882147_0_6_0.wav
# None 20200217_160000_219_0.wav
# None 20200215_080000_211_5.wav
# None 20190621_150000_253_5.wav
# None 20190607_080000_504_0.wav
# None 20190603_150000_271_5.wav
# None 20190621_190000_342_0.wav
# None 20190621_210000_463_5.wav
# None 20200217_000000_183_0.wav
# None 20200217_140000_429_0.wav
# None 20200217_140000_457_5.wav
# None 20190621_210000_31_5.wav
# None 20190603_060000_597_0.wav
# None 20200217_160000_129_0.wav
# None 20200215_110000_273_0.wav
# None 20200215_080000_570_0.wav
# None 20190607_100000_390_0.wav
# None 20200217_060000_333_0.wav
# None XC912998_0_15_0.wav
# None 20200215_080000_403_5.wav
# None 20190621_160000_148_5.wav
# None 20190621_020000_291_0.wav
# None XC975372_0_28_5.wav
# None 20200215_080000_288_0.wav
# None 20190603_140000_6_0.wav
# None 20200217_000000_63_0.wav
# None 20200217_060000_309_0.wav
# None 20190603_190000_160_5.wav
# None 20200217_060000_249_0.wav
# None 20200217_110000_330_0.wav
# None 20190621_210000_291_0.wav
# None 20200217_140000_580_5.wav
# None 20190607_120000_54_0.wav
# None 20200215_070000_334_5.wav
# None 20200217_160000_321_0.wav
# None XC956940_0_31_5.wav
# None 20200217_070000_177_0.wav
# None 20190607_100000_559_5.wav
# None 20190603_150000_463_5.wav
# None 20190621_190000_421_5.wav
# None 20200215_070000_399_0.wav
# None XC729201_0_1_5.wav
# None 20190621_210000_10_5.wav
# None 20200217_090000_466_5.wav
# None 20190603_190000_400_5.wav
# None 20190603_190000_43_5.wav
# None 20190621_140000_430_5.wav
# None 20200215_080000_220_5.wav
# None 20190603_230000_303_0.wav
# None 20200215_090000_565_5.wav
# None 20200217_070000_514_5.wav
# None 20190603_230000_157_5.wav
# None 20200217_140000_277_5.wav
# None 20200215_070000_481_5.wav
# None 20190603_130000_555_0.wav
# None 20190621_020000_142_5.wav
# None 20190603_190000_384_0.wav
# None 20200217_160000_556_5.wav
# None XC981987_0_156_0.wav
# None 20190603_230000_6_0.wav
# None 20190621_210000_115_5.wav
# None 20200217_090000_297_0.wav
# None 20190621_100000_597_0.wav
# None 20190621_210000_9_0.wav
# None 20190621_020000_553_5.wav
# None 20190621_020000_430_5.wav
# None 20200217_070000_88_5.wav
# None 20200217_140000_556_5.wav
# None 20190603_140000_417_0.wav
# None 20190621_160000_360_0.wav
# None 20190603_230000_529_5.wav
# None 20200215_110000_34_5.wav
# None 20190603_160000_439_5.wav
# None 20200217_090000_519_0.wav
# None 20200217_000000_447_0.wav
# None 20190621_010000_381_0.wav
# None 20190612_030000_30_0.wav
# None 20200215_120000_315_0.wav
# None 20190603_170000_165_0.wav
# None 20200217_120000_412_5.wav
# None 20190621_150000_100_5.wav
# None 20190621_020000_69_0.wav
# None 20190621_020000_328_5.wav
# None XC912998_0_7_5.wav
# None 20200215_070000_480_0.wav
# None 20200215_120000_135_0.wav
# None 20190607_120000_19_5.wav
# None 20200217_110000_205_5.wav
# None 20190603_230000_322_5.wav
# None 20190603_230000_360_0.wav
# None 20200215_120000_501_0.wav
# None 20190621_120000_325_5.wav
# None 20200217_120000_289_5.wav
# None 20200217_000000_481_5.wav
# None 20190621_140000_519_0.wav
# None 20200217_110000_550_5.wav
# None 20190621_110000_112_5.wav
# None 20200215_060000_382_5.wav
# None 20190621_160000_349_5.wav
# None 20200217_000000_192_0.wav
# None 20190612_020000_165_0.wav
# None 20190603_110000_55_5.wav
# None 20200215_090000_480_0.wav
# None 20200215_090000_367_5.wav
# None 20190603_140000_213_0.wav
# None 20200217_090000_358_5.wav
# None 20190621_210000_96_0.wav
# None 20190603_110000_597_0.wav
# None 20190603_190000_223_5.wav
# None 20190612_020000_484_5.wav
# None 20190603_170000_525_0.wav
# None 20200217_140000_147_0.wav
# None 20190621_010000_27_0.wav
# None 20190612_020000_258_0.wav
# None 20200215_100000_70_5.wav
# None 20200217_060000_483_0.wav
# None 20190621_150000_252_0.wav
# None 20190603_110000_58_5.wav
# None 20200215_110000_136_5.wav
# None 20200215_090000_52_5.wav
# None 20200217_110000_423_0.wav
# None 20200215_070000_459_0.wav
# None 20190603_190000_474_0.wav
# None 20190603_150000_199_5.wav
# None 20190607_120000_397_5.wav
# None 20200217_160000_54_0.wav
# None 20190621_150000_69_0.wav
# None 20190603_190000_232_5.wav
# None 20200217_120000_547_5.wav
# None 20200217_070000_147_0.wav
# None 20200217_120000_270_0.wav
# None 20190621_010000_211_5.wav
# None 20200217_070000_139_5.wav
# None 20190621_210000_70_5.wav
# None 20190607_100000_381_0.wav
# None 20190603_170000_294_0.wav
# None 20200217_160000_385_5.wav
# None 20200217_110000_490_5.wav
# None 20200215_080000_418_5.wav
# None 20200217_120000_186_0.wav
# None 20200215_100000_139_5.wav
# None 20190603_190000_168_0.wav
# None XC975372_0_15_0.wav
# None 20190603_230000_568_5.wav
# None XC912998_0_27_0.wav
# None 20190621_140000_226_5.wav
# None 20200217_160000_187_5.wav
# None 20190621_140000_337_5.wav
# None 20190607_080000_273_0.wav
# None 20190607_110000_424_5.wav
# None 20200217_060000_364_5.wav
# None 20190612_020000_226_5.wav
# None 20190603_230000_240_0.wav
# None 20200217_090000_546_0.wav
# None 20190621_160000_471_0.wav
# None XC975372_0_55_5.wav
# None 20200217_120000_111_0.wav
# None 20190621_160000_468_0.wav
# None 20190621_210000_226_5.wav
# None 20190621_020000_501_0.wav
# None 20200217_160000_477_0.wav
# None 20190621_150000_459_0.wav
# None 20190607_110000_286_5.wav
# None XC691725_0_4_5.wav
# None 20200217_060000_198_0.wav
# None 20190621_020000_25_5.wav
# None 20190603_170000_96_0.wav
# None 20200217_140000_513_0.wav
# None 20200217_000000_400_5.wav
# None 20200215_060000_574_5.wav
# None 20200217_140000_463_5.wav
# None 20190612_020000_448_5.wav
# None 20200215_080000_43_5.wav
# None 20200215_120000_108_0.wav
# None 20190621_110000_208_5.wav
# None 20200217_070000_307_5.wav
# None 20200217_000000_523_5.wav
# None 20190603_110000_454_5.wav
# None 20200215_100000_397_5.wav
# None 20190607_100000_91_5.wav
# None 20190603_140000_357_0.wav
# None 20190621_190000_267_0.wav
# None 20190612_020000_337_5.wav
# None 20190621_020000_339_0.wav
# None 20190621_160000_156_0.wav
# None 20190621_210000_156_0.wav
# None 20200217_000000_144_0.wav
# None XC713961_0_3_0.wav
# None 20200217_160000_442_5.wav
# None 20200215_120000_105_0.wav
# None 20190621_010000_523_5.wav
# None 20190603_230000_229_5.wav
# None 20200217_110000_408_0.wav
# None 20200217_110000_199_5.wav
# None 20200217_000000_588_0.wav
# None 20190621_110000_166_5.wav
# None 20190603_120000_403_5.wav
# None 20190621_010000_331_5.wav
# None 20200215_110000_90_0.wav
# None 20190621_150000_219_0.wav
# None 20190607_110000_390_0.wav
# None 20190621_160000_135_0.wav
# None 20200215_100000_516_0.wav
# None 20200217_060000_268_5.wav
# None 20190603_130000_246_0.wav
# None 20200217_060000_439_5.wav
# None 20200215_110000_423_0.wav
# None 20190603_160000_289_5.wav
# None 20200215_070000_285_0.wav
# None XC801434_0_22_5.wav
# None 20190621_160000_183_0.wav
# None 20200217_110000_136_5.wav
# None 20200217_000000_22_5.wav
# None 20190621_210000_229_5.wav
# None 20190621_150000_135_0.wav
# None 20200217_160000_199_5.wav
# None 20200217_110000_591_0.wav
# None 20190603_160000_328_5.wav
# None 20190621_160000_229_5.wav
# None 20190612_020000_571_5.wav
# None 20190621_120000_300_0.wav
# None XC696997_0_27_0.wav
# None 20200217_060000_127_5.wav
# None 20200217_120000_301_5.wav
# None 20190603_040000_112_5.wav
# None 20190603_150000_450_0.wav
# None 20190607_120000_577_5.wav
# None 20200217_070000_135_0.wav
# None 20190621_010000_312_0.wav
# None 20200217_070000_589_5.wav
# None 20200217_140000_51_0.wav
# None 20200217_060000_465_0.wav
# None 20190621_020000_496_5.wav
# None 20200217_120000_184_5.wav
# None 20200215_090000_234_0.wav
# None 20190621_160000_174_0.wav
# None 20200217_140000_436_5.wav
# None 20190621_150000_448_5.wav
# None 20200217_060000_442_5.wav
# None 20200215_070000_9_0.wav
# None XC761451_0_9_0.wav
# None XC978938_0_22_5.wav
# None 20200215_070000_108_0.wav
# None 20190603_230000_444_0.wav
# None 20200217_120000_249_0.wav
# None 20190621_210000_28_5.wav
# None 20190621_020000_468_0.wav
# None 20200215_110000_84_0.wav
# None 20200215_110000_549_0.wav
# None 20200217_160000_310_5.wav
# None 20200215_070000_514_5.wav
# None 20200215_060000_369_0.wav
# None 20200215_080000_406_5.wav
# None 20190603_120000_340_5.wav
# None XC721327_0_18_0.wav
# None 20190603_160000_564_0.wav
# None 20190603_230000_346_5.wav
# None 20190603_110000_324_0.wav
# None 20200217_120000_459_0.wav
# None 20200217_110000_351_0.wav
# None 20200217_090000_315_0.wav
# None 20200217_070000_174_0.wav
# None 20190607_120000_412_5.wav
# None 20200217_120000_340_5.wav
# None 20200217_110000_258_0.wav
# None 20190621_120000_60_0.wav
# None 20190621_210000_15_0.wav
# None 20190612_020000_1_5.wav
# None 20190603_160000_546_0.wav
# None 20200217_140000_390_0.wav
# None 20190621_150000_592_5.wav
# None 20190603_160000_163_5.wav
# None 20190603_190000_537_0.wav
# None 20190621_150000_444_0.wav
# None 20190603_170000_216_0.wav
# None 20200217_110000_346_5.wav
# None 20190603_130000_580_5.wav
# None 20190621_010000_142_5.wav
# None 20190621_160000_477_0.wav
# None 20200215_080000_300_0.wav
# None 20200217_060000_40_5.wav
# None 20190603_130000_235_5.wav
# None 20190621_020000_564_0.wav
# None 20190612_020000_430_5.wav
# None XC840067_0_0_0.wav
# None 20200217_090000_301_5.wav
# None 20200217_070000_532_5.wav
# None 20200217_120000_495_0.wav
# None 20190603_150000_294_0.wav
# None 20190603_170000_486_0.wav
# None 20200215_090000_517_5.wav
# None 20200215_060000_183_0.wav
# None 20190621_010000_519_0.wav
# None 20190621_160000_421_5.wav
# None 20200217_160000_16_5.wav
# None 20200215_090000_576_0.wav
# None 20200215_120000_297_0.wav
# None 20190603_230000_253_5.wav
# None 20190603_180000_211_5.wav
# None 20190621_110000_462_0.wav
# None 20190607_080000_160_5.wav
# None 20190603_170000_99_0.wav
# None 20200217_090000_570_0.wav
# None 20200217_090000_6_0.wav
# None 20200215_090000_198_0.wav
# None XC975372_0_42_0.wav
# None 20200217_160000_36_0.wav
# None 20200215_110000_262_5.wav
# None 20190621_020000_460_5.wav
# None 20200215_070000_27_0.wav
# None 20200217_090000_288_0.wav
# None 20200215_120000_513_0.wav
# None 20190621_020000_262_5.wav
# None 20190603_170000_277_5.wav
# None 20190603_230000_451_5.wav
# None 20200215_110000_352_5.wav
# None 20190612_020000_517_5.wav
# None 20190621_140000_382_5.wav
# None 20200215_100000_414_0.wav
# None 20200215_100000_513_0.wav
# None 20190607_100000_462_0.wav
# None 20190621_210000_205_5.wav
# None 20200215_060000_583_5.wav
# None 20190621_180000_157_5.wav
# None 20190603_170000_580_5.wav
# None 20190603_150000_223_5.wav
# None 20200215_060000_376_5.wav
# None 20200217_060000_382_5.wav
# None 20190603_230000_219_0.wav
# None 20200217_060000_279_0.wav
# None 20200215_080000_114_0.wav
# None 20190612_020000_183_0.wav
# None 20200215_060000_279_0.wav
# None 20190603_170000_574_5.wav
# None 20190621_110000_271_5.wav
# None 20190621_010000_354_0.wav
# None 20200215_090000_13_5.wav
# None 20190607_100000_321_0.wav
# None 20200215_090000_144_0.wav
# None 20200217_140000_438_0.wav
# None 20200217_120000_462_0.wav
# None 20200217_120000_543_0.wav
# None 20200217_110000_97_5.wav
# None 20190603_120000_418_5.wav
# None 20190621_160000_165_0.wav
# None 20190621_150000_70_5.wav
# None 20190621_020000_384_0.wav
# None XC732302_0_9_0.wav
# None 20190603_230000_169_5.wav
# None 20190621_210000_258_0.wav
# None 20190603_230000_273_0.wav
# None 20200215_110000_400_5.wav
# None 20190621_160000_136_5.wav
# None 20200215_110000_166_5.wav
# None 20190603_230000_366_0.wav
# None 20200215_070000_268_5.wav
# None 20190603_170000_108_0.wav
# None 20190603_180000_226_5.wav
# None 20190603_180000_165_0.wav
# None 20190607_080000_259_5.wav
# None 20200215_070000_88_5.wav
# None XC761451_0_13_5.wav
# None 20200215_110000_405_0.wav
# None 20190621_210000_427_5.wav
# None 20190621_110000_306_0.wav
# None 20190603_120000_30_0.wav
# None 20190621_210000_181_5.wav
# None 20200217_160000_294_0.wav
# None 20200217_160000_225_0.wav
# None 20190603_230000_133_5.wav
# None 20190603_230000_310_5.wav
# None 20200217_060000_369_0.wav
# None 20200217_110000_267_0.wav
# None 20190603_230000_378_0.wav
# None 20200217_070000_567_0.wav
# None 20190607_100000_481_5.wav
# None 20190621_140000_210_0.wav
# None 20190607_100000_465_0.wav
# None 20200217_160000_109_5.wav
# None 20200217_160000_108_0.wav
# None 20200215_090000_405_0.wav
# None 20200217_110000_379_5.wav
# None 20200217_120000_91_5.wav
# None 20190607_080000_307_5.wav
# None 20200215_070000_147_0.wav
# None 20200215_060000_559_5.wav
# None 20200217_060000_408_0.wav
# None 20200215_100000_355_5.wav
# None 20190621_020000_343_5.wav
# None 20200217_070000_345_0.wav
# None 20200217_110000_387_0.wav
# None 20190621_210000_88_5.wav
# None 20190621_020000_276_0.wav
# None 20200217_090000_513_0.wav
# None 20200215_080000_438_0.wav
# None 20190603_150000_412_5.wav
# None 20200215_090000_579_0.wav
# None 20190603_170000_465_0.wav
# None 20190603_230000_139_5.wav
# None 20190603_180000_387_0.wav
# None 20190603_170000_127_5.wav
# None 20200217_110000_540_0.wav
# None 20190621_160000_132_0.wav
# None 20200215_120000_93_0.wav
# None 20190621_110000_298_5.wav
# None 20200217_060000_238_5.wav
# None 20200217_110000_468_0.wav
# None 20190621_140000_376_5.wav
# None 20190603_180000_495_0.wav
# None 20200217_120000_594_0.wav
# None 20190603_130000_72_0.wav
# None 20200217_060000_108_0.wav
# None 20190621_010000_199_5.wav
# None 20200215_080000_241_5.wav
# None 20190621_210000_190_5.wav
# ...
# None 20190607_080000_522_0.wav
# None 20200215_070000_154_5.wav
# None 20200217_000000_3_0.wav
# None 20200217_110000_444_0.wav
# None 20190621_140000_172_5.wav
# None 20200215_100000_76_5.wav
# None 20190621_210000_268_5.wav
# None 20190612_020000_543_0.wav
# None 20190621_010000_466_5.wav
# None 20200215_070000_537_0.wav
# None 20190607_110000_58_5.wav
# None 20200217_120000_0_0.wav
# None 20200217_000000_324_0.wav
# None 20190621_010000_90_0.wav
# None XC882147_0_18_0.wav
# None 20190603_190000_396_0.wav
# None 20200217_160000_357_0.wav
# None XC931635_0_16_5.wav
# None 20190603_120000_234_0.wav
# None 20190621_010000_192_0.wav
# None 20190621_020000_595_5.wav
# None 20200215_070000_351_0.wav
# None 20200217_060000_316_5.wav
# None XC882147_0_16_5.wav
# None 20200215_080000_36_0.wav
# None 20190603_160000_198_0.wav
# None 20200217_120000_61_5.wav
# None 20190621_210000_393_0.wav
# None 20190621_010000_342_0.wav
# None 20190607_090000_306_0.wav
# None 20200217_140000_451_5.wav
# None 20200217_120000_487_5.wav
# None 20200217_120000_391_5.wav
# None 20200217_070000_456_0.wav
# None 20190603_180000_213_0.wav
# None 20200215_100000_247_5.wav
# None 20190607_080000_265_5.wav
# None 20190603_180000_214_5.wav
# None 20190621_210000_438_0.wav
# None 20190603_230000_61_5.wav
# None 20200217_000000_492_0.wav
# None 20190603_150000_300_0.wav
# None 20200217_060000_105_0.wav
# None XC733505_0_91_5.wav
# None 20190621_150000_261_0.wav
# None 20190621_150000_85_5.wav
# None 20190607_110000_321_0.wav
# None 20190612_020000_415_5.wav
# None 20190603_170000_139_5.wav
# None 20200217_160000_528_0.wav
# None 20200217_160000_285_0.wav
# None 20190621_110000_61_5.wav
# None 20190621_160000_207_0.wav
# None 20200217_070000_228_0.wav
# None 20190621_140000_222_0.wav
# None 20200217_060000_10_5.wav
# None XC761451_0_3_0.wav
# None 20200217_120000_534_0.wav
# None 20200217_060000_49_5.wav
# None 20200217_060000_262_5.wav
# None 20190603_160000_142_5.wav
# None 20200217_140000_447_0.wav
# None 20190612_030000_289_5.wav
# None 20190603_130000_268_5.wav
# None 20190621_010000_379_5.wav
# None 20200217_060000_226_5.wav
# None 20190621_020000_177_0.wav
# None 20190612_020000_330_0.wav
# None 20200217_090000_112_5.wav
# None 20200215_080000_322_5.wav
# None 20200217_160000_492_0.wav
# None 20190621_210000_225_0.wav
# None 20200217_160000_537_0.wav
# None 20190621_090000_457_5.wav
# None 20190603_150000_445_5.wav
# None 20200217_070000_13_5.wav
# None 20200217_060000_175_5.wav
# None 20190621_020000_426_0.wav
# None 20190603_180000_249_0.wav
# None 20190603_140000_328_5.wav
# None 20190607_110000_444_0.wav
# None 20190612_020000_487_5.wav
# None 20190621_160000_196_5.wav
# None 20190607_090000_153_0.wav
# None 20200217_090000_36_0.wav
# None 20190621_120000_69_0.wav
# None 20200217_000000_525_0.wav
# None 20200215_080000_451_5.wav
# None 20200215_080000_133_5.wav
# None 20200217_140000_70_5.wav
# None 20200215_070000_577_5.wav
# None 20200217_070000_220_5.wav
# None 20200217_120000_154_5.wav
# None 20190621_010000_309_0.wav
# None 20200215_090000_225_0.wav
# None 20190607_120000_168_0.wav
# None 20190621_020000_363_0.wav
# None 20190612_020000_306_0.wav
# None XC732302_0_6_0.wav
# None 20200217_140000_138_0.wav
# None XC956940_0_21_0.wav
# None 20200217_060000_285_0.wav
# None 20200217_000000_238_5.wav
# None 20200215_090000_154_5.wav
# None 20190621_010000_168_0.wav
# None 20200215_060000_330_0.wav
# None 20190607_120000_234_0.wav
# None 20190603_160000_240_0.wav
# None 20190621_120000_58_5.wav
# None 20190603_140000_174_0.wav
# None 20200215_120000_285_0.wav
# None 20200217_140000_340_5.wav
# None 20190607_110000_438_0.wav
# None 20190603_130000_481_5.wav
# None 20200215_100000_66_0.wav
# None 20190603_130000_568_5.wav
# None 20200217_060000_171_0.wav
# None 20190607_080000_513_0.wav
# None 20190621_160000_138_0.wav
# None 20190603_090000_534_0.wav
# None 20190603_140000_423_0.wav
# None 20190603_230000_214_5.wav
# None 20200215_070000_366_0.wav
# None 20200217_110000_355_5.wav
# None 20190607_110000_349_5.wav
# None 20200217_140000_165_0.wav
# None 20200217_060000_592_5.wav
# None 20190621_010000_177_0.wav
# None 20190603_150000_585_0.wav
# None 20190607_120000_379_5.wav
# None 20200217_070000_397_5.wav
# None 20190603_170000_480_0.wav
# None 20200215_090000_468_0.wav
# None 20190603_230000_583_5.wav
# None 20200217_070000_82_5.wav
# None 20190603_230000_168_0.wav
# None 20200217_110000_28_5.wav
# None 20200215_090000_126_0.wav
# None 20200217_110000_561_0.wav
# None 20200217_060000_324_0.wav
# None 20190603_130000_55_5.wav
# None 20190603_160000_187_5.wav
# None 20200217_140000_417_0.wav
# None 20190603_110000_501_0.wav
# None 20190621_210000_447_0.wav
# None 20200217_140000_109_5.wav
# None 20190621_010000_184_5.wav
# None 20200217_060000_75_0.wav
# None 20200215_110000_519_0.wav
# None 20190603_130000_403_5.wav
# None 20190607_110000_87_0.wav
# None 20190621_110000_345_0.wav
# None 20190603_160000_426_0.wav
# None 20190621_010000_486_0.wav
# None 20190621_210000_93_0.wav
# None XC732302_0_0_0.wav
# None 20190603_120000_229_5.wav
# None 20200215_070000_121_5.wav
# None 20190603_160000_55_5.wav
# None 20190603_190000_418_5.wav
# None 20200217_120000_442_5.wav
# None 20200217_160000_481_5.wav
# None 20190607_110000_48_0.wav
# None 20200217_070000_133_5.wav
# None 20190603_160000_211_5.wav
# None 20190621_110000_84_0.wav
# None 20190603_130000_561_0.wav
# None 20190603_190000_75_0.wav
# None 20190621_150000_226_5.wav
# None 20200217_060000_30_0.wav
# None 20190603_230000_102_0.wav
# None 20200215_120000_301_5.wav
# None 20200217_070000_157_5.wav
# None 20190603_170000_505_5.wav
# None 20200217_090000_127_5.wav
# None 20190603_110000_510_0.wav
# None 20200217_070000_100_5.wav
# None 20190607_110000_241_5.wav
# None 20190621_110000_55_5.wav
# None 20190621_020000_358_5.wav
# None 20200217_000000_270_0.wav
# None 20190603_230000_471_0.wav
# None 20190621_010000_393_0.wav
# None 20200217_000000_567_0.wav
# None 20190603_160000_492_0.wav
# None 20190607_060000_474_0.wav
# None XC911886_0_16_5.wav
# None 20200217_140000_198_0.wav
# None 20190607_080000_535_5.wav
# None 20190621_210000_493_5.wav
# None 20200217_160000_387_0.wav
# None 20190603_170000_421_5.wav
# None 20200217_070000_477_0.wav
# None 20200217_060000_19_5.wav
# None XC713961_0_31_5.wav
# None 20200217_120000_247_5.wav
# None 20200215_110000_234_0.wav
# None 20190621_010000_534_0.wav
# None 20190621_140000_18_0.wav
# None 20190621_210000_64_5.wav
# None 20200217_090000_346_5.wav
# None 20190621_160000_508_5.wav
# None 20200217_090000_547_5.wav
# None 20200215_110000_327_0.wav
# None 20190603_160000_409_5.wav
# None 20200215_080000_189_0.wav
# None 20190603_230000_469_5.wav
# None 20190603_150000_126_0.wav
# None 20200217_070000_339_0.wav
# None 20190603_190000_81_0.wav
# None 20200217_000000_474_0.wav
# None 20190612_020000_109_5.wav
# None 20190621_140000_313_5.wav
# None 20200215_080000_246_0.wav
# None 20200217_110000_73_5.wav
# None 20200215_060000_241_5.wav
# None 20200217_160000_19_5.wav
# None 20190612_020000_577_5.wav
# None 20200217_060000_493_5.wav
# None 20200215_070000_243_0.wav
# None 20200215_080000_544_5.wav
# None 20190603_230000_13_5.wav
# None 20190603_120000_219_0.wav
# None 20190603_180000_411_0.wav
# None 20200215_070000_544_5.wav
# None 20190603_190000_355_5.wav
# None 20190621_150000_153_0.wav
# None 20190621_210000_360_0.wav
# None 20200217_060000_358_5.wav
# None 20200217_090000_87_0.wav
# None 20200215_120000_493_5.wav
# None 20190603_190000_21_0.wav
# None 20200215_070000_460_5.wav
# None 20200215_110000_58_5.wav
# None 20190603_160000_367_5.wav
# None 20190603_130000_327_0.wav
# None 20200215_090000_559_5.wav
# None 20190621_120000_321_0.wav
# None 20200215_090000_519_0.wav
# None XC900653_0_6_0.wav
# None 20200215_060000_502_5.wav
# None 20190607_100000_475_5.wav
# None 20190603_130000_112_5.wav
# None 20200215_110000_141_0.wav
# None 20190603_190000_564_0.wav
# None 20190621_210000_123_0.wav
# None 20190621_190000_406_5.wav
# None 20190621_150000_597_0.wav
# None 20190603_150000_346_5.wav
# None 20200217_160000_439_5.wav
# None 20190603_150000_384_0.wav
# None 20200217_060000_181_5.wav
# None 20190612_020000_208_5.wav
# None 20200217_120000_231_0.wav
# None 20200217_160000_69_0.wav
# None 20200215_070000_156_0.wav
# None 20190607_110000_229_5.wav
# None 20200217_110000_430_5.wav
# None 20190603_150000_351_0.wav
# None 20190603_070000_271_5.wav
# None 20200217_140000_96_0.wav
# None XC732302_0_10_5.wav
# None 20200217_120000_357_0.wav
# None 20190607_110000_208_5.wav
# None 20200217_000000_291_0.wav
# None 20190603_150000_337_5.wav
# None 20190621_090000_492_0.wav
# None 20190607_110000_163_5.wav
# None 20190603_180000_369_0.wav
# None 20200217_140000_558_0.wav
# None 20200215_080000_223_5.wav
# None XC902525_0_28_5.wav
# None 20200215_090000_387_0.wav
# None XC733505_0_60_0.wav
# None 20190621_160000_270_0.wav
# None 20190603_190000_450_0.wav
# None XC981987_0_52_5.wav
# None 20200217_000000_163_5.wav
# None 20190603_070000_381_0.wav
# None 20190603_230000_22_5.wav
# None 20190603_230000_418_5.wav
# None 20190603_110000_303_0.wav
# None 20190612_020000_61_5.wav
# None 20190603_160000_208_5.wav
# None 20200215_120000_100_5.wav
# None 20200215_120000_525_0.wav
# None 20200215_120000_103_5.wav
# None 20190621_140000_208_5.wav
# None 20200215_110000_150_0.wav
# None 20200217_000000_502_5.wav
# None 20200217_090000_286_5.wav
# None 20190612_020000_198_0.wav
# None 20190621_140000_333_0.wav
# None 20190621_110000_163_5.wav
# None 20190607_110000_289_5.wav
# None 20190603_070000_220_5.wav
# None 20200215_110000_256_5.wav
# None 20200215_060000_301_5.wav
# None 20200217_090000_525_0.wav
# None XC931827_0_117_0.wav
# None 20190621_160000_169_5.wav
# None 20190621_210000_87_0.wav
# None XC911886_0_9_0.wav
# None 20190621_210000_76_5.wav
# None 20200217_110000_481_5.wav
# None 20190621_210000_0_0.wav
# None 20200215_070000_412_5.wav
# None 20190603_180000_217_5.wav
# None 20190603_190000_138_0.wav
# None 20200217_120000_198_0.wav
# None 20190603_230000_58_5.wav
# None 20190603_180000_130_5.wav
# None 20200217_120000_229_5.wav
# None 20190603_150000_433_5.wav
# None 20190603_230000_220_5.wav
# None 20200217_110000_55_5.wav
# None 20190621_020000_99_0.wav
# None XC818170_0_40_5.wav
# None 20200217_090000_16_5.wav
# None 20200215_060000_597_0.wav
# None 20190607_120000_267_0.wav
# None 20190603_090000_64_5.wav
# None 20190603_180000_345_0.wav
# None 20200217_090000_106_5.wav
# None 20200217_160000_186_0.wav
# None 20190607_110000_15_0.wav
# None 20190621_120000_220_5.wav
# None 20190621_150000_172_5.wav
# None 20200217_160000_9_0.wav
# None 20190603_110000_547_5.wav
# None 20200215_090000_54_0.wav
# None 20200217_060000_417_0.wav
# None 20190621_110000_34_5.wav
# None XC668297_0_43_5.wav
# None 20200215_110000_552_0.wav
# None XC733505_0_90_0.wav
# None 20190603_230000_313_5.wav
# None 20190621_150000_169_5.wav
# None 20190607_120000_6_0.wav
# None 20200215_090000_181_5.wav
# None 20190603_230000_201_0.wav
# None 20190621_110000_183_0.wav
# None 20190612_020000_168_0.wav
# None 20190603_140000_367_5.wav
# None 20200215_070000_501_0.wav
# None 20200217_120000_87_0.wav
# None 20200217_160000_234_0.wav
# None 20200217_160000_364_5.wav
# None 20200215_090000_546_0.wav
# None 20200217_090000_111_0.wav
# None 20200217_160000_175_5.wav
# None 20200217_000000_246_0.wav
# None 20200217_090000_348_0.wav
# None 20200217_000000_321_0.wav
# None 20200217_090000_357_0.wav
# None 20190621_210000_45_0.wav
# None 20200217_000000_354_0.wav
# None 20190621_020000_250_5.wav
# None 20190603_170000_430_5.wav
# None 20200217_060000_73_5.wav
# None 20200215_080000_394_5.wav
# None 20190621_160000_484_5.wav
# None 20190603_110000_264_0.wav
# None 20190603_180000_342_0.wav
# None 20200217_070000_207_0.wav
# None 20200217_110000_358_5.wav
# None 20200217_140000_322_5.wav
# None 20190621_090000_399_0.wav
# None 20190621_190000_294_0.wav
# None 20190621_050000_480_0.wav
# None 20190621_020000_504_0.wav
# None 20200217_090000_144_0.wav
# None 20200215_100000_225_0.wav
# None 20190621_210000_481_5.wav
# None XC911886_0_21_0.wav
# None 20190607_100000_502_5.wav
# None 20200215_070000_328_5.wav
# None 20200215_110000_15_0.wav
# None 20190607_090000_348_0.wav
# None 20190612_020000_220_5.wav
# None 20200217_090000_31_5.wav
# None 20190621_090000_90_0.wav
# None 20190621_010000_297_0.wav
# None 20200215_120000_558_0.wav
# None 20190621_020000_259_5.wav
# None 20190603_070000_91_5.wav
# None 20200217_110000_235_5.wav
# None 20200215_060000_514_5.wav
# None 20200215_090000_67_5.wav
# None 20190603_190000_109_5.wav
# None 20200217_120000_454_5.wav
# None 20190621_050000_286_5.wav
# None 20190612_020000_540_0.wav
# None 20190621_210000_412_5.wav
# None 20200215_110000_397_5.wav
# None 20200215_060000_306_0.wav
# None 20200215_100000_543_0.wav
# None 20200215_060000_493_5.wav
# None 20190603_150000_75_0.wav
# None 20200217_060000_25_5.wav
# None 20200217_140000_354_0.wav
# None 20200217_160000_318_0.wav
# None 20200217_000000_537_0.wav
# None 20190607_080000_553_5.wav
# None 20200217_000000_456_0.wav
# None 20190612_020000_421_5.wav
# None 20200215_090000_525_0.wav
# None 20200217_140000_46_5.wav
# None 20200215_080000_247_5.wav
# None 20190603_160000_124_5.wav
# None 20190603_130000_271_5.wav
# None 20200215_120000_499_5.wav
# None 20200215_090000_130_5.wav
# None 20190621_020000_271_5.wav
# None 20190621_020000_385_5.wav
# None 20190603_190000_19_5.wav
# None 20200217_110000_384_0.wav
# None 20200217_000000_583_5.wav
# None 20200215_120000_394_5.wav
# None XC975372_0_19_5.wav
# None 20190621_010000_568_5.wav
# None 20200215_090000_76_5.wav
# None 20200215_110000_576_0.wav
# None 20190621_210000_468_0.wav
# None 20200215_120000_391_5.wav
# None 20200217_070000_435_0.wav
# None 20190607_090000_313_5.wav
# None 20200217_090000_61_5.wav
# None 20190607_080000_486_0.wav
# None 20200217_000000_493_5.wav
# None 20190603_150000_255_0.wav
# None 20200217_160000_522_0.wav
# None 20200215_110000_580_5.wav
# None 20200217_110000_264_0.wav
# None 20190603_150000_166_5.wav
# None 20190603_070000_294_0.wav
# None 20190603_160000_147_0.wav
# None 20200217_000000_582_0.wav
# None XC680900_0_3_0.wav
# None 20190621_120000_39_0.wav
# None 20200215_060000_277_5.wav
# None 20190603_140000_102_0.wav
# None 20200217_110000_66_0.wav
# None 20200217_110000_567_0.wav
# None 20200215_080000_402_0.wav
# None 20190621_150000_429_0.wav
# None 20190621_020000_592_5.wav
# None 20190607_120000_522_0.wav
# None 20200215_080000_141_0.wav
# None 20190621_140000_348_0.wav
# None 20200215_090000_244_5.wav
# None 20200217_110000_315_0.wav
# None 20190607_120000_541_5.wav
# None 20190603_130000_295_5.wav
# None 20200217_090000_253_5.wav
# None 20200215_090000_544_5.wav
# None 20200215_090000_109_5.wav
# None 20200215_080000_91_5.wav
# None 20190621_090000_597_0.wav
# None XC733505_0_93_0.wav
# None 20200215_110000_307_5.wav
# None 20190621_160000_142_5.wav
# None 20200217_160000_189_0.wav
# None 20190621_110000_312_0.wav
# None 20190621_010000_565_5.wav
# None 20190621_010000_304_5.wav
# None 20190607_100000_226_5.wav
# None XC882147_0_46_5.wav
# None 20190621_110000_90_0.wav
# None 20200217_140000_268_5.wav
# None 20190607_120000_57_0.wav
# None 20200215_110000_474_0.wav
# None 20190603_150000_42_0.wav
# None 20190621_160000_364_5.wav
# None 20190603_160000_24_0.wav
# None 20200217_110000_375_0.wav
# None 20200217_090000_70_5.wav
# None 20190621_140000_132_0.wav
# None 20200217_120000_457_5.wav
# None 20190607_090000_303_0.wav
# None 20190603_230000_51_0.wav
# None 20190621_160000_591_0.wav
# None 20200217_140000_298_5.wav
# None 20190603_170000_559_5.wav
# None 20190621_020000_507_0.wav
# None 20200215_080000_310_5.wav
# None 20190621_150000_361_5.wav
# None 20190621_020000_46_5.wav
# None 20190621_010000_318_0.wav
# None 20190603_140000_354_0.wav
# None 20190603_230000_514_5.wav
# None 20190607_110000_24_0.wav
# None 20190603_170000_553_5.wav
# None 20190612_020000_526_5.wav
# None 20190607_110000_451_5.wav
# None 20190621_020000_349_5.wav
# None 20190607_120000_55_5.wav
# None 20200215_090000_79_5.wav
# None 20190603_170000_63_0.wav
# None 20190621_180000_183_0.wav
# None 20200217_160000_286_5.wav
# None 20200217_060000_157_5.wav
# None 20190603_160000_189_0.wav
# None 20200217_070000_385_5.wav
# None 20200217_060000_498_0.wav
# None 20200217_090000_573_0.wav
# None 20200215_070000_555_0.wav
# None 20190603_160000_133_5.wav
# None 20190603_150000_304_5.wav
# None 20200217_110000_226_5.wav
# None 20200217_060000_360_0.wav
# None 20200215_100000_445_5.wav
# None 20190603_130000_528_0.wav
# None 20200215_080000_126_0.wav
# None 20190603_130000_559_5.wav
# None 20200217_120000_520_5.wav
# None 20190621_020000_309_0.wav
# None 20200215_080000_115_5.wav
# None 20190621_150000_54_0.wav
# None 20200217_160000_570_0.wav
# None 20190621_210000_465_0.wav
# None 20190607_120000_288_0.wav
# None 20190621_150000_102_0.wav
# None 20190612_020000_324_0.wav

# %% [markdown]
# # WABAD Integration

# %%
train_folder = f"{DATASET_PATH}/train"
test_folder = f"{DATASET_PATH}/test"
WABAD_FOLDER = "/home/giacomoschiavo/WABAD/segments"

dataset_species_count = {}
for species in os.listdir(test_folder):
    dataset_species_count[species] = {
        "train": len(os.listdir(os.path.join(train_folder, species))),
        "test": len(os.listdir(os.path.join(test_folder, species))),
        "wabad": len(os.listdir(os.path.join(WABAD_FOLDER, species))) if os.path.exists(os.path.join(WABAD_FOLDER, species)) else 0
    }

wabad_species = os.listdir(WABAD_FOLDER)
dataset_species_count_df = pd.DataFrame.from_dict(dataset_species_count, orient='index')
dataset_species_count_df.index.name = 'Species'
dataset_species_count_df = dataset_species_count_df.reset_index() # Make 'Species' a regular column

dataset_species_count_df["In WABAD?"] = dataset_species_count_df["Species"].apply(lambda x: x in wabad_species)
dataset_species_count_df.sort_values(by="train", ascending=False)
# Out:
#                                        Species  train  test  wabad  In WABAD?
# 9                                         None   7000  5116  13345       True
# 20          Fringilla coelebs_Common Chaffinch   6662   981      0      False
# 21               Turdus philomelos_Song Thrush   4225    58      0      False
# 18        Sylvia atricapilla_Eurasian Blackcap   3196   487      0      False
# 15        Regulus ignicapilla_Common Firecrest   3054   231      0      False
# 11    Phylloscopus collybita_Common Chiffchaff   1780   669      0      False
# 7            Erithacus rubecula_European Robin   1407   549      0      False
# 6        Troglodytes troglodytes_Eurasian Wren   1189   111      0      False
# 3                    Regulus regulus_Goldcrest    918    10    999       True
# 12                                        Wind    731   146      0      False
# 2                      Periparus ater_Coal Tit    375    20   3616       True
# 4                                         Rain    353    23      0      False
# 10     Certhia familiaris_Eurasian Treecreeper    324     3    198       True
# 1         Muscicapa striata_Spotted Flycatcher    256    14     21       True
# 13            Turdus merula_Eurasian Blackbird    251   307   8060       True
# 5                                   Vegetation    188    26      0      False
# 16                                     Pecking    175     8      0      False
# 19           Lophophanes cristatus_Crested Tit    138     3    283       True
# 14          Loxia curvirostra_Common Crossbill    119    49    116       True
# 0                                    Aeroplane     47    22      0      False
# 8           Dryocopus martius_Black Woodpecker     47    21    109       True
# 17  Dendrocopos major_Great Spotted Woodpecker     23    16    463       True

# %%
import random
WABAD_FOLDER = "/home/giacomoschiavo/WABAD/segments"

# MOVE WABAD TO TRAINING FOLDER
train_species = os.listdir(TRAIN_PATH)
for species in os.listdir(WABAD_FOLDER):
    if species not in train_species or species == "None":
        print(species)
        continue
    # select a maximum of 1000 segments per speciess
    all_audios = os.listdir(os.path.join(WABAD_FOLDER, species))[:4000]
    selected_audios = all_audios
        # selected_audios = random.sample(all_audios, NUM_SEGMENTS)
    for audio in selected_audios:
        os.rename(
            os.path.join(WABAD_FOLDER, species, audio),
            os.path.join(TRAIN_PATH, species, audio)
        )
# Out:
# None

# %% [markdown]
# ## Undo WABAD

# %%
# move back
target_path = "/home/giacomoschiavo/WABAD/segments/"
for species in os.listdir(TRAIN_PATH):
    for audio in os.listdir(os.path.join(TRAIN_PATH, species)):
        if len(audio.split("_")[0]) <= 6:
            print(species, audio)
            os.rename(
                os.path.join(TRAIN_PATH, species, audio),
                os.path.join(target_path, species, audio)
            )
# Out:
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_22_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230520_054000_45_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230520_054000_48_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_24_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_52_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_55_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230517_075500_7_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230518_084000_28_5.wav
# Muscicapa striata_Spotted Flycatcher POZO_20230601_073000_31_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230518_084000_30_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230520_054000_46_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_25_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230518_084000_33_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230518_084000_31_5.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230517_075500_9_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_54_0.wav
# Muscicapa striata_Spotted Flycatcher POZO_20230601_073000_36_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230519_065500_57_0.wav
# Muscicapa striata_Spotted Flycatcher SLOB_20230517_075500_10_5.wav
# Muscicapa striata_Spotted Flycatcher POZO_20230601_073000_33_0.wav
# Muscicapa striata_Spotted Flycatcher POZO_20230601_073000_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_46_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070102_46_5.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_3_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_31_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_36_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_22_5.wav
# Periparus ater_Coal Tit PINA_20220501_082800_43_5.wav
# Periparus ater_Coal Tit PINA_20220501_082800_10_5.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_40_5.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_48_0.wav
# Periparus ater_Coal Tit PINA_20220602_063400_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_9_0.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_54_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_49_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_36_0.wav
# Periparus ater_Coal Tit PINA_20220504_071900_42_0.wav
# Periparus ater_Coal Tit PINA_20220502_083200_1_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_15_0.wav
# Periparus ater_Coal Tit DYOM_20230506_070102_15_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_1_5.wav
# Periparus ater_Coal Tit PINA_20220501_085000_19_5.wav
# Periparus ater_Coal Tit PINA_20220601_082500_55_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_25_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_25_5.wav
# Periparus ater_Coal Tit PINA_20220601_082500_25_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_54_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_57_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_19_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_31_5.wav
# Periparus ater_Coal Tit GLEN_20230422_060004_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_13_5.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_40_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062702_39_0.wav
# Periparus ater_Coal Tit PINA_20220430_084500_43_5.wav
# Periparus ater_Coal Tit SLOB_20230520_063500_3_0.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_46_5.wav
# Periparus ater_Coal Tit NAV_20230318_080100_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_43_5.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_46_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_0_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_52_5.wav
# Periparus ater_Coal Tit PINA_20220430_083200_6_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_45_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_28_5.wav
# Periparus ater_Coal Tit NAV_20230316_080500_24_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_39_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_15_0.wav
# Periparus ater_Coal Tit PINA_20220506_072200_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_7_5.wav
# Periparus ater_Coal Tit PINA_20220430_083200_9_0.wav
# Periparus ater_Coal Tit NAV_20230316_080800_6_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060202_7_5.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070302_18_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_19_5.wav
# Periparus ater_Coal Tit PINA_20220602_062800_36_0.wav
# Periparus ater_Coal Tit PINA_20220501_083200_19_5.wav
# Periparus ater_Coal Tit NAV_20230316_080200_24_0.wav
# Periparus ater_Coal Tit PINA_20220603_082900_28_5.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_33_0.wav
# Periparus ater_Coal Tit PINA_20220430_085600_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071202_30_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060402_36_0.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_12_0.wav
# Periparus ater_Coal Tit PINA_20220502_083200_33_0.wav
# Periparus ater_Coal Tit DYOM_20230506_062702_37_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_40_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_43_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_49_5.wav
# Periparus ater_Coal Tit NAV_20230316_080300_54_0.wav
# Periparus ater_Coal Tit NAV_20230316_080400_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_49_5.wav
# Periparus ater_Coal Tit PINA_20220501_085000_15_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_30_0.wav
# Periparus ater_Coal Tit DYOM_20230508_072502_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_49_5.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_21_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_36_0.wav
# Periparus ater_Coal Tit PINA_20220430_083200_7_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_7_5.wav
# Periparus ater_Coal Tit NAV_20230319_080600_10_5.wav
# Periparus ater_Coal Tit PINA_20220602_075600_34_5.wav
# Periparus ater_Coal Tit NAV_20230316_080400_28_5.wav
# Periparus ater_Coal Tit NAV_20230317_080500_0_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_57_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_22_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_24_0.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_10_5.wav
# Periparus ater_Coal Tit NAV_20230316_080100_46_5.wav
# Periparus ater_Coal Tit NAV_20230318_080900_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_7_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_52_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_13_5.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_33_0.wav
# Periparus ater_Coal Tit HAR_20220523_125702_16_5.wav
# Periparus ater_Coal Tit PINA_20220504_071500_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_48_0.wav
# Periparus ater_Coal Tit PINA_20220502_090100_37_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_13_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_43_5.wav
# Periparus ater_Coal Tit PINA_20220430_084500_51_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071202_49_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_6_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_16_5.wav
# Periparus ater_Coal Tit PINA_20220602_062800_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_6_0.wav
# Periparus ater_Coal Tit NAV_20230316_080200_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_30_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_18_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_36_0.wav
# Periparus ater_Coal Tit NAV_20230316_080200_43_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_19_5.wav
# Periparus ater_Coal Tit HAG_20200529_131100_7_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_13_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_15_0.wav
# Periparus ater_Coal Tit PINA_20220430_084500_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_43_5.wav
# Periparus ater_Coal Tit PINA_20220506_073400_4_5.wav
# Periparus ater_Coal Tit NAV_20230316_080100_45_0.wav
# Periparus ater_Coal Tit SCHF_20230422_173510_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_21_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_6_0.wav
# Periparus ater_Coal Tit PINA_20220506_073400_52_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_19_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_4_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_30_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_37_5.wav
# Periparus ater_Coal Tit PINA_20220504_070800_4_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_7_5.wav
# Periparus ater_Coal Tit PINA_20220504_071900_39_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_52_5.wav
# Periparus ater_Coal Tit GLEN_20230422_060004_39_0.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_27_0.wav
# Periparus ater_Coal Tit PINA_20220502_083200_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_52_5.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_31_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061302_22_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_48_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_45_0.wav
# Periparus ater_Coal Tit NAV_20230318_080900_13_5.wav
# Periparus ater_Coal Tit GLEN_20230422_060002_51_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_49_5.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_31_5.wav
# Periparus ater_Coal Tit PINA_20220501_082800_9_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_51_0.wav
# Periparus ater_Coal Tit PINA_20220501_090300_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_43_5.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_3_0.wav
# Periparus ater_Coal Tit PINA_20220506_071700_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_18_0.wav
# Periparus ater_Coal Tit NAV_20230319_080300_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071202_1_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_9_0.wav
# Periparus ater_Coal Tit PINA_20220601_082300_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_22_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_25_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_4_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_1_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_37_5.wav
# Periparus ater_Coal Tit HAR_20220613_130702_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_22_5.wav
# Periparus ater_Coal Tit PINA_20220502_083200_39_0.wav
# Periparus ater_Coal Tit PINA_20220601_082500_21_0.wav
# Periparus ater_Coal Tit GLEN_20230507_060005_18_0.wav
# Periparus ater_Coal Tit NAV_20230316_081100_19_5.wav
# Periparus ater_Coal Tit NAV_20230316_080800_21_0.wav
# Periparus ater_Coal Tit PINA_20220501_085000_18_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_27_0.wav
# Periparus ater_Coal Tit PINA_20220602_063400_7_5.wav
# Periparus ater_Coal Tit DYOM_20230508_072502_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_46_5.wav
# Periparus ater_Coal Tit NAV_20230316_080200_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_54_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_16_5.wav
# Periparus ater_Coal Tit NAV_20230316_080800_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_39_0.wav
# Periparus ater_Coal Tit NAV_20230316_080300_52_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_34_5.wav
# Periparus ater_Coal Tit PINA_20220601_082300_37_5.wav
# Periparus ater_Coal Tit NAV_20230318_080900_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_40_5.wav
# Periparus ater_Coal Tit PINA_20220506_073400_45_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_22_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_6_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_48_0.wav
# Periparus ater_Coal Tit SCHF_20230428_063510_6_0.wav
# Periparus ater_Coal Tit PINA_20220501_090300_3_0.wav
# Periparus ater_Coal Tit DYOM_20230506_062702_31_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070102_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_24_0.wav
# Periparus ater_Coal Tit SLOB_20230520_063500_48_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_43_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_31_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_4_5.wav
# Periparus ater_Coal Tit NAV_20230316_080200_19_5.wav
# Periparus ater_Coal Tit DYOM_20230511_061602_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_48_0.wav
# Periparus ater_Coal Tit NAV_20230316_080400_49_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061702_22_5.wav
# Periparus ater_Coal Tit PINA_20220506_072200_30_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_4_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_18_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_6_0.wav
# Periparus ater_Coal Tit PINA_20220502_083700_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_49_5.wav
# Periparus ater_Coal Tit PINA_20220506_073700_22_5.wav
# Periparus ater_Coal Tit PINA_20220506_073700_55_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_34_5.wav
# Periparus ater_Coal Tit NAV_20230316_080800_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_27_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_51_0.wav
# Periparus ater_Coal Tit NAV_20230316_080100_31_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070102_9_0.wav
# Periparus ater_Coal Tit PINA_20220602_061400_18_0.wav
# Periparus ater_Coal Tit PINA_20220504_071900_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_24_0.wav
# Periparus ater_Coal Tit GLEN_20230422_060002_33_0.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_34_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_10_5.wav
# Periparus ater_Coal Tit PINA_20220504_072700_54_0.wav
# Periparus ater_Coal Tit PINA_20220602_075600_49_5.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_13_5.wav
# Periparus ater_Coal Tit PINA_20220501_082500_21_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_19_5.wav
# Periparus ater_Coal Tit PINA_20220506_073400_15_0.wav
# Periparus ater_Coal Tit PINA_20220501_082800_33_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060702_31_5.wav
# Periparus ater_Coal Tit PINA_20220504_071500_3_0.wav
# Periparus ater_Coal Tit PINA_20220504_071500_34_5.wav
# Periparus ater_Coal Tit PINA_20220603_082900_9_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_51_0.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_16_5.wav
# Periparus ater_Coal Tit PINA_20220602_063400_42_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_40_5.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_37_5.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_28_5.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_28_5.wav
# Periparus ater_Coal Tit PINA_20220501_083200_18_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060402_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_36_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_3_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060702_24_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_22_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050004_33_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_49_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_33_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_21_0.wav
# Periparus ater_Coal Tit PINA_20220602_063400_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_10_5.wav
# Periparus ater_Coal Tit PINA_20220603_082900_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061302_12_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_33_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_40_5.wav
# Periparus ater_Coal Tit PINA_20220501_090300_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_33_0.wav
# Periparus ater_Coal Tit PINA_20220430_085600_51_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_54_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_18_0.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_54_0.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_7_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_6_0.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_51_0.wav
# Periparus ater_Coal Tit PINA_20220506_072200_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_3_0.wav
# Periparus ater_Coal Tit PINA_20220603_083500_57_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_34_5.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_22_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_49_5.wav
# Periparus ater_Coal Tit PINA_20220504_071900_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_13_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_36_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_49_5.wav
# Periparus ater_Coal Tit PINA_20220506_071700_39_0.wav
# Periparus ater_Coal Tit PINA_20220506_073700_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_31_5.wav
# Periparus ater_Coal Tit NAV_20230316_080800_19_5.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_45_0.wav
# Periparus ater_Coal Tit NAV_20230316_080400_30_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_54_0.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_25_5.wav
# Periparus ater_Coal Tit NAV_20230316_081100_52_5.wav
# Periparus ater_Coal Tit PINA_20220430_083200_4_5.wav
# Periparus ater_Coal Tit NAV_20230316_080500_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_54_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_12_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061502_45_0.wav
# Periparus ater_Coal Tit PINA_20220506_071700_9_0.wav
# Periparus ater_Coal Tit PINA_20220602_063400_16_5.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_25_5.wav
# Periparus ater_Coal Tit HAR_20220523_125702_36_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_49_5.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_43_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060402_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_19_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061702_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_25_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_15_0.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_54_0.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_16_5.wav
# Periparus ater_Coal Tit NAV_20230316_080400_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_6_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_22_5.wav
# Periparus ater_Coal Tit PINA_20220602_075600_9_0.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_30_0.wav
# Periparus ater_Coal Tit HAR_20220523_125702_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_16_5.wav
# Periparus ater_Coal Tit PINA_20220603_081500_30_0.wav
# Periparus ater_Coal Tit PINA_20220502_090100_36_0.wav
# Periparus ater_Coal Tit NAV_20230318_080900_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_45_0.wav
# Periparus ater_Coal Tit PINA_20220602_075600_25_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_6_0.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_13_5.wav
# Periparus ater_Coal Tit NAV_20230316_080100_9_0.wav
# Periparus ater_Coal Tit NAV_20230316_081100_15_0.wav
# Periparus ater_Coal Tit PINA_20220502_090100_0_0.wav
# Periparus ater_Coal Tit NAV_20230318_080900_24_0.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060202_30_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_6_0.wav
# Periparus ater_Coal Tit NAV_20230316_080400_31_5.wav
# Periparus ater_Coal Tit NAV_20230316_081100_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_6_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_51_0.wav
# Periparus ater_Coal Tit NAV_20230316_081100_40_5.wav
# Periparus ater_Coal Tit HAR_20220523_125702_37_5.wav
# Periparus ater_Coal Tit PINA_20220601_082300_31_5.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_28_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_40_5.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_51_0.wav
# Periparus ater_Coal Tit SCHF_20230428_063510_16_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_13_5.wav
# Periparus ater_Coal Tit HAR_20220523_125702_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_39_0.wav
# Periparus ater_Coal Tit NAV_20230316_080200_33_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_3_0.wav
# Periparus ater_Coal Tit HAR_20220523_125702_49_5.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_31_5.wav
# Periparus ater_Coal Tit NAV_20230316_081100_21_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_24_0.wav
# Periparus ater_Coal Tit HAG_20190514_070000_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_43_5.wav
# Periparus ater_Coal Tit PINA_20220601_082300_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_27_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_39_0.wav
# Periparus ater_Coal Tit DYOM_20230506_081102_12_0.wav
# Periparus ater_Coal Tit NAV_20230315_080300_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071202_28_5.wav
# Periparus ater_Coal Tit PINA_20220506_073400_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_30_0.wav
# Periparus ater_Coal Tit PINA_20220502_083700_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_0_0.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_1_5.wav
# Periparus ater_Coal Tit GLEN_20230422_060002_43_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_31_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_45_0.wav
# Periparus ater_Coal Tit PINA_20220506_073400_54_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_36_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_18_0.wav
# Periparus ater_Coal Tit NAV_20230316_080100_24_0.wav
# Periparus ater_Coal Tit PINA_20220502_090100_16_5.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_46_5.wav
# Periparus ater_Coal Tit GLEN_20230422_060004_10_5.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_10_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_37_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_49_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061702_3_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060702_27_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_36_0.wav
# Periparus ater_Coal Tit PINA_20220601_082300_7_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_49_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_7_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_33_0.wav
# Periparus ater_Coal Tit PINA_20220603_081500_6_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_57_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_51_0.wav
# Periparus ater_Coal Tit NAV_20230318_080900_18_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_49_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_28_5.wav
# Periparus ater_Coal Tit GLEN_20230507_060005_7_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_0_0.wav
# Periparus ater_Coal Tit NAV_20230316_080500_13_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_54_0.wav
# Periparus ater_Coal Tit NAV_20230316_080800_46_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083800_19_5.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_19_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_13_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_57_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_43_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060202_0_0.wav
# Periparus ater_Coal Tit PINA_20220601_074600_7_5.wav
# Periparus ater_Coal Tit NAV_20230318_080100_42_0.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_27_0.wav
# Periparus ater_Coal Tit DYOM_20230506_081102_34_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_51_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060702_34_5.wav
# Periparus ater_Coal Tit NAV_20230318_080100_25_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_28_5.wav
# Periparus ater_Coal Tit NAV_20230318_080900_3_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_24_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_7_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_10_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_21_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_21_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_51_0.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_31_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_48_0.wav
# Periparus ater_Coal Tit PINA_20220506_073400_36_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_30_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_30_0.wav
# Periparus ater_Coal Tit PINA_20220506_071700_13_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_28_5.wav
# Periparus ater_Coal Tit NAV_20230318_080900_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_1_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_19_5.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_6_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_19_5.wav
# Periparus ater_Coal Tit PINA_20220601_082500_27_0.wav
# Periparus ater_Coal Tit NAV_20230316_080500_10_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_48_0.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_19_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_9_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_45_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_55_5.wav
# Periparus ater_Coal Tit PINA_20220502_090100_15_0.wav
# Periparus ater_Coal Tit PINA_20220601_074600_9_0.wav
# Periparus ater_Coal Tit PINA_20220602_062800_39_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_25_5.wav
# Periparus ater_Coal Tit PINA_20220501_082500_18_0.wav
# Periparus ater_Coal Tit NAV_20230316_080200_12_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_36_0.wav
# Periparus ater_Coal Tit PINA_20220430_085600_4_5.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_10_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_31_5.wav
# Periparus ater_Coal Tit PINA_20220602_063400_21_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_9_0.wav
# Periparus ater_Coal Tit PINA_20220602_075600_39_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_48_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_31_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_16_5.wav
# Periparus ater_Coal Tit PINA_20220501_082800_1_5.wav
# Periparus ater_Coal Tit NAV_20230316_081100_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_42_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_49_5.wav
# Periparus ater_Coal Tit PINA_20220602_063400_45_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_48_0.wav
# Periparus ater_Coal Tit PINA_20220502_083200_54_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_31_5.wav
# Periparus ater_Coal Tit NAV_20230316_080800_48_0.wav
# Periparus ater_Coal Tit GLEN_20230507_060005_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_43_5.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_42_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_9_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_49_5.wav
# Periparus ater_Coal Tit PINA_20220501_082500_49_5.wav
# Periparus ater_Coal Tit DYOM_20230506_081102_33_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070302_42_0.wav
# Periparus ater_Coal Tit PINA_20220602_061400_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_9_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_1_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_13_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_30_0.wav
# Periparus ater_Coal Tit NAV_20230317_080500_34_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_0_0.wav
# Periparus ater_Coal Tit PINA_20220501_082800_31_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060202_15_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_33_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_54_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_9_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_24_0.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_43_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_21_0.wav
# Periparus ater_Coal Tit PINA_20220502_083700_36_0.wav
# Periparus ater_Coal Tit PINA_20220506_071700_6_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061102_7_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_42_0.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_49_5.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_54_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_16_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_52_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_4_5.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_46_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061702_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_0_0.wav
# Periparus ater_Coal Tit PINA_20220602_063400_33_0.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_49_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_31_5.wav
# Periparus ater_Coal Tit NAV_20230316_080200_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_48_0.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_33_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_18_0.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_12_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_48_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060000_28_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_6_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070302_43_5.wav
# Periparus ater_Coal Tit NAV_20230316_080100_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_42_0.wav
# Periparus ater_Coal Tit NAV_20230316_080100_42_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061302_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_18_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_43_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_42_0.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_37_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_34_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_13_5.wav
# Periparus ater_Coal Tit GLEN_20230422_060004_42_0.wav
# Periparus ater_Coal Tit PINA_20220502_090100_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_4_5.wav
# Periparus ater_Coal Tit NAV_20230316_081100_43_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_6_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_28_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060402_0_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_33_0.wav
# Periparus ater_Coal Tit NAV_20230317_080500_40_5.wav
# Periparus ater_Coal Tit PINA_20220430_085600_40_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_27_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_6_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_39_0.wav
# Periparus ater_Coal Tit PINA_20220601_074600_21_0.wav
# Periparus ater_Coal Tit NAV_20230318_080800_6_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_3_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050004_48_0.wav
# Periparus ater_Coal Tit DYOM_20230508_072502_22_5.wav
# Periparus ater_Coal Tit PINA_20220603_083500_22_5.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_49_5.wav
# Periparus ater_Coal Tit HAG_20190514_070000_39_0.wav
# Periparus ater_Coal Tit PINA_20220501_090300_1_5.wav
# Periparus ater_Coal Tit PINA_20220504_070500_57_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_28_5.wav
# Periparus ater_Coal Tit NAV_20230318_080800_28_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050004_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_10_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_39_0.wav
# Periparus ater_Coal Tit SLOB_20230521_083800_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_46_5.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_36_0.wav
# Periparus ater_Coal Tit PINA_20220601_082500_16_5.wav
# Periparus ater_Coal Tit SLOB_20230520_063500_40_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_18_0.wav
# Periparus ater_Coal Tit SLOB_20230520_063700_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_10_5.wav
# Periparus ater_Coal Tit NAV_20230318_080100_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062202_10_5.wav
# Periparus ater_Coal Tit NAV_20230316_080100_18_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_37_5.wav
# Periparus ater_Coal Tit DYOM_20230509_061502_37_5.wav
# Periparus ater_Coal Tit PINA_20220430_084500_0_0.wav
# Periparus ater_Coal Tit DYOM_20230512_060402_51_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_52_5.wav
# Periparus ater_Coal Tit PINA_20220501_082800_19_5.wav
# Periparus ater_Coal Tit DYOM_20230506_081102_28_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_54_0.wav
# Periparus ater_Coal Tit NAV_20230316_080100_49_5.wav
# Periparus ater_Coal Tit NAV_20230318_080900_43_5.wav
# Periparus ater_Coal Tit DYOM_20230511_061602_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_9_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050004_52_5.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_36_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_39_0.wav
# Periparus ater_Coal Tit PINA_20220504_071900_16_5.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_31_5.wav
# Periparus ater_Coal Tit PINA_20220602_062100_39_0.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_24_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_18_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061502_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_24_0.wav
# Periparus ater_Coal Tit NAV_20230316_080800_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_16_5.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_18_0.wav
# Periparus ater_Coal Tit NAV_20230315_080300_25_5.wav
# Periparus ater_Coal Tit NAV_20230318_080800_43_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_43_5.wav
# Periparus ater_Coal Tit NAV_20230319_080300_52_5.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_48_0.wav
# Periparus ater_Coal Tit PINA_20220506_073700_21_0.wav
# Periparus ater_Coal Tit SLOB_20230428_080300_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_24_0.wav
# Periparus ater_Coal Tit SCHF_20230428_063510_3_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_51_0.wav
# Periparus ater_Coal Tit PINA_20220502_083200_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_42_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060902_25_5.wav
# Periparus ater_Coal Tit PINA_20220603_083500_7_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_54_0.wav
# Periparus ater_Coal Tit PINA_20220506_073700_24_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_33_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060102_7_5.wav
# Periparus ater_Coal Tit PINA_20220502_083200_4_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_19_5.wav
# Periparus ater_Coal Tit PINA_20220502_090100_30_0.wav
# Periparus ater_Coal Tit PINA_20220601_082300_36_0.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_12_0.wav
# Periparus ater_Coal Tit PINA_20220504_071500_6_0.wav
# Periparus ater_Coal Tit SLOB_20230521_083800_15_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060402_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_0_0.wav
# Periparus ater_Coal Tit PINA_20220504_072700_52_5.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_15_0.wav
# Periparus ater_Coal Tit DYOM_20230506_070000_52_5.wav
# Periparus ater_Coal Tit SLOB_20230520_063500_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060102_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062402_1_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_24_0.wav
# Periparus ater_Coal Tit PINA_20220430_085600_21_0.wav
# Periparus ater_Coal Tit DYOM_20230506_081102_3_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_36_0.wav
# Periparus ater_Coal Tit PINA_20220506_071700_51_0.wav
# Periparus ater_Coal Tit NAV_20230316_080200_40_5.wav
# Periparus ater_Coal Tit PINA_20220501_082500_12_0.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_51_0.wav
# Periparus ater_Coal Tit DYOM_20230508_080902_42_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_10_5.wav
# Periparus ater_Coal Tit HAR_20220523_125702_57_0.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062502_13_5.wav
# Periparus ater_Coal Tit HAR_20220613_130702_30_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_21_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062802_21_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_10_5.wav
# Periparus ater_Coal Tit PINA_20220502_083200_25_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_28_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_15_0.wav
# Periparus ater_Coal Tit NAV_20230316_080300_9_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060102_1_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_7_5.wav
# Periparus ater_Coal Tit HAR_20220613_130702_0_0.wav
# Periparus ater_Coal Tit PINA_20220504_072500_45_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_3_0.wav
# Periparus ater_Coal Tit NAV_20230316_080100_39_0.wav
# Periparus ater_Coal Tit GLEN_20230425_050004_42_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_46_5.wav
# Periparus ater_Coal Tit DYOM_20230508_070302_42_0.wav
# Periparus ater_Coal Tit PINA_20220430_085600_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_36_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061202_3_0.wav
# Periparus ater_Coal Tit NAV_20230319_080600_4_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060302_15_0.wav
# Periparus ater_Coal Tit DYOM_20230512_061002_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_21_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_37_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060102_51_0.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_39_0.wav
# Periparus ater_Coal Tit DYOM_20230509_061602_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072102_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061102_21_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070102_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060702_34_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062702_33_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_21_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_43_5.wav
# Periparus ater_Coal Tit SLOB_20230521_083600_43_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_19_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_6_0.wav
# Periparus ater_Coal Tit PINA_20220506_071700_45_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_27_0.wav
# Periparus ater_Coal Tit PINA_20220601_074600_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_082602_18_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_28_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_13_5.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_48_0.wav
# Periparus ater_Coal Tit NAV_20230316_080500_51_0.wav
# Periparus ater_Coal Tit DYOM_20230506_062702_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060502_54_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_37_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070602_28_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062902_52_5.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_25_5.wav
# Periparus ater_Coal Tit PINA_20220603_082300_27_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061302_10_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061702_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_46_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_42_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062902_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060102_3_0.wav
# Periparus ater_Coal Tit PINA_20220504_071900_57_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_9_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060702_31_5.wav
# Periparus ater_Coal Tit PINA_20220506_073700_6_0.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_15_0.wav
# Periparus ater_Coal Tit DYOM_20230506_070102_18_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_22_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072302_34_5.wav
# Periparus ater_Coal Tit PINA_20220603_081500_24_0.wav
# Periparus ater_Coal Tit PINA_20220501_085000_12_0.wav
# Periparus ater_Coal Tit PINA_20220601_074600_30_0.wav
# Periparus ater_Coal Tit NAV_20230317_080500_1_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_30_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_25_5.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_52_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_31_5.wav
# Periparus ater_Coal Tit DYOM_20230508_062402_25_5.wav
# Periparus ater_Coal Tit PINA_20220430_085600_33_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_54_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_12_0.wav
# Periparus ater_Coal Tit NAV_20230316_081100_48_0.wav
# Periparus ater_Coal Tit BIAL_20210423_070904_30_0.wav
# Periparus ater_Coal Tit PINA_20220502_083700_30_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_40_5.wav
# Periparus ater_Coal Tit PINA_20220501_085000_9_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_10_5.wav
# Periparus ater_Coal Tit DYOM_20230507_060302_51_0.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_7_5.wav
# Periparus ater_Coal Tit PINA_20220506_073400_46_5.wav
# Periparus ater_Coal Tit GLEN_20230507_060005_1_5.wav
# Periparus ater_Coal Tit PINA_20220501_085000_16_5.wav
# Periparus ater_Coal Tit PINA_20220430_084500_30_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061502_12_0.wav
# Periparus ater_Coal Tit NAV_20230316_080400_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_10_5.wav
# Periparus ater_Coal Tit PINA_20220501_082500_51_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060000_57_0.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_12_0.wav
# Periparus ater_Coal Tit PINA_20220603_081500_48_0.wav
# Periparus ater_Coal Tit DYOM_20230510_060202_43_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061302_1_5.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_18_0.wav
# Periparus ater_Coal Tit DYOM_20230508_062202_15_0.wav
# Periparus ater_Coal Tit PINA_20220501_082500_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_45_0.wav
# Periparus ater_Coal Tit DYOM_20230508_060402_48_0.wav
# Periparus ater_Coal Tit DYOM_20230507_062102_7_5.wav
# Periparus ater_Coal Tit DYOM_20230512_060702_43_5.wav
# Periparus ater_Coal Tit GLEN_20230418_050005_25_5.wav
# Periparus ater_Coal Tit DYOM_20230507_061702_31_5.wav
# Periparus ater_Coal Tit PINA_20220502_083200_40_5.wav
# Periparus ater_Coal Tit DYOM_20230507_062602_13_5.wav
# Periparus ater_Coal Tit DYOM_20230507_072202_16_5.wav
# Periparus ater_Coal Tit NAV_20230316_080100_25_5.wav
# Periparus ater_Coal Tit NAV_20230316_080800_39_0.wav
# Periparus ater_Coal Tit DYOM_20230507_061802_19_5.wav
# Periparus ater_Coal Tit NAV_20230318_080900_57_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071602_34_5.wav
# Periparus ater_Coal Tit DYOM_20230507_071302_18_0.wav
# Periparus ater_Coal Tit NAV_20230318_080100_30_0.wav
# Periparus ater_Coal Tit DYOM_20230511_060102_34_5.wav
# Periparus ater_Coal Tit PINA_20220602_062100_1_5.wav
# Periparus ater_Coal Tit GLEN_20230424_060001_18_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070402_33_0.wav
# Periparus ater_Coal Tit DYOM_20230507_070702_21_0.wav
# Periparus ater_Coal Tit PINA_20220430_084500_12_0.wav
# Periparus ater_Coal Tit DYOM_20230507_060202_21_0.wav
# Periparus ater_Coal Tit PINA_20220502_083200_31_5.wav
# Periparus ater_Coal Tit DYOM_20230506_062702_28_5.wav
# Periparus ater_Coal Tit PINA_20220504_071500_1_5.wav
# Periparus ater_Coal Tit DYOM_20230509_060000_49_5.wav
# Periparus ater_Coal Tit DYOM_20230508_060802_15_0.wav
# Periparus ater_Coal Tit DYOM_20230508_061002_1_5.wav
# Periparus ater_Coal Tit PINA_20220506_071700_7_5.wav
# Periparus ater_Coal Tit SCHF_20230422_173510_36_0.wav
# Periparus ater_Coal Tit DYOM_20230507_071202_54_0.wav
# Periparus ater_Coal Tit PINA_20220506_073700_25_5.wav
# ...
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_24_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_3_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_12_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_43_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_18_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_16_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_18_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_49_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_40_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_34_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_33_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_34_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_30_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_40_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_48_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_36_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_19_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_21_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_46_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_18_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_27_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_081500_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_19_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_49_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_34_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_15_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_25_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_51_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_48_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_12_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_48_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_49_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_24_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_30_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_51_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_25_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_46_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_1_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_40_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_6_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_33_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_48_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_0_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_071500_48_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_22_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_37_5.wav
# Lophophanes cristatus_Crested Tit COU_20220629_064602_25_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_1_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_42_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_31_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_54_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070800_51_0.wav
# Lophophanes cristatus_Crested Tit COU_20220629_064602_27_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070800_49_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_55_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_25_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_45_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_54_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_40_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_1_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_3_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_24_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_22_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_30_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_1_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_25_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_45_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_45_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_55_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_16_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_19_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_16_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_30_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_071500_42_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_24_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_40_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_18_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_31_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_071500_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_45_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_7_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_19_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_28_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_45_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_55_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_1_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_12_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_27_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_30_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_40_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_18_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_55_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_7_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_52_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_45_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_7_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_7_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_31_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_19_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_4_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_34_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_49_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_28_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_18_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_7_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_071500_45_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_42_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_16_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_13_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_42_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_18_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_1_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_33_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_37_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_25_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_54_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_15_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_36_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_34_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_1_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_0_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_37_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_24_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_15_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_12_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_49_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_31_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_54_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_28_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_46_5.wav
# Lophophanes cristatus_Crested Tit COU_20220629_064602_24_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_36_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_25_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_12_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_46_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220502_083200_13_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_21_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_3_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_21_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_0_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_0_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_13_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_7_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_49_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_42_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_40_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_6_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_4_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_33_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220502_084800_36_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_15_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_51_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_42_0.wav
# Lophophanes cristatus_Crested Tit COU_20220629_064602_22_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_55_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_28_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_30_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_13_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_3_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_33_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_57_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_18_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_57_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_081500_36_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_19_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_28_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230316_080100_27_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_46_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_31_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_54_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_52_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_6_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_4_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_49_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_36_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220502_083200_15_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_16_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_15_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_54_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_42_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_4_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_0_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_28_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_57_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_55_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_082300_21_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_081500_37_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_39_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_57_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_15_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_10_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_48_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_55_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_57_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_57_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_22_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_21_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_51_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_18_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220603_085300_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_45_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_46_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_28_5.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_34_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_3_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_31_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_31_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_6_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070800_52_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_30_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_46_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_074600_55_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_22_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_15_0.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_27_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_22_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220504_070500_36_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_4_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220502_084800_33_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_074900_36_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080900_0_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220601_084500_43_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_083200_48_0.wav
# Lophophanes cristatus_Crested Tit NAV_20230318_080300_37_5.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_9_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220506_075200_25_5.wav
# Lophophanes cristatus_Crested Tit HAG_20200529_131500_45_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220501_084500_27_0.wav
# Lophophanes cristatus_Crested Tit PINA_20220602_062100_16_5.wav

# %%
dataset_species_count_wabad = {}
for species in os.listdir(test_folder):
    dataset_species_count_wabad[species] = {
        "train": len(os.listdir(os.path.join(train_folder, species))),
        "test": len(os.listdir(os.path.join(test_folder, species)))
    }
dataset_species_count_df = pd.DataFrame.from_dict(dataset_species_count_wabad, orient='index')
dataset_species_count_df.index.name = 'Species'
dataset_species_count_df.sort_values(by="train", ascending=False)
# Out:
#                                             train  test
# Species
# None                                        11000  5116
# Fringilla coelebs_Common Chaffinch           6662   981
# Regulus regulus_Goldcrest                    5589    10
# Periparus ater_Coal Tit                      5491    20
# Turdus merula_Eurasian Blackbird             5255   307
# Turdus philomelos_Song Thrush                4225    58
# Sylvia atricapilla_Eurasian Blackcap         3196   487
# Regulus ignicapilla_Common Firecrest         3054   231
# Certhia familiaris_Eurasian Treecreeper      1818     3
# Phylloscopus collybita_Common Chiffchaff     1780   669
# Erithacus rubecula_European Robin            1407   549
# Muscicapa striata_Spotted Flycatcher         1301    14
# Troglodytes troglodytes_Eurasian Wren        1189   111
# Lophophanes cristatus_Crested Tit             973     3
# Wind                                          731   146
# Loxia curvirostra_Common Crossbill            711    49
# Dendrocopos major_Great Spotted Woodpecker    578    16
# Rain                                          353    23
# Dryocopus martius_Black Woodpecker            344    21
# Vegetation                                    188    26
# Pecking                                       175     8
# Aeroplane                                      47    22

# %% [markdown]
# # Augmentation

# %%
# MOVE ALREADY CALCULATED AUGMENTATIONS
# REMOVED_PATH = f'{DATASET_PATH}/augm_removed'
# if os.path.exists(REMOVED_PATH):
#     for species in os.listdir(REMOVED_PATH):
#         for audio in os.listdir(os.path.join(REMOVED_PATH, species)):
#             print(species, audio)
#             os.rename(
#                 os.path.join(REMOVED_PATH, species, audio),
#                 os.path.join(TRAIN_PATH, species, audio)
#             )

# %%
import librosa
import soundfile as sf
from audiomentations import Compose, PitchShift, TimeStretch, AddBackgroundNoise, Gain

# %%
def load_audio(file_path):
    audio, sr = librosa.load(file_path, sr=None)
    return audio, sr

def save_audio(file_path, audio, sr):
    sf.write(file_path, audio, sr)

# %%
bg_noise_path = f"{DATASET_PATH}/train_removed/None"
bg_noises = os.listdir(bg_noise_path)
augmentations = {
    "psA": Compose([PitchShift(min_semitones=-3, max_semitones=-1, p=0.75)]),
    "psB": Compose([PitchShift(min_semitones=1, max_semitones=3, p=0.75)]),
    "ts": Compose([TimeStretch(min_rate=0.9, max_rate=1.1, p=0.75)]),
    "bn": Compose([
        AddBackgroundNoise(sounds_path=os.path.join(bg_noise_path, random.choice(bg_noises)), p=0.8),
        Gain(min_gain_db=-5, max_gain_db=5, p=0.5) 
    ]),
}


def apply_augmentations(file_path, output_dir):
    audio, sr = load_audio(file_path)
    
    for aug_name, aug in augmentations.items():
        file_name = os.path.splitext(file_path)[0].split('/')[-1]
        if "aug" in file_name:
            continue
        save_audio_path = f"{output_dir}/{file_name}_aug_{aug_name}.wav"
        if os.path.exists(save_audio_path):
            continue
        augmented_audio = aug(samples=audio, sample_rate=sr)
        save_audio(save_audio_path, augmented_audio, sr)

# %%
# pick samples where validation samples == 0
train_folder = f'{DATASET_PATH}/train'
species_to_augment = []
threshold = 1000
for species in os.listdir(train_folder):
    if len(species.split("_")) <= 1:
        print(species, "skipped")
        continue
    if len(os.listdir(os.path.join(train_folder, species))) >= threshold:
        continue
    species_to_augment.append(species)

species_to_augment
# Out:
# Aeroplane skipped
# Rain skipped
# Vegetation skipped
# None skipped
# Wind skipped
# Pecking skipped
# ['Muscicapa striata_Spotted Flycatcher',
#  'Periparus ater_Coal Tit',
#  'Regulus regulus_Goldcrest',
#  'Dryocopus martius_Black Woodpecker',
#  'Certhia familiaris_Eurasian Treecreeper',
#  'Turdus merula_Eurasian Blackbird',
#  'Loxia curvirostra_Common Crossbill',
#  'Dendrocopos major_Great Spotted Woodpecker',
#  'Lophophanes cristatus_Crested Tit']

# %%
for species in species_to_augment:
    files = os.listdir(os.path.join(train_folder, species))
    print("Augmenting ", species)
    for i in tqdm(range(len(files)), colour="blue"):
        audio = files[i]
        apply_augmentations(os.path.join(train_folder, species, audio), os.path.join(train_folder, species))
# Out:
# Augmenting  Muscicapa striata_Spotted Flycatcher
# 100%|██████████| 256/256 [00:34<00:00,  7.36it/s]
# Augmenting  Periparus ater_Coal Tit
# 100%|██████████| 375/375 [00:49<00:00,  7.61it/s]
# Augmenting  Regulus regulus_Goldcrest
# 100%|██████████| 918/918 [01:58<00:00,  7.74it/s]
# Augmenting  Dryocopus martius_Black Woodpecker
#  53%|█████▎    | 25/47 [00:02<00:02,  8.33it/s]/opt/conda/envs/myenv/lib/python3.10/site-packages/audiomentations/core/audio_loading_utils.py:37: UserWarning: /home/giacomoschiavo/segments/dataset/train_removed/None/20200217_110000_39_0.wav had to be resampled from 48000 Hz to 44100 Hz. This hurt execution time.
#   warnings.warn(
# 100%|██████████| 47/47 [00:05<00:00,  7.98it/s]
# Augmenting  Certhia familiaris_Eurasian Treecreeper
# 100%|██████████| 324/324 [00:42<00:00,  7.56it/s]
# Augmenting  Turdus merula_Eurasian Blackbird
# 100%|██████████| 251/251 [00:34<00:00,  7.37it/s]
# Augmenting  Loxia curvirostra_Common Crossbill
# 100%|██████████| 119/119 [00:15<00:00,  7.78it/s]
# Augmenting  Dendrocopos major_Great Spotted Woodpecker
# 100%|██████████| 23/23 [00:03<00:00,  6.82it/s]
# Augmenting  Lophophanes cristatus_Crested Tit
# 100%|██████████| 138/138 [00:18<00:00,  7.66it/s]

# %%
print_dataset_count_table(DATASET_PATH)
# Out:
#                                             train  valid  test
# Species
# None                                         7000   2098  5116
# Fringilla coelebs_Common Chaffinch           6662   1918   981
# Regulus regulus_Goldcrest                    4590     57    10
# Turdus philomelos_Song Thrush                4225   1056    58
# Sylvia atricapilla_Eurasian Blackcap         3196    708   487
# Regulus ignicapilla_Common Firecrest         3054    312   231
# Periparus ater_Coal Tit                      1875      6    20
# Phylloscopus collybita_Common Chiffchaff     1780    402   669
# Certhia familiaris_Eurasian Treecreeper      1620      4     3
# Erithacus rubecula_European Robin            1407     58   549
# Muscicapa striata_Spotted Flycatcher         1280     15    14
# Turdus merula_Eurasian Blackbird             1255     13   307
# Troglodytes troglodytes_Eurasian Wren        1189     43   111
# Wind                                          731     75   146
# Lophophanes cristatus_Crested Tit             690     17     3
# Loxia curvirostra_Common Crossbill            595     29    49
# Rain                                          353     88    23
# Dryocopus martius_Black Woodpecker            235     10    21
# Vegetation                                    188      5    26
# Pecking                                       175     34     8
# Dendrocopos major_Great Spotted Woodpecker    115      5    16
# Aeroplane                                      47      8    22

# %% [markdown]
# ## Augmentation removal

# %%
train_path = f"{DATASET_PATH}/train"
target_path = f"{DATASET_PATH}/augm_removed"
os.makedirs(target_path, exist_ok=True)
for species in os.listdir(train_path):
    for audio in os.listdir(os.path.join(train_path, species)):
        os.makedirs(os.path.join(target_path, species), exist_ok=True)
        if "aug" in audio:
            os.rename(
                os.path.join(train_path, species, audio),
                os.path.join(target_path, species, audio),
            )

# %%
print_dataset_count_table(DATASET_PATH)
# Out:
#                                             train  valid  test
# Species
# None                                         7000   2098  5116
# Fringilla coelebs_Common Chaffinch           6662   1918   981
# Turdus philomelos_Song Thrush                4225   1056    58
# Sylvia atricapilla_Eurasian Blackcap         3196    708   487
# Regulus ignicapilla_Common Firecrest         3054    312   231
# Phylloscopus collybita_Common Chiffchaff     1780    402   669
# Erithacus rubecula_European Robin            1407     58   549
# Troglodytes troglodytes_Eurasian Wren        1189     43   111
# Regulus regulus_Goldcrest                     918     57    10
# Wind                                          731     75   146
# Periparus ater_Coal Tit                       375      6    20
# Rain                                          353     88    23
# Certhia familiaris_Eurasian Treecreeper       324      4     3
# Muscicapa striata_Spotted Flycatcher          256     15    14
# Turdus merula_Eurasian Blackbird              251     13   307
# Vegetation                                    188      5    26
# Pecking                                       175     34     8
# Lophophanes cristatus_Crested Tit             138     17     3
# Loxia curvirostra_Common Crossbill            119     29    49
# Aeroplane                                      47      8    22
# Dryocopus martius_Black Woodpecker             47     10    21
# Dendrocopos major_Great Spotted Woodpecker     23      5    16

# %% [markdown]
# # SNR Filter

# %%
def calculate_snr(audio_path):
    """
    Calculates the Signal-to-Noise Ratio (SNR) of an audio file with respect to a noise segment.

    - audio_path: path to the audio file
    - noise_start, noise_end: time interval in seconds where the noise is isolated
    """
    
    noise_audio = f"{DATASET_PATH}/None/20190603_110000_322_5.wav"
    y_noise, sr_noise = librosa.load(noise_audio, sr=None)
    
    noise_sample = y_noise[:]
    
    y, sr = librosa.load(audio_path, sr=None)
    signal_power = np.mean(y**2)
    noise_power = np.mean(noise_sample**2)
    
    if noise_power == 0:
        return np.inf
    
    snr_db = 10 * np.log10(signal_power / noise_power)
    return snr_db

# %%
species_to_reduce = []
threshold = 200
train_folder = f'{DATASET_PATH}/train'
for species in os.listdir(train_folder):
    if len(species.split("_")) <= 1:
        continue
    if len(os.listdir(os.path.join(train_folder, species))) <= threshold:
        continue
    species_to_reduce.append(species)

# %%
info = {}
for species in species_to_reduce:
    info[species] = {}
    for audio_path in os.listdir(os.path.join(train_folder, species)):
        full_audio_path = os.path.join(train_folder, species, audio_path)
        snr = calculate_snr(full_audio_path)
        info[species][audio_path] = snr

# %%
with open(f"utils/{DATASET_NAME}/audio_snr_info.json", "w") as f:
    json.dump(info, f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Raccolta di tutti gli SNR in una lista unica
all_snr_values = []
for specie in info:
    all_snr_values.extend(info[specie].values())

# Creazione dell'istogramma
plt.figure(figsize=(10, 6))
sns.histplot(all_snr_values, bins=30, kde=True)

# Titoli e labels
plt.title("Distribuzione degli SNR per tutte le specie")
plt.xlabel("SNR")
plt.ylabel("Frequenza")

# Mostra il grafico
plt.show()

# %%
# Initialize the dictionary to store the results
top_800_per_specie = {}

# Iterate through each species in the 'info' dictionary
for species, files in info.items():
    # Filter files with SNR less than 20 dB
    snr_below_20 = {file: snr for file, snr in files.items() if snr < 20}
    
    # Sort the filtered files by SNR in descending order
    sorted_files = sorted(snr_below_20.items(), key=lambda item: item[1], reverse=True)
    
    # Select the first 800 files from the sorted list
    best_800 = [file for file, snr in sorted_files[:800]]
    
    # Add the species and the list of the best 800 files to the results dictionary
    top_800_per_specie[species] = best_800

# The 'top_800_per_specie' dictionary now contains species as keys
# and lists of the best 800 audio files with SNR less than 20 dB as values

# %%
target_path = f"{DATASET_PATH}/snr_removed"
train_path = f"{DATASET_PATH}/train"
os.makedirs(target_path, exist_ok=True)
for species in os.listdir(train_path):
    if species not in species_to_reduce:
        continue
    for audio in os.listdir(os.path.join(train_path, species)):
        os.makedirs(os.path.join(target_path, species), exist_ok=True)
        if audio not in top_800_per_specie[species]:
            os.rename(
                os.path.join(train_path, species, audio),
                os.path.join(target_path, species, audio)
            )

# %%
print_dataset_count_table()
# Out:
#                                             train  valid  test
# Species
# Fringilla coelebs_Common Chaffinch           5402    600  2040
# Turdus philomelos_Song Thrush                3886    431    58
# Sylvia atricapilla_Eurasian Blackcap         2725    302   715
# Regulus ignicapilla_Common Firecrest         2500    277   417
# Erithacus rubecula_European Robin            1247    138    69
# Troglodytes troglodytes_Eurasian Wren        1044    115    52
# Regulus regulus_Goldcrest                     495     55   106
# Periparus ater_Coal Tit                       286     31   116
# Muscicapa striata_Spotted Flycatcher          231     25    64
# Turdus merula_Eurasian Blackbird              140     15    13
# Certhia familiaris_Eurasian Treecreeper       139     15    69
# Loxia curvirostra_Common Crossbill            134     14    59
# Lophophanes cristatus_Crested Tit             104     11    31
# Dryocopus martius_Black Woodpecker             46      5    24
# Dendrocopos major_Great Spotted Woodpecker     34      3    27
# Pyrrhula pyrrhula_Eurasian Bullfinch           27      2    28
# Glaucidium passerinum_Eurasian Pygmy-Owl       27      2     4

# %% [markdown]
# ### Undo SNR removal

# %%
import os
snr_folder_path = f"{DATASET_PATH}/snr_removed"
train_path = f"{DATASET_PATH}/train"
for species in os.listdir(snr_folder_path):
    for audio in os.listdir(os.path.join(snr_folder_path, species)):
        os.rename(
            os.path.join(snr_folder_path, species, audio),
            os.path.join(train_path, species, audio)
        )

# %% [markdown]
# ### Undo WABAD from Train and Valid

# %%
train_path = f"{DATASET_PATH}/train"
# valid_path = f"{DATASET_PATH}/valid"
wabad_segments = "E:/Giacomo/Tovanella/wabad_segments"

for species in os.listdir(train_path):
    for audio in os.listdir(os.path.join(train_path, species)):
        is_wabad = len(audio.split("_")[0]) != 8
        if is_wabad:
            os.rename(
                os.path.join(train_path, species, audio),
                os.path.join(wabad_segments, species, audio)
            )

# %% [markdown]
# ### Undo Validation

# %%
train_path = f"{DATASET_PATH}/train"
valid_path = f"{DATASET_PATH}/valid"

for species in os.listdir(valid_path):
    for audio in os.listdir(os.path.join(valid_path, species)):
        os.rename(
            os.path.join(valid_path, species, audio),
            os.path.join(train_path, species, audio)
        )
