# %% [markdown]
# # New evaluation test set playground

# %% [markdown]
# this file will be used to test different finetuned models. everytime it is used, please save the results in a different copy and leave this file as clean as possible

# %% [markdown]
# Changes:

# %%
import os
import numpy as np
import json
import pandas as pd
from birdnetlib.analyzer import Analyzer
from birdnetlib.batch import DirectoryAnalyzer
import matplotlib.pyplot as plt 
import copy         # deepcopy
import seaborn as sns

# %%
MODEL_NAME = "wabad_on_minor"
DATASET_NAME = "NEW_DATASET"
DATASET_PATH = f"E:/Giacomo/Tovanella/{DATASET_NAME}"

# %% [markdown]
# ## test the model and extract predictions

# %%
complete_pred_segments = {}
def on_analyze_complete(recording):
    audio_name = recording.path.split('\\')[-1]
    if len(audio_name.split("_")) == 3:
        date, number, segm_id = audio_name.split('_')    # <20200215>_<090000>_<88.wav>
        segm_id = segm_id.split('.')[0]               # <88>.<wav>
    audio_name = "_".join([date, number]) + ".WAV"      # 20190603_030000_196.WAV
    if audio_name not in complete_pred_segments:
        complete_pred_segments[audio_name] = {}
    if segm_id not in complete_pred_segments[audio_name]:
        complete_pred_segments[audio_name][segm_id] = {}
    complete_pred_segments[audio_name][segm_id] = { 
        detection["label"]: detection["confidence"] for detection in recording.detections 
    }
    print("Analyzing ", recording.path)

def on_error(recording, error):
    print("An exception occurred: {}".format(error))
    print(recording.path)

# %%
with open(f"utils/{DATASET_NAME}/true_segments.json") as f:
    all_segments = json.load(f)

# %%
with open("utils/category_info.json") as f:
    category_info = json.load(f)

species_list = list(category_info.keys())

# %% [markdown]
# ## Thresholds

# %%
# save best_threshold_by_species
best_threshold_by_species = {}
if os.path.exists(f"classifiers/official/{MODEL_NAME}/best_threshold_by_species.json"):
    with open(f"classifiers/official/{MODEL_NAME}/best_threshold_by_species.json") as f:
        best_threshold_by_species = json.load(f)

# %% [markdown]
# # Testing

# %%
model_path = f"classifiers/official/{MODEL_NAME}/CustomClassifier.tflite"
labels_path = f"classifiers/official/{MODEL_NAME}/CustomClassifier_Labels.txt"
valid_path = "E:/Giacomo/Tovanella/DATASET/validation"
min_conf = 0.1

analyzer = Analyzer(
    classifier_labels_path=labels_path, 
    classifier_model_path=model_path,
)
# Out:
# load_custom_models
# Custom model loaded.
# loading custom classifier labels
# Labels loaded.
# load model False
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.

# %%
complete_pred_segments = {}
test_path = f"{DATASET_PATH}/test"
for folder in os.listdir(test_path):
    directory = os.path.join(test_path, folder)

    print("Starting Watcher: ", folder)
    batch = DirectoryAnalyzer(
        directory,
        analyzers=[analyzer],
        min_conf=min_conf,
    )

    batch.on_analyze_complete = on_analyze_complete
    batch.on_error = on_error
    batch.process()
# Out:
# Starting Watcher:  Certhia familiaris_Eurasian Treecreeper
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_070000_63.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_070000_63.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_070000_82.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_070000_82.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_070000_83.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_070000_83.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_070000_88.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_070000_88.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_070000_89.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_070000_89.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_090000_100.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_090000_100.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_090000_99.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20190608_090000_99.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_160000_196.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20200217_160000_196.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_160000_197.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Certhia familiaris_Eurasian Treecreeper\20200217_160000_197.wav
# Starting Watcher:  Dendrocopos major_Great Spotted Woodpecker
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_110000_55.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dendrocopos major_Great Spotted Woodpecker\20200217_110000_55.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_110000_56.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dendrocopos major_Great Spotted Woodpecker\20200217_110000_56.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_110000_57.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dendrocopos major_Great Spotted Woodpecker\20200217_110000_57.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_110000_58.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dendrocopos major_Great Spotted Woodpecker\20200217_110000_58.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_110000_59.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dendrocopos major_Great Spotted Woodpecker\20200217_110000_59.wav
# Starting Watcher:  Dryocopus martius_Black Woodpecker
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_100000_173.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200215_100000_173.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_40.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_40.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_41.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_41.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_6.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_6.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_66.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_66.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_67.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_67.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_68.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_68.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_69.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_69.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_7.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_7.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_090000_77.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Dryocopus martius_Black Woodpecker\20200217_090000_77.wav
# Starting Watcher:  Erithacus rubecula_European Robin
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_101.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_101.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_103.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_103.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_104.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_104.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_110.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_110.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_112.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_112.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_113.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_113.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_114.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_114.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_115.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_115.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_116.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_116.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_117.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_117.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_127.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_127.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_128.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_128.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_131.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_131.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_132.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_132.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_133.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_133.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_172.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_172.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_173.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_173.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_175.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_175.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_180.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_180.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_181.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_181.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_87.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_87.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_88.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_88.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_89.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_89.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_90.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_90.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_91.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_91.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_92.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_92.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_94.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_94.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_95.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_95.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_96.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_96.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_180000_97.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Erithacus rubecula_European Robin\20190621_180000_97.wav
# Starting Watcher:  Fringilla coelebs_Common Chaffinch
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_030000_13.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_030000_13.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_030000_14.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_030000_14.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_030000_176.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_030000_176.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_030000_181.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_030000_181.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_030000_182.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_030000_182.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_0.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_0.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_100.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_100.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_110.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_110.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_112.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_112.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_113.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_113.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_120.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_120.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_121.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_121.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_122.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_122.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_123.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_123.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_124.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_124.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_147.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_148.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_148.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_15.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_15.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_151.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_151.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_152.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_152.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_154.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_154.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_155.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_155.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_158.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_158.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_163.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_163.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_164.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_164.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_167.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_167.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_168.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_168.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_17.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_17.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_172.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_172.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_173.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_173.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_175.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_175.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_18.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_18.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_182.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_182.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_183.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_183.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_185.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_185.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_186.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_186.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_188.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_188.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_189.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_189.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_19.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_19.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_190.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_190.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_191.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_191.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_192.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_192.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_193.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_193.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_194.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_194.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_195.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_195.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_196.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_196.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_197.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_197.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_198.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_198.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_21.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_21.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_22.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_22.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_24.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_24.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_25.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_25.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_29.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_29.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_30.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_30.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_33.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_33.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_34.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_34.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_35.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_35.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_36.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_36.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_41.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_41.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_42.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_42.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_44.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_44.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_45.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_45.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_46.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_46.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_49.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_49.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_5.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_5.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_50.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_50.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_6.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_6.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_62.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_62.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_77.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_77.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_78.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_78.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_91.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_91.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_92.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_92.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_93.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_93.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_95.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_95.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_96.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_96.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_97.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_97.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_98.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_98.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_040000_99.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_040000_99.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_0.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_0.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_1.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_1.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_10.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_10.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_100.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_100.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_101.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_101.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_104.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_104.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_105.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_105.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_106.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_106.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_107.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_107.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_108.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_108.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_109.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_109.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_11.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_11.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_110.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_110.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_111.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_111.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_112.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_112.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_113.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_113.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_114.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_114.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_115.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_115.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_116.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_116.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_117.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_117.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_118.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_118.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_119.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_119.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_120.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_120.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_121.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_121.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_122.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_122.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_123.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_123.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_124.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_124.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_125.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_125.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_126.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_126.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_127.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_127.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_128.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_128.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_129.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_129.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_13.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_13.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_130.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_130.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_131.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_131.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_132.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_132.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_133.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_133.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_134.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_134.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_135.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_135.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_136.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_136.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_137.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_137.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_139.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_139.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_14.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_14.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_140.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_140.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_141.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_141.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_142.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_142.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_143.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_143.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_145.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_145.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_146.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_146.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_147.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_149.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_149.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_15.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_15.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_150.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_150.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_151.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_151.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_152.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_152.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_153.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_153.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_154.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_154.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_155.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_155.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_156.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_156.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_157.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_157.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_158.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_158.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_16.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_16.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_160.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_160.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_161.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_161.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_162.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_162.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_163.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_163.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_164.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_164.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_165.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_165.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_166.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_166.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_167.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_167.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_168.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_168.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_169.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_169.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_17.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_17.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_170.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_170.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_171.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_171.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_173.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_173.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_174.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_174.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_176.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_176.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_177.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_177.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_179.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_179.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_18.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_18.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_180.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_180.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_181.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_181.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_182.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_182.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_183.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_183.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_184.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_184.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_185.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_185.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_186.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_186.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_187.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_187.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_188.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_188.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_189.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_189.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_19.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_19.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_190.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_190.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_191.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_191.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_192.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_192.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_193.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Fringilla coelebs_Common Chaffinch\20190621_050000_193.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_050000_194.wav
# ...
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_195.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_195.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_2.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_2.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_20.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_20.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_21.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_21.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_22.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_22.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_23.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_23.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_24.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_24.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_25.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_25.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_26.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_26.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_27.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_27.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_28.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_28.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_29.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_29.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_3.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_3.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_30.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_30.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_31.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_31.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_32.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_32.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_33.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_33.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_34.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_34.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_4.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_4.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_5.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_5.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_6.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_6.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_87.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_87.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_190000_88.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Turdus philomelos_Song Thrush\20190621_190000_88.wav
# Starting Watcher:  Vegetation_
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190603_100000_9.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190603_100000_9.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_100000_15.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_100000_15.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_100000_16.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_100000_16.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_1.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_1.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_10.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_10.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_117.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_117.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_197.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_197.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_2.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_2.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_51.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_51.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_52.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_52.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_56.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_56.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_57.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_57.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_86.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_86.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_87.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_87.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_120000_9.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_120000_9.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_140000_62.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_140000_62.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_140000_63.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_140000_63.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_150000_144.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_150000_144.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190621_150000_145.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20190621_150000_145.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_070000_16.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20200217_070000_16.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_070000_17.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20200217_070000_17.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_070000_18.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20200217_070000_18.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200217_070000_19.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Vegetation_\20200217_070000_19.wav
# Starting Watcher:  Wind_
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_140000_15.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20190608_140000_15.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_140000_16.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20190608_140000_16.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20190608_140000_17.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20190608_140000_17.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_110000_67.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_110000_67.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_110000_68.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_110000_68.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_110000_69.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_110000_69.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_110000_70.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_110000_70.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_138.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_138.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_139.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_139.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_140.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_140.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_141.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_141.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_142.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_142.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_143.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_143.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_146.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_146.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_147.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_148.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_148.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_149.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_149.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_150.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_150.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_151.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_151.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_154.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_154.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_155.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_155.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_156.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_156.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_157.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_157.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_178.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_178.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_179.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_179.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_180.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_180.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_181.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_181.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_54.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_54.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_55.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_55.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_68.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_68.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_69.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_69.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_70.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_70.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_71.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_71.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_72.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_72.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_87.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_87.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_88.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_88.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_89.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_89.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_90.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_90.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 20200215_120000_91.wav
# Analyzing  E:\Giacomo\Tovanella\NEW_DATASET\test\Wind_\20200215_120000_91.wav

# %%
# SAVE
test_complete_pred_segments = copy.deepcopy(complete_pred_segments)
with open(f"classifiers/official/{MODEL_NAME}/test_complete_pred_segments_1.json", "w") as f:
    json.dump(test_complete_pred_segments, f)

# %%
# LOAD, ATTENZIONE AL _1
# with open(f"classifiers/official/{model_name}/test_complete_pred_segments_1.json") as f:
#     complete_pred_segments = json.load(f)

# %%
test_pred_segments = copy.deepcopy(test_complete_pred_segments)
for audio in test_complete_pred_segments:
    for segm_id in test_complete_pred_segments[audio]:
        species_to_save = []
        for label, conf_score in test_complete_pred_segments[audio][segm_id].items():
            if best_threshold_by_species != {}:
                if conf_score > best_threshold_by_species[label]:     # soglia dinamica
                    species_to_save.append(label)
            else:
                if conf_score > 0.2:     # soglia dinamica
                    species_to_save.append(label)
        test_pred_segments[audio][segm_id] = species_to_save

# %%
test_true_segments = {}
for audio in all_segments.keys():
    if audio in test_pred_segments:
        test_true_segments[audio] = {}
        for key, values in all_segments[audio].items():
            if key in test_pred_segments[audio]:
                test_true_segments[audio][key] = [value for value in values if value in species_list]

# %% [markdown]
# ## get results

# %%
from sklearn.preprocessing import MultiLabelBinarizer

species_list = []
# with open(f"classifiers/official/{model_name}/CustomClassifier_Labels.txt") as f:
#     for line in f:  # Iteriamo direttamente sulle righe del file
#         species_list.append(line.strip())  # Rimuovi eventuali spazi bianchi e newline
species_list = os.listdir(test_path)

# species_list.remove("Pecking_")
# species_list.remove("Rain_")
# species_list.remove("Vegetation_")
# species_list.remove("Wind_")
# species_list.remove("Glaucidium passerinum_Eurasian Pygmy-Owl")
# species_list.remove("Turdus merula_Eurasian Blackbird")
# species_list.remove("Muscicapa striata_Spotted Flycatcher")
# species_list.remove("Periparus ater_Coal Tit")
# species_list.remove("Pyrrhula pyrrhula_Eurasian Bullfinch")

mlb = MultiLabelBinarizer()
mlb.fit([list(species_list)])

len(mlb.classes_)
# Out:
# 18

# %% [markdown]
# ### classification report

# %%
y_pred = []
y_true = []
for audio in test_pred_segments:
    # sort in increasing order
    sortable_true_segments = { str(key): value for key, value in test_true_segments[audio].items() }
    sortable_pred_segments = { str(key): value for key, value in test_pred_segments[audio].items() }
    sorted_true_segments = dict(sorted(sortable_true_segments.items()))
    sorted_pred_segments = dict(sorted(sortable_pred_segments.items()))
    y_true.append(mlb.transform(sorted_true_segments.values()))     # apply transform on every label of every segment
    y_pred.append(mlb.transform(sorted_pred_segments.values()))     # apply transform on every label of every segment

y_true = np.vstack(y_true)
y_pred = np.vstack(y_pred)
# Out:
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Muscicapa striata_Spotted Flycatcher', 'Phylloscopus collybita_Common Chiffchaff'] will be ignored
#   warnings.warn(
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Muscicapa striata_Spotted Flycatcher', 'Phylloscopus collybita_Common Chiffchaff', 'Turdus viscivorus_Mistle Thrush'] will be ignored
#   warnings.warn(
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Muscicapa striata_Spotted Flycatcher'] will be ignored
#   warnings.warn(
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Glaucidium passerinum_Eurasian Pygmy-Owl', 'Phylloscopus collybita_Common Chiffchaff'] will be ignored
#   warnings.warn(
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Phylloscopus collybita_Common Chiffchaff'] will be ignored
#   warnings.warn(
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Aeroplane_', 'Phylloscopus collybita_Common Chiffchaff'] will be ignored
#   warnings.warn(
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Turdus viscivorus_Mistle Thrush'] will be ignored
#   warnings.warn(

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=mlb.classes_, zero_division=0, output_dict=True)
with open(f"classifiers/official/{MODEL_NAME}/classification_report_1.json", "w") as f:
    json.dump(report, f)

report_df = pd.DataFrame(report).T
report_df
# Out:
#                                             precision    recall  f1-score  \
# Certhia familiaris_Eurasian Treecreeper      1.000000  0.043478  0.083333
# Dendrocopos major_Great Spotted Woodpecker   0.916667  1.000000  0.956522
# Dryocopus martius_Black Woodpecker           1.000000  0.100000  0.181818
# Erithacus rubecula_European Robin            0.281250  0.375000  0.321429
# Fringilla coelebs_Common Chaffinch           0.905709  0.809745  0.855043
# Lophophanes cristatus_Crested Tit            0.333333  0.052632  0.090909
# Loxia curvirostra_Common Crossbill           0.392157  0.833333  0.533333
# Pecking_                                     0.142857  0.636364  0.233333
# Periparus ater_Coal Tit                      0.848485  0.437500  0.577320
# Rain_                                        0.727273  0.421053  0.533333
# Regulus ignicapilla_Common Firecrest         0.509479  0.607345  0.554124
# Regulus regulus_Goldcrest                    0.550000  0.161765  0.250000
# Sylvia atricapilla_Eurasian Blackcap         0.572961  0.405775  0.475089
# Troglodytes troglodytes_Eurasian Wren        0.643564  0.302326  0.411392
# Turdus merula_Eurasian Blackbird             0.857143  0.315789  0.461538
# Turdus philomelos_Song Thrush                0.437500  0.607143  0.508547
# Vegetation_                                  0.333333  0.193548  0.244898
# Wind_                                        0.145833  0.127273  0.135922
# micro avg                                    0.672029  0.589480  0.628054
# macro avg                                    0.588752  0.412782  0.411549
# weighted avg                                 0.694876  0.589480  0.621283
# samples avg                                  0.686838  0.628726  0.623548
#
#                                             support
# Certhia familiaris_Eurasian Treecreeper        23.0
# Dendrocopos major_Great Spotted Woodpecker     11.0
# Dryocopus martius_Black Woodpecker             10.0
# Erithacus rubecula_European Robin              48.0
# Fringilla coelebs_Common Chaffinch           1293.0
# Lophophanes cristatus_Crested Tit              19.0
# Loxia curvirostra_Common Crossbill             24.0
# Pecking_                                       11.0
# Periparus ater_Coal Tit                        64.0
# Rain_                                          19.0
# Regulus ignicapilla_Common Firecrest          354.0
# Regulus regulus_Goldcrest                      68.0
# Sylvia atricapilla_Eurasian Blackcap          658.0
# Troglodytes troglodytes_Eurasian Wren         215.0
# Turdus merula_Eurasian Blackbird               19.0
# Turdus philomelos_Song Thrush                 196.0
# Vegetation_                                    31.0
# Wind_                                          55.0
# micro avg                                    3118.0
# macro avg                                    3118.0
# weighted avg                                 3118.0
# samples avg                                  3118.0

# %%
pred_array = []
for key in test_pred_segments.keys():
    for value in test_pred_segments[key].values():
        pred_array.extend(set(v for v in value if v in species_list))

# %%
true_array = []
for key in test_true_segments.keys():
    for value in test_true_segments[key].values():
        true_array.extend(set(v for v in value if v in species_list))

# %%
# Converti gli array in Series di pandas per contare le occorrenze
true_series = pd.Series(true_array)
pred_series = pd.Series(pred_array)

# Conta le occorrenze e crea DataFrame
true_counts = true_series.value_counts().sort_index()
pred_counts = pred_series.value_counts().sort_index()

# Unisci i due DataFrame per avere tutte le categorie
all_categories = pd.concat([true_counts, pred_counts], axis=1, sort=True).fillna(0)
all_categories.columns = ['True Segments', 'Predicted Segments']

# Crea il grafico orizzontale
plt.figure(figsize=(8, 4))  # Aumenta la larghezza per le etichette
sns.histplot(data=all_categories, y=all_categories.index, weights='True Segments', alpha=0.5, color='blue', label='True Segments', discrete=True, orientation='horizontal')
sns.histplot(data=all_categories, y=all_categories.index, weights='Predicted Segments', alpha=0.5, color='red', label='Predicted Segments', discrete=True, orientation='horizontal')

plt.xscale('log')  # Scala logaritmica sull'asse x
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### auc roc

# %%
y_pred_conf = []

for audio in test_pred_segments:
    scores_pred = []
    for segm, predictions in complete_pred_segments[audio].items():
        segm_conf_score = np.zeros(len(mlb.classes_))  # Vettore inizializzato a 0 per tutte le classi

        for pred, conf in predictions.items():
            binary_vector = mlb.transform([[pred]])[0]  # Convertiamo in binario (shape: (n_classes,))
            segm_conf_score += binary_vector * conf  # Moltiplichiamo per il confidence score

        scores_pred.append(segm_conf_score)  # Ogni segmento ora ha un array della stessa lunghezza di n_classes
    
    y_pred_conf.append(np.array(scores_pred))  # Lista di array uniformi

# Convertiamo in un array 2D
y_pred_conf = np.vstack(y_pred_conf)
# Out:
# c:\Users\giaco\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:878: UserWarning: unknown class(es) ['Muscicapa striata_Spotted Flycatcher'] will be ignored
#   warnings.warn(

# %%
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12, 7))  # Aumenta la dimensione
n_classes = len(mlb.classes_)
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true[:, i], y_pred_conf[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Classe {mlb.classes_[i]} (AUC = {roc_auc:.2f})')

# Linea di riferimento
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC per Classificazione Multilabel')
plt.legend(loc="upper left", bbox_to_anchor=(1, 1), fontsize=8)
plt.tight_layout()
plt.show()

# %%
roc_data = {}

n_classes = len(mlb.classes_)
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true[:, i], y_pred_conf[:, i])
    roc_auc = auc(fpr, tpr)
    
    # Salviamo i dati in un dizionario
    roc_data[mlb.classes_[i]] = {
        "fpr": fpr.tolist(),  # Converti in lista per compatibilità JSON
        "tpr": tpr.tolist(),
        "auc": roc_auc
    }
    
with open(f"classifiers/official/{MODEL_NAME}/roc_auc_1.json", "w") as f:
    json.dump(roc_data, f)
